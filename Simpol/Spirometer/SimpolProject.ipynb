# %% [markdown]
# # Retrieving and Analyzing Audience of a Twitter Account

# %%
from LibOM.Tools import *
from omterms.interface import *
from functools import reduce
import re, json
import pandas as pd

# %%
class Tweets:
    re_rt = re.compile(r"RT @.*?:")
    re_url = re.compile("(?P<url>https?://[^\s]+)")
    re_ht_valid = re.compile(r"^[a-zA-Z]+[a-zA-Z0-9]*")
    
    def __init__(self, tweets = []):
        print('The tweet extractor class is initiated with {} tweets'.format(len(tweets)))
    
    def extract_info(self,tweets, kw = True):
        return [{'rt': self.is_rt(t),
                 'rt_from': self.rt_from(t),
                 'mentions': self.extract_mentions(t),
                 'hashtags': self.extract_hashtags(t),
                 'keywords': self.extract_keywords(t, kw),
                 'text': self.clean_text(t)} for t in tweets
               ]
            
    def is_rt(self, tweet):
        tweet = tweet['text']
        search = re.search(self.re_rt, tweet)
        return True if search else False
    
    def rt_from(self, tweet):
        matched = re.match(self.re_rt, tweet['text'])
        if not matched: return set()
        tweet['text'] = matched.group()
        return self.extract_mentions(tweet, no_rt=False)
    
    def remove_rt(self, tweet):
        tweet = tweet['text']
        return re.sub(self.re_rt, r' ', tweet)
    
    def extract_urls(self, tweet):
        tweet = tweet['text']
        search = re.search(self.re_url, tweet)
        if search: return search.group("url")
        
    def remove_urls(self, tweet):
        tweet = tweet['text']
        return re.sub(self.re_url, r' ', tweet)
    
    def extract_mentions(self, tweet, no_rt = True):
        tweet = tweet['text']
        if no_rt: tweet = re.sub(self.re_rt, r' ', tweet)
        mentions = set(t[1:] for t in tweet.split() if t.startswith('@'))
        return set([m[:-1] if m.endswith(':') else m for m in mentions])
    
    def extract_hashtags(self, tweet):
        tweet = tweet['text']
        hts = [t[1:] for t in tweet.split() if t.startswith('#')]
        valid_hts = set()
        for ht in hts:
            matched = re.match(self.re_ht_valid, ht)
            if not matched: continue
            valid_hts.add(matched.group())  
        return valid_hts
    
    def remove_mentions(self, tweet):
        tweet = tweet['text']
        tokens = tweet.split()
        mentions = set(t for t in tokens if t.startswith('@'))
        return ' '.join([t for t in tokens if t not in mentions])
    
    def clean_text(self, tweet):
        tweet['text'] = self.remove_urls(tweet)
        tweet['text'] = self.remove_rt(tweet)
        return self.remove_mentions(tweet)
    
    def extract_keywords(self, tweet, kw = True):
        if not kw: return set()
        if tweet['lang'] != 'en': return set()
        text = self.clean_text(tweet)
        return set(extract_terms(text, min_termlength=2, min_tf=0).Term)

# %% [markdown]
# ### 1. Connecting to the Twitter API

# %% [markdown]
# #### Credentials
# In order to get credentials to be able to connect to the Twitter:
# - Login to https://apps.twitter.com
#  - If you already have twitter application you may use its credentials.
#  - Or generate a new set of keys and tokens via "Create a New App" button.
# - Click "Keys and Access Tokens" tab and copy "API key", API secret".
# - Click "Create my Access Token" and copy "Access token" and "Access token secret".

# %%
Credentials = {}
Credentials['Consumer_Key'] = "your key" 
Credentials['Consumer_Secret'] = "your secret"
Credentials['Access_Token'] = "your token" 
Credentials['Access_Token_Secret'] = "your token secret"

# %% [markdown]
# #### Instantiating the custom Twitter interface
#  The interface is used to drive Twitter API. It was originally developed for the Community Spirals API project.

# %%
ClientTwitter = Twitter()

# %% [markdown]
# #### Setting the account.

# %%
account = 'SimPolProject'

# %% [markdown]
# ### 2. Retrieving followers of the account
#
# Uncomment the cell below, when updating and re-harvesting twitters of the followers is needed. It will take time and will be subject to limitations.

# %%
#followers = ClientTwitter.retrieve_followers([auser])['theset']
# The account's own tweets are also to be harvested.
#followers.add(account)

# %% [markdown]
# #### Saving the harvested data on the disk for re-use and to avoid repeated harvesting.

# %%
fname = './output/lists/' + account +'_followers.pickle'

# %%
#with open(fname, 'wb') as handle: pickle.dump(followers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Reloading the harvested tweets of the followers

# %%
with open(fname, 'rb') as handle:
    followers = pickle.load(handle)

# %%
len(followers)
# Out:
# 683

# %%
pp.pprint(followers)
# Out:
# {'0ttamatt',
#  '2dipicchee',
#  '4A50CqwsQqeahlq',
#  '7softley',
#  '7wData',
#  '85Fifteen',
#  'AEBIOM',
#  'APRC_CF',
#  'ARNAOYTHSD',
#  'AdaFerko',
#  'AdamPC26',
#  'Adeline_story',
#  'Adellibya1979',
#  'AdolfSanchez5',
#  'Adoufrancois',
#  'Agent_Jase',
#  'Agn_ssa',
#  'AlanGIsaac',
#  'AlbertoMunoz',
#  'AldeiDiogo',
#  'AlessandroLaced',
#  'Alex_GuerreroR',
#  'AlineCosette',
#  'Amanuel40Rui',
#  'AndreaBindo',
#  'AndreaRoventini',
#  'Andreas_Chile',
#  'Andrewbrum',
#  'AngelFe23124123',
#  'Angela07261976',
#  'Anna_Hadorn',
#  'AnneMur16630871',
#  'AppDeveloperHue',
#  'ArcmorRib',
#  'ArnautzPgvila',
#  'Arturo311311311',
#  'AsaBentley',
#  'Asmmar1999',
#  'AugustusSouto',
#  'BIntendente',
#  'BUPardeeCenter',
#  'Barone54924381',
#  'BenitoMma',
#  'Benmccreton1',
#  'Better_Finance',
#  'Beyond_Ratings',
#  'Bifrostonline',
#  'BigDataStackEU',
#  'BingoLittle1',
#  'BlacMambaMMA',
#  'Blinis',
#  'Blueland1',
#  'BluewaterGlobe',
#  'BoekeKatrin',
#  'BradZarnett',
#  'BrainConceptual',
#  'BsjgMMZetBPIHca',
#  'BusinessPartnrs',
#  'ByGeorgePerr',
#  'CASAPUEBLO8',
#  'CCL_Aus',
#  'CGraciaLazaro',
#  'CMCSatBU',
#  'CT_Coughlin',
#  'CanddyShawn',
#  'CanvasVC',
#  'CardanIOTeam',
#  'CardanoStiftung',
#  'CarnesBestia',
#  'CaroleCasuco',
#  'CasaEdelVicenza',
#  'Casinos95',
#  'Caydennash2',
#  'CherryEnergy1',
#  'ChrisGGeorgas',
#  'ChrisHudgins5',
#  'ChristosEllina1',
#  'CigeuInfo',
#  'Climate_Friend',
#  'CoeGSS',
#  'Complexity_Labs',
#  'Concerns_You',
#  'CorneliaDaniel',
#  'CriptodivisasMx',
#  'Crypto20183',
#  'CyprusInno',
#  'DELPHIBG',
#  'D_young_69',
#  'Daimakaimura',
#  'DarkMatter_Labs',
#  'DatingCH',
#  'DeboyJames21',
#  'DecentralizedEn',
#  'DeepestLearning',
#  'Demon666Yt',
#  'DiabetesDaisy',
#  'DimasSetyadi5',
#  'DinoFiorita',
#  'DistributedNRG',
#  'DougThorpe_com',
#  'DrDrossosDem',
#  'Drideologie',
#  'DucThiLuu',
#  'Duph_Berg',
#  'DustyTweak',
#  'EERwtUeb7HgG8pf',
#  'EHillBrody',
#  'EarthWatt',
#  'Easyimpresa1',
#  'EcologicalEcon',
#  'Eindhoven60',
#  'Elcada_GmbH',
#  'EmreYakr1',
#  'EnviroNews',
#  'Etp4H',
#  'EuroLuckyStars',
#  'FETFX_EU',
#  'FETFlagships',
#  'FabioCarrirolo',
#  'FabriceSabatier',
#  'Falco810',
#  'FcoKienzle',
#  'Fede_Botta',
#  'Fet2Rin',
#  'FightInequalit1',
#  'Filipata__',
#  'FinexusCenter',
#  'FinforTomorrow',
#  'FiramisCompany',
#  'FootnoteMedia',
#  'FoundationRMF',
#  'Frances11022994',
#  'FranciscoICMC',
#  'FredAmblard',
#  'FutSciNow',
#  'GECoalition',
#  'Gabriel_Hatem',
#  'GautierChauvin',
#  'GeoVun',
#  'GiachiniDaniele',
#  'Gianlucamisu',
#  'Gius_C',
#  'GladiAAreise',
#  'GochaT69',
#  'GuidoCaldarelli',
#  'HNR_org',
#  'HamishJWyatt',
#  'HanKitcher',
#  'HelenJackson0',
#  'Helens60',
#  'HyacintheBuiss1',
#  'IASS_DOLFINS',
#  'IASS_Potsdam',
#  'IBSEN_H2020',
#  'IET_online',
#  'IMPACT_EV',
#  'IMTipps',
#  'IOPDAHKA',
#  'ISEEORG',
#  'ISI_Fondazione',
#  'ISIgrowth',
#  'Igorsemenoff',
#  'Ika_Midenistis',
#  'ImpactShapers',
#  'Inova_Paciente',
#  'JBPKGSolutions',
#  'JFernandoGRE',
#  'JacopoSestili',
#  'JahelMielke',
#  'James_Vaccaro',
#  'JeromeRoch74',
#  'JoeRini6',
#  'JofreCarnicer',
#  'JonathanEcon',
#  'JulienHallak',
#  'KerrieMengersen',
#  'KimMarln',
#  'KleineBottleM',
#  'KoljaKleineberg',
#  'KushyKush',
#  'LDNinst',
#  'LERUnews',
#  'L__Macfarlane',
#  'LeadMakelaar',
#  'LeanneUssher',
#  'LetUsShineNow',
#  'LetsWorkHappy',
#  'LieveFransen',
#  'LindaBach14',
#  'Lori_McNeill',
#  'LostInMath',
#  'Louisbarla',
#  'Lsuttors',
#  'LucieKirstein',
#  'LuisaDeAmicis',
#  'LyndaMansson',
#  'MARGA_GLEZ_FDEZ',
#  'MARIASOLOMONID2',
#  'MBMConsultancy',
#  'MPA37855265',
#  'MacroPru',
#  'Mahfuz__Rahman',
#  'MariaBejaCosta1',
#  'MariaMariliam23',
#  'Marji84',
#  'MarlonMasine',
#  'MartaCalderaro',
#  'MartinaOccelli',
#  'Mattia_Guerini',
#  'Maxknew',
#  'MazzucatoM',
#  'MiaPhlor',
#  'MichaelRFerrari',
#  'MichellLiberty',
#  'MiguelBasire',
#  'MikeOConnor3',
#  'MitchDOPEcom',
#  'Mlopezforero',
#  'MolinariMax_',
#  'MoneyWAmission',
#  'Monithon',
#  'MorganBeaugrand',
#  'NectuntLab',
#  'NgulunguT',
#  'NickBeglinger',
#  'NickJackson81',
#  'Nietzchrodinger',
#  'NomosCSP',
#  'OVESCO',
#  'Oleatopia',
#  'OlgaBuchholz',
#  'OneClickSolar',
#  'OnePlanetParis',
#  'OrpheusEU',
#  'PEP4UM',
#  'PPFEnergia',
#  'PSalazarO',
#  'PaoloBarucca',
#  'Paorazio',
#  'PatrikReisinger',
#  'PatsonBibou1168',
#  'Pedromgi19',
#  'PetraKraljNovak',
#  'Peveeeric1',
#  'PheasantEnergy',
#  'Phil5571',
#  'PhillipNunnUK',
#  'PhysScala',
#  'Pierre_Monnin',
#  'Platy_Kalamatas',
#  'PolatSihab',
#  'PolicyCompassEU',
#  'Project722TMX',
#  'PubAffairsEU',
#  'REANworld',
#  'RFIFoundation',
#  'RRytenband',
#  'RakibEnew',
#  'RebuildMacro',
#  'Registry_Blocks',
#  'RitaMaria_dRC',
#  'RobPasqualino',
#  'RoccaBam',
#  'RockJimford',
#  'RogerCremades',
#  'RogervEijk',
#  'RothcoPepp',
#  'RubyBretislav',
#  'SFL_nl',
#  'SICommunity_EU',
#  'SSEinitiative',
#  'SUPERTWIN_H2020',
#  'Sandra_G_Urbano',
#  'Saracris95',
#  'Sb4GvLAuBrNkc93',
#  'Schumannpoet',
#  'Seavangelesse',
#  'Sebespejo',
#  'SelinaStoller',
#  'SeloSlav',
#  'ShaunFrankson',
#  'SiQuizas',
#  'SimPolProject',
#  'SimonThordal',
#  'SimulPast',
#  'SodreLuciana',
#  'StarwarsMaker',
#  'StephaneNappo',
#  'StieberHarald',
#  'SunilMalhotra',
#  'SusFinLab',
#  'SusieMod88',
#  'SvyatoslavHrync',
#  'SwissCognitive',
#  'TMWFTE',
#  'TSERETELI_0102',
#  'TagederSonne',
#  'TehRaio',
#  'TheRealShankar',
#  'Thierry_Kame',
#  'TiberiuPetre',
#  'TipGhosh',
#  'TomasBalint',
#  'TorreyShine',
#  'Transitionway',
#  'UB_ICS',
#  'UNEP_FI',
#  'ValerioVolpati',
#  'Vangel_artist',
#  'VeronicaClima',
#  'Vibeka',
#  'VilmaBerta17',
#  'VivereLanzarote',
#  'VlPetrovV',
#  'WJFTechnical',
#  'WOETUK',
#  'WRIClimate',
#  'WarrenWhitlock',
#  'WelfareUnited',
#  'WiedmannBibel',
#  'Xilbshi',
#  'YannisDafermos',
#  'ZeGordon',
#  'Zen3dT',
#  'ZhengIsabelle',
#  'ZoeGold69',
#  'ZofiaWemanska',
#  '_ChiaraPerillo',
#  '_NicoFrey',
#  '__jasmy',
#  '_ch3m',
#  '_marameo_',
#  '_ndrd_',
#  'a_yang_w',
#  'adilson_motter',
#  'adria_plazas',
#  'aebiondo',
#  'aetw15',
#  'afrochia',
#  'agabardo',
#  'ailatan1898',
#  'ale_marichela',
#  'aleaf_h2020',
#  'alediemmee',
#  'alfonso_soldano',
#  'alp08989139',
#  'alvarofenomeno',
#  'amanahramadiah',
#  'amapr1',
#  'ambatellova8u9',
#  'amritasaha',
#  'amsterdam_bill',
#  'anaishannah',
#  'andkarpf',
#  'andrasonea',
#  'anduviera',
#  'anewmediaprof',
#  'angelnunhez',
#  'anhvan_dz',
#  'anielloiorio197',
#  'anima_tu',
#  'anxosan',
#  'aparpau',
#  'arthurturrell',
#  'asgeirbt',
#  'aurorab96124853',
#  'avogli',
#  'axekoukou',
#  'ayazarka88',
#  'aymeric_vie',
#  'bandigsm',
#  'barcomerni',
#  'barryejames',
#  'baryshnevadn0',
#  'bassindales',
#  'bastidas_d',
#  'bb_pedromartins',
#  'bdp_smith',
#  'bellacindylee',
#  'bergautier',
#  'bethscleft',
#  'bginoc',
#  'bh7u86u5tvfsn',
#  'bitlumens',
#  'bobbyreyes20',
#  'bonosverdes',
#  'bplisse',
#  'brianehenyo',
#  'brianla1',
#  'brjmoez',
#  'bulentozel',
#  'burrolahola',
#  'camilleoudinot',
#  'carinacarinas',
#  'carnadani',
#  'cbbagsic',
#  'chrizau',
#  'ciro',
#  'claudia_mihai',
#  'complex_warsaw',
#  'coonchi14',
#  'cosnet_bifi',
#  'crie_ufrj',
#  'daniel_eth',
#  'daniel_goldsmth',
#  'danilo_liuzzi',
#  'danilushkinaed1',
#  'darden2032',
#  'dariomarmo_lama',
#  'darko_darkoa',
#  'dataforpolicy',
#  'davidecellai',
#  'destiny_dii',
#  'dgpapanikas',
#  'dindjic',
#  'dlacalle_IA',
#  'dormiveglia',
#  'dpcwiseman',
#  'dsuker',
#  'duyennguyen286',
#  'e77876519af54a6',
#  'economics_twitr',
#  'ecozzo',
#  'edzaizvobwo',
#  'egbr916',
#  'eleni_choidas',
#  'elifgunduzyeli',
#  'elisa_letizia',
#  'elisa_omodei',
#  'emacampiglio',
#  'emergir_co',
#  'energynewsnowtv',
#  'envproceng',
#  'enzomanzo1',
#  'epathlo',
#  'er_chechi',
#  'eric_vanpraag',
#  'eswissolar',
#  'eurohumph',
#  'ey0758',
#  'f_bontadini',
#  'fabiofxvanni',
#  'fbonmatiB',
#  'feducaydesarrol',
#  'ferminserrano',
#  'fet_eu',
#  'filevaig41',
#  'filipe2747',
#  'filippoaddarii',
#  'firth_john',
#  'flaskn6',
#  'flipparini',
#  'forfinancewatch',
#  'fotinipolichro',
#  'francrsci',
#  'fun_rich',
#  'futsofwelfare',
#  'gagliol',
#  'galeanojav',
#  'gary6115',
#  'gbracci_des',
#  'georguensberg',
#  'georsara11',
#  'germanacanzi',
#  'gerrad12456789',
#  'giacomo_rella',
#  'giacomolivan',
#  'giannismanidis1',
#  'gilologi',
#  'giorgosvarzelio',
#  'giuliaporino',
#  'globalromance16',
#  'godinfred',
#  'goldthau',
#  'gomezramirez_ac',
#  'goodhartlaw',
#  'greenblut_kris',
#  'greencareersorg',
#  'greenetworksco',
#  'greenwinproject',
#  'grippt',
#  'guyyeomans',
#  'gzkbs',
#  'hamzaz',
#  'hans_taeubler',
#  'harshalhayat',
#  'helloplanetmars',
#  'heloisa58879287',
#  'hjybuptster',
#  'hsissom',
#  'huumanhlc1980',
#  'i_anag',
#  'iacobet79',
#  'ideeverdi',
#  'igor_mozetic',
#  'ilhanakbas',
#  'imleslahdin',
#  'impactdottech',
#  'impactvesting',
#  'impaqt_io',
#  'imsumitchouhan',
#  'indy_johar',
#  'iormazabali',
#  'ivan8848',
#  'ivancitocostasm',
#  'jarekkla',
#  'jferretm',
#  'jgliu626',
#  'jimodonnell2',
#  'jiyanstorymovie',
#  'jkpaulin',
#  'jlmateos',
#  'jmblanch',
#  'jnode',
#  'joaquimfialho19',
#  'joelcomm',
#  'johemart55',
#  'johnbirdswords',
#  'joostmulder',
#  'jordywos',
#  'joseph_sattler',
#  'juancerdap',
#  'jviver',
#  'kaliterilamia',
#  'karlape45',
#  'katausten',
#  'kate3lakes',
#  'kevinpuisieux',
#  'koptermaharania',
#  'kostasdimou5',
#  'kostasgal50',
#  'kostastt1',
#  'kosttttoziss',
#  'kurganskayapos',
#  'laografikos',
#  'larryclane',
#  'laurasabatini3',
#  'laurentbaheux',
#  'laurettaeliana',
#  'lectureverb',
#  'lgaalves',
#  'licht_anna',
#  'lilitpopoyan',
#  'lindod1972',
#  'lista_redes',
#  'lperodabasioglu',
#  'm_dalp',
#  'm_waeck',
#  'maggie_q_q',
#  'mallenbaker',
#  'manlius84',
#  'manuelhurt',
#  'marcobardoscia',
#  'marcoderrico',
#  'marcos_mancini',
#  'marialaxa541',
#  'mariusjoh',
#  'marlin_meier',
#  'mateusevil10',
#  'maxidana1',
#  'mennoliauw',
#  'mercadomagico',
#  'michele_slowey',
#  'mientje1000000',
#  'mike_n_martin',
#  'min_standardism',
#  'mireillmartini',
#  'miromarchi',
#  'mixalis_papako',
#  'mkhm',
#  'mm1112322234',
#  'mnapoletano1',
#  'monicanagore',
#  'moritszsz',
#  'mqdicer',
#  'mszll',
#  'multiplex_fet',
#  'mvly3',
#  'my_pochemuchka',
#  'mydailynews24',
#  'n33dstfu',
#  'nachoenblanco',
#  'nalsrarekli',
#  'nanumyan',
#  'netizait',
#  'netsci15',
#  'netsci2017',
#  'ngominhthanh4',
#  'nicolerycroft1',
#  'nyaghouti',
#  'oddsku007',
#  'oikonomopoulo14',
#  'oil_products',
#  'olivierhoedeman',
#  'openmaker',
#  'openp2pdesign',
#  'orbassano2000',
#  'oskayipek',
#  'p_chiocchetti',
#  'p_messages',
#  'palabresgroup',
#  'palpi643',
#  'panchulzz',
#  'panteshkinati8',
#  'parraguezr',
#  'partickaya7wa1',
#  'pdjahnke',
#  'ph_desfosses',
#  'pikosapikosgr',
#  'plusvaluetweets',
#  'poesiaculina',
#  'popeye4__',
#  'prabprab',
#  'promitmoitra',
#  'querforscher',
#  'r0guetrainer',
#  'rcabinte',
#  'recofunghi',
#  'renesugar',
#  'repecCitEc',
#  'resume_unilu',
#  'rgod777',
#  'ricardo11701135',
#  'riddick19811',
#  'rubene822',
#  'saitej786',
#  'sambaravioli',
#  'sandrosapio',
#  'sarahncorry',
#  'sarresd8',
#  'sartin',
#  'saxorut',
#  'schulte_stef',
#  'sconquer8',
#  'sebastienwathle',
#  'sees_lab',
#  'sergiocabrero',
#  'shakgohir',
#  'shanegibson',
#  'shopwearblack',
#  'simply_jaehyuk',
#  'sjnwoh',
#  'smalkina5e1',
#  'solarcollab',
#  'solarfornia',
#  'spiros_patelis',
#  'stefanodigiorg3',
#  'stefatos_kostas',
#  'stephenkinsella',
#  'stf18',
#  'strategypod',
#  'styvencr7',
#  'su_re_co',
#  'syaltout',
#  'syroter_',
#  'systemRK',
#  'tachristopoulos',
#  'takis_kt',
#  'tarik_rko',
#  'thanhbong06',
#  'the_young_fdn',
#  'theceschi',
#  'thekokytus',
#  'thetippytopblog',
#  'titarchukaj2s',
#  'tiveleva4ie',
#  'tommaschera',
#  'tori_henry2',
#  'tozhs',
#  'tricks_y',
#  'trxias',
#  'uzh_bf',
#  'valteraguiar654',
#  'vectracrome111',
#  'veronika_st5',
#  'vijayakumarmad6',
#  'vtchakarova',
#  'xavierhervas',
#  'yanhua_yanhua7',
#  'yuliay',
#  'yuridayana10',
#  'zbattiz',
#  'zoozanne'}

# %% [markdown]
# ### 3. Retrieving tweets of the followers of the account
# Uncomment the cell below, when updating and re-harvesting twitters of the followers is needed. It will take time and will be subject to limitations.

# %%
def harvest_tweets(followers):
    done = set()
    notdone = set(followers).difference(done)
    for auser in notdone:
        debates = ClientTwitter.retrieve_tweets([auser], nlatest = 200, merge = False)
        tweets = debates[auser]['content']
        fname = './output/tweets/' + auser +'.pickle'
        with open(fname, 'wb') as handle:
            pickle.dump(tweets, handle, protocol=pickle.HIGHEST_PROTOCOL)
        done.add(auser)
        print('Done: {}'.format(auser))
    return done, notdone

# %%
#harvest_tweets(followers)

# %% [markdown]
# #### A quick examination of harvested data.

# %%
for auser in followers:
    fname = './output/tweets/' + auser +'.pickle'
    with open(fname, 'rb') as handle:
        tweets = pickle.load(handle)
    print('{}: {}'.format(auser,len(tweets)))
    if len(tweets) < 5: pp.pprint(tweets)
# Out:
# Marji84: 200
# feducaydesarrol: 200
# vectracrome111: 200
# SwissCognitive: 200
# greencareersorg: 199
# ArnautzPgvila: 200
# dlacalle_IA: 200
# StieberHarald: 37
# SiQuizas: 199
# hsissom: 69
# adilson_motter: 143
# VlPetrovV: 193
# aurorab96124853: 1
# [{'lang': 'en',
#   'text': 'aurora borealis demonstration 1. move the crowd '
#           'https://t.co/O8Wa2fAW8Y via @YouTube'}]
# burrolahola: 200
# marlin_meier: 37
# Seavangelesse: 200
# 7wData: 200
# danilushkinaed1: 25
# daniel_goldsmth: 200
# SusFinLab: 199
# filevaig41: 34
# EnviroNews: 199
# Xilbshi: 185
# AndreaBindo: 200
# PPFEnergia: 199
# germanacanzi: 200
# MichellLiberty: 192
# bassindales: 200
# fet_eu: 200
# PolicyCompassEU: 199
# anaishannah: 200
# Maxknew: 199
# egbr916: 200
# shakgohir: 199
# TSERETELI_0102: 22
# BrainConceptual: 52
# bb_pedromartins: 200
# DinoFiorita: 199
# OVESCO: 200
# Saracris95: 199
# WOETUK: 23
# agabardo: 199
# MariaBejaCosta1: 157
# aymeric_vie: 200
# 2dipicchee: 192
# KimMarln: 200
# brjmoez: 200
# kurganskayapos: 27
# ale_marichela: 200
# Transitionway: 200
# LyndaMansson: 199
# amsterdam_bill: 200
# anielloiorio197: 200
# CCL_Aus: 200
# 85Fifteen: 200
# MARGA_GLEZ_FDEZ: 200
# CGraciaLazaro: 200
# dindjic: 200
# SICommunity_EU: 200
# Angela07261976: 200
# i_anag: 46
# DiabetesDaisy: 200
# imleslahdin: 200
# solarcollab: 200
# michele_slowey: 0
# []
# cbbagsic: 200
# oskayipek: 199
# HelenJackson0: 200
# nyaghouti: 0
# ''
# giuliaporino: 11
# GECoalition: 200
# DistributedNRG: 200
# ZeGordon: 0
# ''
# AppDeveloperHue: 172
# jnode: 199
# simply_jaehyuk: 198
# guyyeomans: 200
# SimonThordal: 42
# Drideologie: 200
# ambatellova8u9: 24
# maxidana1: 27
# juancerdap: 199
# kate3lakes: 196
# baryshnevadn0: 30
# Climate_Friend: 200
# PhysScala: 0
# []
# FutSciNow: 194
# PubAffairsEU: 200
# MBMConsultancy: 200
# BradZarnett: 200
# CanddyShawn: 199
# LERUnews: 200
# Mahfuz__Rahman: 197
# OlgaBuchholz: 0
# ''
# riddick19811: 0
# ''
# RFIFoundation: 200
# marialaxa541: 200
# impactdottech: 193
# panteshkinati8: 28
# spiros_patelis: 11
# ChrisHudgins5: 192
# emergir_co: 164
# saxorut: 131
# mkhm: 0
# ''
# stefatos_kostas: 200
# WJFTechnical: 200
# repecCitEc: 200
# trxias: 10
# CardanoStiftung: 199
# RoccaBam: 2
# [{'lang': 'in', 'text': 'Hidup ku  kecag kecog'},
#  {'lang': 'in', 'text': 'Pencarian yg mengerti keadaan'}]
# m_dalp: 25
# fun_rich: 200
# stefanodigiorg3: 161
# orbassano2000: 200
# mszll: 199
# CMCSatBU: 200
# harshalhayat: 200
# LindaBach14: 85
# tarik_rko: 198
# NectuntLab: 57
# mateusevil10: 1
# [{'lang': 'en', 'text': 'Hand Spinner #2MCanalTop10'}]
# greenetworksco: 200
# RogerCremades: 200
# dariomarmo_lama: 200
# MiguelBasire: 199
# TomasBalint: 200
# anduviera: 200
# zoozanne: 200
# iacobet79: 10
# FETFlagships: 200
# barcomerni: 200
# elisa_letizia: 36
# a_yang_w: 0
# []
# IASS_Potsdam: 200
# IBSEN_H2020: 200
# saitej786: 197
# thetippytopblog: 199
# mariusjoh: 200
# VivereLanzarote: 190
# SusieMod88: 200
# MartaCalderaro: 200
# kaliterilamia: 200
# sambaravioli: 199
# lindod1972: 200
# dpcwiseman: 200
# IMPACT_EV: 199
# bandigsm: 36
# CasaEdelVicenza: 24
# querforscher: 72
# camilleoudinot: 200
# mireillmartini: 200
# lgaalves: 200
# DrDrossosDem: 200
# ZhengIsabelle: 41
# SelinaStoller: 200
# CanvasVC: 200
# RRytenband: 200
# lectureverb: 200
# oil_products: 54
# Lsuttors: 200
# ivancitocostasm: 11
# UNEP_FI: 200
# koptermaharania: 0
# ''
# BlacMambaMMA: 192
# RothcoPepp: 200
# afrochia: 0
# ''
# Falco810: 200
# CT_Coughlin: 200
# filippoaddarii: 200
# jkpaulin: 200
# imsumitchouhan: 200
# openmaker: 200
# thekokytus: 193
# EERwtUeb7HgG8pf: 132
# 7softley: 200
# Louisbarla: 0
# []
# BIntendente: 200
# elifgunduzyeli: 200
# AdaFerko: 200
# Casinos95: 0
# ''
# MolinariMax_: 200
# Bifrostonline: 200
# Igorsemenoff: 200
# parraguezr: 200
# _ch3m: 199
# amapr1: 45
# georguensberg: 200
# darko_darkoa: 15
# VilmaBerta17: 197
# sandrosapio: 25
# laografikos: 3
# [{'lang': 'el',
#   'text': 'Επιτυχία με πολύ καλά σχόλια είχε στο φεστιβάλ Αλοννήσου  Ο '
#           'Χορευτικός Όμιλος »ΜΕΤΕΩΡΑ» https://t.co/VgWuu8SL2a'},
#  {'lang': 'el', 'text': 'ΓΕΙΑ ΧΑΡΑ !!!'},
#  {'lang': 'el', 'text': 'ΓΕΙΑ ΧΑΡΑ'}]
# EuroLuckyStars: 1
# [{'lang': 'en',
#   'text': 'RT @BarackObama: "No one is born hating another person because of '
#           'the color of his skin or his background or his religion..." '
#           'https://t.co/InZ58zkoAm'}]
# laurentbaheux: 200
# filipe2747: 200
# amanahramadiah: 200
# Adoufrancois: 0
# ''
# rgod777: 200
# ShaunFrankson: 200
# EarthWatt: 198
# tachristopoulos: 200
# coonchi14: 14
# IASS_DOLFINS: 125
# Anna_Hadorn: 14
# ISIgrowth: 200
# AlessandroLaced: 199
# anhvan_dz: 23
# MarlonMasine: 106
# ailatan1898: 69
# hans_taeubler: 200
# MoneyWAmission: 200
# kostastt1: 200
# Zen3dT: 200
# min_standardism: 200
# HyacintheBuiss1: 200
# KerrieMengersen: 200
# BenitoMma: 172
# FranciscoICMC: 199
# 0ttamatt: 73
# oikonomopoulo14: 119
# huumanhlc1980: 200
# yuridayana10: 97
# netizait: 0
# []
# AndreaRoventini: 200
# Caydennash2: 127
# Platy_Kalamatas: 200
# AldeiDiogo: 176
# OrpheusEU: 200
# CyprusInno: 200
# RogervEijk: 119
# Eindhoven60: 200
# licht_anna: 3
# [{'lang': 'de',
#   'text': 'RT @joha_roth: Heimat\n'
#           'Heimat und Inneres\n'
#           '\n'
#           'Inneres\n'
#           'Inneres und Bauen\n'
#           '\n'
#           'Heimat\n'
#           'Heimat und Bauen\n'
#           '\n'
#           'Heimat und Inneres und Bauen und\n'
#           'Ein Horst'},
#  {'lang': 'en',
#   'text': 'RT @SimPolProject: New GCF working paper: why coordination is key '
#           'in triggering #greeninvestment for a sustainable future '
#           '#greengrowth https://t.co/efF5I0X1ji'},
#  {'lang': 'in',
#   'text': 'Public viewing im Laidak, Berlin: #c24live https://t.co/4t3zXg7aa3'}]
# anima_tu: 200
# MitchDOPEcom: 14
# sconquer8: 9
# HanKitcher: 200
# OnePlanetParis: 184
# ideeverdi: 6
# chrizau: 200
# IET_online: 200
# WRIClimate: 200
# DucThiLuu: 48
# Barone54924381: 197
# NgulunguT: 1
# [{'lang': 'fr',
#   'text': "# a l'anniv de fils de  président Trump,qu'il demande a son père le "
#           'new Kinshasa, comme la fille de g.Busch.'}]
# CASAPUEBLO8: 79
# Inova_Paciente: 99
# mientje1000000: 200
# RobPasqualino: 58
# Mlopezforero: 117
# VeronicaClima: 200
# JFernandoGRE: 200
# Complexity_Labs: 200
# CardanIOTeam: 30
# popeye4__: 200
# asgeirbt: 199
# ISI_Fondazione: 200
# oddsku007: 198
# Duph_Berg: 199
# eric_vanpraag: 200
# sebastienwathle: 1
# [{'lang': 'und', 'text': 'https://t.co/eS0RbKOAzT'}]
# Schumannpoet: 89
# DatingCH: 200
# Lori_McNeill: 200
# ivan8848: 200
# Benmccreton1: 200
# partickaya7wa1: 30
# SUPERTWIN_H2020: 73
# JulienHallak: 174
# ARNAOYTHSD: 200
# theceschi: 200
# carnadani: 82
# EHillBrody: 0
# ''
# tommaschera: 11
# LetsWorkHappy: 200
# davidecellai: 200
# PhillipNunnUK: 200
# eswissolar: 58
# ImpactShapers: 67
# _NicoFrey: 200
# JeromeRoch74: 200
# r0guetrainer: 199
# Mattia_Guerini: 200
# elisa_omodei: 200
# amritasaha: 200
# mike_n_martin: 198
# georsara11: 64
# styvencr7: 0
# []
# WiedmannBibel: 200
# alvarofenomeno: 195
# MARIASOLOMONID2: 140
# aparpau: 200
# daniel_eth: 200
# systemRK: 83
# Phil5571: 0
# []
# gilologi: 200
# Demon666Yt: 32
# hjybuptster: 194
# JofreCarnicer: 200
# thanhbong06: 135
# marcos_mancini: 200
# ChrisGGeorgas: 200
# kostasgal50: 11
# promitmoitra: 200
# SvyatoslavHrync: 200
# mydailynews24: 200
# su_re_co: 199
# _ChiaraPerillo: 47
# L__Macfarlane: 200
# ciro: 200
# D_young_69: 200
# Amanuel40Rui: 200
# APRC_CF: 200
# ISEEORG: 200
# nanumyan: 133
# axekoukou: 200
# OneClickSolar: 188
# jarekkla: 1
# [{'lang': 'en',
#   'text': 'RT @complex_warsaw: On Thursday @complex_warsaw will hold a '
#           '@wwcs_2017 inspired #NetworkGame\xa0during #Warsaw #Science Fair '
#           '(@FNWarszawa):\xa0https://t.co/BfYM1l2Fq4 https://t.co/Y1IaTllZtd'}]
# Andreas_Chile: 4
# [{'lang': 'en',
#   'text': '@fininquiry , arguably now at the centre (at least in my network '
#           'data) of the ideas on sustainable finance, speaks its last words. '
#           'Congrats for an honest and comprehensive report: '
#           'https://t.co/f4ZnyBFnos'},
#  {'lang': 'en',
#   'text': "There is an alternative! It's pluralism. Come join our quest to "
#           '#Changeeconomics https://t.co/IT7ilHADUy'},
#  {'lang': 'de',
#   'text': 'Gastwirtschaft: Lobbyisten im Unterricht | Gastwirtschaft\xa0- '
#           'Frankfurter Rundschau https://t.co/Q1tBsYuP5d via @FRonline'},
#  {'lang': 'und', 'text': '#PropaganBDA\nhttps://t.co/zxKSQNsikQ'}]
# greenblut_kris: 200
# _ndrd_: 37
# mqdicer: 200
# fotinipolichro: 4
# [{'lang': 'und', 'text': '#nightout #drinks #have fun https://t.co/vZQmQdVlo6'},
#  {'lang': 'und', 'text': 'https://t.co/XpHkIf8qfu'},
#  {'lang': 'und', 'text': '#photooftheday https://t.co/HHBT5Bn8cm'},
#  {'lang': 'und', 'text': 'https://t.co/bmJ2NRWIJx'}]
# bh7u86u5tvfsn: 6
# jlmateos: 199
# my_pochemuchka: 131
# er_chechi: 24
# recofunghi: 200
# olivierhoedeman: 200
# Agent_Jase: 200
# Vangel_artist: 200
# FoundationRMF: 200
# sarahncorry: 200
# 4A50CqwsQqeahlq: 0
# []
# syroter_: 23
# CriptodivisasMx: 198
# bginoc: 199
# TheRealShankar: 197
# SeloSlav: 200
# epathlo: 17
# AngelFe23124123: 9
# Oleatopia: 83
# prabprab: 200
# firth_john: 200
# GautierChauvin: 0
# []
# Frances11022994: 200
# lista_redes: 200
# FinexusCenter: 4
# [{'lang': 'en',
#   'text': 'Prof. Battiston will give a lecture on Contagion in Financial '
#           'Networks at the \n'
#           'Lake Como School 2018 on Complex Networks. Apply by Feb 18, 2018.\n'
#           '@zbattiz @barabasi @vcolizza @cosnet_bifi\n'
#           'https://t.co/6VDLCRfYD1 https://t.co/9levqy3LFl'},
#  {'lang': 'en',
#   'text': 'Prof. Battiston invites you to the 2nd @FinexusCenter Conference: '
#           '"Closing the Gaps between Financial Networks and  Sustainability" '
#           'on 17-19 January 2018 at the University of Zurich.  Register today: '
#           'https://t.co/KY5NPEe5CE  @zbattiz https://t.co/YwpY0ixANq'},
#  {'lang': 'en',
#   'text': 'Get your own Sustainable Business Corner @FinexusCenter Conference: '
#           'submit by Dec 15 to pitch your start-up idea or to showcase your '
#           'business in sustainable finance! Apply here: '
#           'https://t.co/MTo5XcGQBq   #dolfinsproject #sustainablefinance '
#           '@zbattiz @SimPolProject https://t.co/EG7KqX27ov'},
#  {'lang': 'en',
#   'text': 'Submit your abstract for a short presentation on Sustainable '
#           'Finance! We welcome your submission by December 15. Apply here: '
#           'https://t.co/MTo5XcGQBq  #dolfinsproject #sustainablefinance '
#           '@zbattiz @uzh_news_en @SimPolProject https://t.co/yY5ARuSJpA'}]
# mixalis_papako: 200
# Agn_ssa: 136
# Daimakaimura: 198
# futsofwelfare: 200
# BingoLittle1: 200
# forfinancewatch: 200
# EcologicalEcon: 200
# stephenkinsella: 200
# Adellibya1979: 142
# FredAmblard: 78
# nachoenblanco: 72
# ValerioVolpati: 6
# bitlumens: 200
# BoekeKatrin: 0
# ''
# StarwarsMaker: 29
# andrasonea: 200
# StephaneNappo: 0
# ''
# the_young_fdn: 200
# Thierry_Kame: 199
# ey0758: 0
# ''
# MikeOConnor3: 200
# avogli: 0
# ''
# edzaizvobwo: 184
# DELPHIBG: 200
# hamzaz: 190
# sees_lab: 200
# RebuildMacro: 200
# flaskn6: 200
# LucieKirstein: 15
# KoljaKleineberg: 200
# Paorazio: 200
# gary6115: 200
# MichaelRFerrari: 200
# DeboyJames21: 185
# NickJackson81: 73
# LetUsShineNow: 200
# multiplex_fet: 11
# ferminserrano: 200
# complex_warsaw: 113
# ricardo11701135: 23
# bergautier: 199
# LostInMath: 48
# JBPKGSolutions: 83
# kostasdimou5: 0
# []
# veronika_st5: 68
# AnneMur16630871: 200
# emacampiglio: 199
# Easyimpresa1: 17
# Better_Finance: 200
# LeanneUssher: 43
# renesugar: 200
# AsaBentley: 200
# enzomanzo1: 41
# yuliay: 199
# ayazarka88: 199
# MartinaOccelli: 117
# goodhartlaw: 199
# panchulzz: 0
# []
# netsci2017: 200
# bethscleft: 69
# resume_unilu: 200
# TagederSonne: 200
# JonathanEcon: 6
# marcoderrico: 0
# ''
# TMWFTE: 200
# CigeuInfo: 0
# ''
# Alex_GuerreroR: 200
# GiachiniDaniele: 110
# FETFX_EU: 200
# LuisaDeAmicis: 200
# brianla1: 196
# FabriceSabatier: 99
# __jasmy: 4
# [{'lang': 'en',
#   'text': 'RT @SimPolProject: How can we make #green #securitization safe? '
#           '@HLEG_Sus_Fin @pcanfin @EU_ENV @EUClimateAction @DSMeu @SustAbility '
#           'https://t.co/lkGHMSOd5U https://t.co/qWTYIErcHj'},
#  {'lang': 'en',
#   'text': 'RT @EU_Finance: Into Sustainable Finance? #SusFinEU🌿💶🇪🇺\n'
#           '📑Read @HLEG_Sus_Fin report https://t.co/4RmDBwx21p\n'
#           '📢Send your feedback! https://t.co/Z5KqNAn9DQ #ESG '
#           'https://t.co/EBuKribZn8'},
#  {'lang': 'en',
#   'text': 'RT @SimPolProject: we #DOLFINS @simpolproject support @HLEG_Sus_Fin '
#           'recommendation on capital requir. + climate stress-test '
#           'https://t.co/jVyFR46wCD  @FETFX_EU https://t.co/qiiDBSbinQ'},
#  {'lang': 'en',
#   'text': 'RT @SimPolProject: we support ambitious goals of @HLEG_Sus_Fin '
#           'report for  #sustainable #finance  @UNEP_FI @EIB @ECThinkTank\n'
#           'https://t.co/jVyFR46wCD https://t.co/2GY96uNv3r'}]
# marcobardoscia: 200
# schulte_stef: 200
# RitaMaria_dRC: 154
# sarresd8: 0
# ''
# iormazabali: 200
# NickBeglinger: 200
# Filipata__: 199
# WelfareUnited: 132
# ZofiaWemanska: 0
# []
# takis_kt: 200
# joostmulder: 200
# jiyanstorymovie: 12
# aleaf_h2020: 171
# laurettaeliana: 61
# FiramisCompany: 200
# Blueland1: 200
# Andrewbrum: 200
# Ika_Midenistis: 129
# JahelMielke: 98
# Project722TMX: 50
# manlius84: 200
# syaltout: 199
# LDNinst: 104
# stf18: 200
# dgpapanikas: 200
# impactvesting: 200
# brianehenyo: 200
# darden2032: 200
# AlanGIsaac: 200
# bellacindylee: 176
# miromarchi: 199
# laurasabatini3: 200
# rcabinte: 200
# alediemmee: 20
# jferretm: 197
# angelnunhez: 199
# gomezramirez_ac: 200
# carinacarinas: 200
# DustyTweak: 0
# []
# YannisDafermos: 65
# giacomo_rella: 4
# [{'lang': 'en',
#   'text': "RT @paulkrugman: Love for fascists isn't just for American "
#           'conservatives https://t.co/p7wgGWLUeX'},
#  {'lang': 'en',
#   'text': 'RT @Noahpinion: Political ideology prefix translation guide:\n'
#           '\n'
#           '"neo-X" = "kinda like X, but in a way we don\'t like"\n'
#           '\n'
#           '"alt-X" = "X, but spread by anonymous trolls"\n'
#           '\n'
#           '"post-X" = "X, but less respected"\n'
#           '\n'
#           '"crypto-X" = "stop pretending not to be X, you\'re not fooling '
#           'anyone"'},
#  {'lang': 'en',
#   'text': 'RT @fsaraceno: If you are interested in the debate on the future of '
#           'macro (I certainly am), here is a special issue of @OxrepJournal '
#           'that you should not miss. All articles are worth reading, and '
#           'discussing. Excellent job of the editors https://t.co/Vd6s3IFfSI'},
#  {'lang': 'en',
#   'text': 'Linear dynamic systems. Introduction Example of a complex dynamic '
#           'systemcomplex dynamic system. - ppt download '
#           'https://t.co/oxjuDqikf7'}]
# globalromance16: 200
# bdp_smith: 200
# PolatSihab: 110
# AEBIOM: 200
# tricks_y: 176
# alfonso_soldano: 4
# [{'lang': 'en',
#   'text': 'RT @DivineArtRecord: @alfonso_soldano “is a marvellous pianist and '
#           'the music seems to flow from his fingers like water.” (The '
#           'Chronicle) https://t.co/NMsAVkFXZ3 https://t.co/Gc2kCQFNKn'},
#  {'lang': 'en',
#   'text': 'RT @DivineArtRecord: Upcoming concerts from pianist '
#           '@alfonso_soldano incl recitals featuring works from his new '
#           'Castelnuovo-Tedesco album https://t.co/IFPuyh5FLe'},
#  {'lang': 'en', 'text': 'Soon!!! https://t.co/PaZS0Hdf3e'},
#  {'lang': 'en',
#   'text': "#Concert and #piano. Can't wait 15th September worldwide release of "
#           'Cd Castelnuovo-Tedesco Piano Works  @DivineArtRecord'}]
# SSEinitiative: 200
# CorneliaDaniel: 200
# KushyKush: 200
# strategypod: 200
# vijayakumarmad6: 1
# [{'lang': 'en',
#   'text': 'RT @XHNews: Craving for peace: Life gradually resuming its course '
#           'in towns west of #Damascus after rebel evacuation '
#           'https://t.co/a2b64u289y'}]
# goldthau: 200
# igor_mozetic: 127
# danilo_liuzzi: 27
# sartin: 200
# JacopoSestili: 198
# ngominhthanh4: 199
# ecozzo: 200
# RakibEnew: 198
# dsuker: 200
# TehRaio: 200
# energynewsnowtv: 200
# AdolfSanchez5: 200
# BusinessPartnrs: 200
# PetraKraljNovak: 33
# netsci15: 200
# lilitpopoyan: 178
# TorreyShine: 15
# sjnwoh: 200
# joaquimfialho19: 2
# [{'lang': 'en',
#   'text': 'DuckDuckGo is my search engine of choice. #ComeToTheDuckSide - we '
#           'have privacy. https://t.co/zOXYKQ2wJY'},
#  {'lang': 'pt',
#   'text': 'A independência de São Tomé segundo Tomás Medeiros '
#           'https://t.co/H1a3VI8SSe via @sharethis'}]
# Sebespejo: 196
# HNR_org: 200
# PatrikReisinger: 193
# kevinpuisieux: 16
# mm1112322234: 200
# giannismanidis1: 13
# grippt: 200
# Peveeeric1: 200
# duyennguyen286: 61
# e77876519af54a6: 132
# anewmediaprof: 200
# FightInequalit1: 198
# mallenbaker: 200
# LeadMakelaar: 200
# Blinis: 200
# eurohumph: 200
# zbattiz: 200
# Adeline_story: 0
# ''
# galeanojav: 200
# DeepestLearning: 12
# gagliol: 200
# jmblanch: 199
# rubene822: 0
# ''
# solarfornia: 12
# Beyond_Ratings: 200
# gzkbs: 24
# tozhs: 0
# ''
# vtchakarova: 200
# mvly3: 172
# GochaT69: 32
# CoeGSS: 199
# UB_ICS: 200
# Vibeka: 197
# _marameo_: 200
# FinforTomorrow: 200
# smalkina5e1: 38
# fabiofxvanni: 200
# IOPDAHKA: 0
# []
# GladiAAreise: 9
# MorganBeaugrand: 199
# PaoloBarucca: 199
# sergiocabrero: 200
# Registry_Blocks: 48
# ArcmorRib: 26
# Arturo311311311: 2
# [{'lang': 'es', 'text': 'Lugnet@sunday 2017 Enduro https://t.co/hrpfuAJrTB'},
#  {'lang': 'en', 'text': '@burtonsnowboard @EeeebElias Nice ! Flight'}]
# BUPardeeCenter: 200
# BsjgMMZetBPIHca: 94
# p_messages: 200
# PheasantEnergy: 200
# PSalazarO: 200
# joseph_sattler: 197
# dormiveglia: 51
# jordywos: 200
# SFL_nl: 200
# crie_ufrj: 168
# gbracci_des: 200
# SunilMalhotra: 200
# lperodabasioglu: 0
# []
# maggie_q_q: 0
# ''
# johnbirdswords: 200
# jviver: 187
# MacroPru: 200
# CarnesBestia: 16
# gerrad12456789: 6
# DecentralizedEn: 200
# f_bontadini: 192
# HamishJWyatt: 200
# envproceng: 40
# Gius_C: 71
# Pierre_Monnin: 200
# uzh_bf: 103
# tori_henry2: 1
# [{'lang': 'und', 'text': '#Newtwitternewme'}]
# joelcomm: 200
# n33dstfu: 10
# Gabriel_Hatem: 110
# shopwearblack: 31
# GeoVun: 72
# nicolerycroft1: 200
# jgliu626: 4
# [{'lang': 'en', 'text': '@POTUS you are great !'},
#  {'lang': 'und', 'text': '#NewProfilePic https://t.co/qPkXhpdqxA'},
#  {'lang': 'en', 'text': '@KwokMiles Who is Guan Jun?\nThank you very much!'},
#  {'lang': 'fr', 'text': 'Hello tous;\nje suis la au 05052012.'}]
# p_chiocchetti: 200
# Gianlucamisu: 200
# yanhua_yanhua7: 1
# [{'lang': 'en',
#   'text': 'RT @net_science: Voting Simulation based Agglomerative Hierarchical '
#           'Method for Network Community Detection https://t.co/OE7BoAKbq6'}]
# indy_johar: 200
# PatsonBibou1168: 186
# GuidoCaldarelli: 200
# Etp4H: 200
# AdamPC26: 199
# bulentozel: 81
# m_waeck: 93
# Helens60: 195
# plusvaluetweets: 200
# bonosverdes: 194
# destiny_dii: 200
# Nietzchrodinger: 200
# JoeRini6: 200
# alp08989139: 0
# []
# RubyBretislav: 200
# mercadomagico: 200
# TipGhosh: 200
# IMTipps: 200
# larryclane: 0
# ''
# Fede_Botta: 200
# palabresgroup: 76
# FabioCarrirolo: 200
# shanegibson: 200
# Sb4GvLAuBrNkc93: 0
# []
# Fet2Rin: 200
# MiaPhlor: 200
# pikosapikosgr: 200
# Asmmar1999: 2
# [{'lang': 'und', 'text': 'https://t.co/9BvbTvjH8u'},
#  {'lang': 'und', 'text': 'https://t.co/pludGNEmvf'}]
# FootnoteMedia: 200
# SodreLuciana: 200
# AlineCosette: 200
# BluewaterGlobe: 200
# NomosCSP: 200
# James_Vaccaro: 200
# AugustusSouto: 200
# moritszsz: 168
# CaroleCasuco: 200
# mnapoletano1: 200
# DimasSetyadi5: 146
# greenwinproject: 200
# heloisa58879287: 11
# ChristosEllina1: 200
# WarrenWhitlock: 200
# francrsci: 1
# [{'lang': 'it', 'text': 'Scopri in'}]
# johemart55: 200
# xavierhervas: 199
# REANworld: 199
# AlbertoMunoz: 200
# cosnet_bifi: 200
# DarkMatter_Labs: 200
# poesiaculina: 144
# valteraguiar654: 198
# Sandra_G_Urbano: 82
# aetw15: 200
# arthurturrell: 200
# giorgosvarzelio: 13
# karlape45: 200
# palpi643: 193
# tiveleva4ie: 34
# monicanagore: 200
# ByGeorgePerr: 200
# RockJimford: 200
# Concerns_You: 200
# jimodonnell2: 200
# LieveFransen: 200
# bobbyreyes20: 198
# ph_desfosses: 200
# bastidas_d: 195
# DougThorpe_com: 200
# TiberiuPetre: 0
# ''
# flipparini: 200
# dataforpolicy: 200
# giacomolivan: 153
# mennoliauw: 4
# [{'lang': 'nl',
#   'text': 'RT @EricHolterhues: In Amsterdam creëerden @pjotrdejong &amp; '
#           '@mennoliauw   @vandejong Springhouse gefinancierd door Triodos '
#           'Cultuurfonds  https://t.co/DPPrlswkPC'},
#  {'lang': 'en',
#   'text': 'RT @DSMeu: Want to make the most out of online engagement? Check '
#           'out the EU-supported project @mymeedia http://t.co/n3CGzilCqF '
#           '#h2020 #socialmedia'},
#  {'lang': 'nl',
#   'text': '@rvermin @mennoliauw De aanhouder wint! Vanavond was relaunch WR!! '
#           'Nu meer bottom up benadering.'},
#  {'lang': 'nl',
#   'text': 'RT @VanVelzenMusic: Kan de kracht van muziek bijdragen aan vrede? '
#           'Kijk morgen naar #MusicAboveFighting onze reis voor Masterpeace '
#           'naar Congo! Om 21u op Veronica'}]
# helloplanetmars: 200
# aebiondo: 106
# Monithon: 200
# CherryEnergy1: 199
# PEP4UM: 200
# SimPolProject: 200
# titarchukaj2s: 39
# ZoeGold69: 200
# Crypto20183: 121
# manuelhurt: 27
# economics_twitr: 3
# [{'lang': 'en',
#   'text': "RT @ProfNoto: @Undercoverhist I don't think that should be an "
#           'unpopular opinion! Here is what I was taught in grad school (taken '
#           "from David Autor's lecture notes https://t.co/gbTEz6k4qi) "
#           'https://t.co/dTlXBZKFKy'},
#  {'lang': 'en',
#   'text': 'RT @elliswonk: .@NinjaEconomics is suing some men in Silicon Valley '
#           'for some disturbing behavior and it’s about to go to trial. Read '
#           'about and support here =&gt; https://t.co/Vmx2gUSaHE'},
#  {'lang': 'en',
#   'text': '@AndreLorentz Are there slides or video of this somewhere?'}]
# FcoKienzle: 200
# claudia_mihai: 197
# andkarpf: 2
# [{'lang': 'en',
#   'text': 'RT @Rainmaker1973: This is an evergreen \n'
#           '#science #saturdayfun https://t.co/sotKTsur6M'},
#  {'lang': 'de',
#   'text': '@vpetritsch @brunepoirson @ElliKoestinger Das führt die Idee des '
#           'Emissionshandels, und die Entscheidung gegen CO2 Steuern, ad '
#           'absurdum. Bei der Allokation von Zertifikaten gehört nachgeschärft. '
#           'Da gibt es bekanntermaßen seit Jahren eine Überallokation.'}]
# barryejames: 200
# openp2pdesign: 200
# impaqt_io: 200
# Elcada_GmbH: 136
# godinfred: 90
# nalsrarekli: 199
# Pedromgi19: 0
# ''
# MPA37855265: 21
# BigDataStackEU: 34
# katausten: 200
# EmreYakr1: 199
# MariaMariliam23: 200
# SimulPast: 199
# pdjahnke: 176
# kosttttoziss: 200
# eleni_choidas: 200
# ilhanakbas: 199
# anxosan: 200
# fbonmatiB: 200
# bplisse: 81
# KleineBottleM: 1
# [{'lang': 'en',
#   'text': "If you love machine learning, you might have a look at a book I've "
#           'recently published https://t.co/mLcqqBG6Re #machinelearning'}]
# adria_plazas: 200
# MazzucatoM: 200

# %% [markdown]
# ### 4. Extracting and curating information from each follower's tweets

# %%
def has_info(data):
    for k,v in data.items():
        if v: return True
    return False
    
def curate_user(auser, curator, kw = True):
    fname = './output/tweets/' + auser +'.pickle'
    with open(fname, 'rb') as handle:
        tweets = pickle.load(handle)
    n = len(tweets)
    print('{}: {}'.format(auser,n))
    curated = curator.extract_info(tweets, kw)
    curated = [c for c in curated if has_info(c)]
    return n, curated

def curate_followers(followers, kw = True):
    """It proccesses and analyzes each follower's each tweets one by one.
    
    Note:
        Examining tweets one by one specifically to clean, tokenize and standardize and
        extract terms is relatively costly in terms of time.
    
    Args:
        followers (:obj:`set` of  :obj:`str`): A set of twitter account's screen names.
        kw (:obj:`bool`): When True extract terms of each tweets (default True).
    
    Returns:
        (:obj:`dict`): A JSON like collection of curated data.
            Each entry in the collection represents a curated twitter data.
    
    """
    curated = dict()
    mT = Tweets()
    for f in followers:
        n, data = curate_user(f, mT, kw)
        curated[f] = {'ntweets':n,'data':data}
    ofnamebase = './output/simpolproject_curated_new'
    fpickle = ofnamebase + '.pickle'
    fjson = ofnamebase + '.json'
    with open(fpickle, 'wb') as handle:
        pickle.dump(curated, handle, protocol=pickle.HIGHEST_PROTOCOL)
    #with open(fjson, 'w') as handle: json.dump(curated, handle)
    return curated

# %% [markdown]
# #### 4.1 Demo of curating a specific twitter account
# Note that only 'mentions' and 'rt_from' fields are listed below.

# %%
mT = Tweets()
acurated_account = curate_user('zbattiz', mT, kw=True)
# Out:
# The tweet extractor class is initiated with 0 tweets
# zbattiz: 200
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 25
# Cleaning process: Initial size of tokens = 25
# Reduction due to punctuations and stopwords = 9.
# Reduction due to all numeral terms = 2
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 11
# Percentage = 44%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 42
# Cleaning process: Initial size of tokens = 42
# Reduction due to punctuations and stopwords = 22.
# Reduction due to all numeral terms = 1
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 23
# Percentage = 55%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 10
# Cleaning process: Initial size of tokens = 10
# Reduction due to punctuations and stopwords = 5.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 5
# Percentage = 50%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 29
# Cleaning process: Initial size of tokens = 29
# Reduction due to punctuations and stopwords = 13.
# Reduction due to all numeral terms = 2
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 15
# Percentage = 52%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 33
# Cleaning process: Initial size of tokens = 33
# Reduction due to punctuations and stopwords = 18.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 18
# Percentage = 55%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 23
# Cleaning process: Initial size of tokens = 23
# Reduction due to punctuations and stopwords = 9.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 10
# Percentage = 43%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 34
# Cleaning process: Initial size of tokens = 34
# Reduction due to punctuations and stopwords = 15.
# Reduction due to all numeral terms = 2
# Reduction due to short terms = 2
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 19
# Percentage = 56%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 8
# Cleaning process: Initial size of tokens = 8
# Reduction due to punctuations and stopwords = 4.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 4
# Percentage = 50%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 6
# Cleaning process: Initial size of tokens = 6
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 2
# Percentage = 33%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 5
# Cleaning process: Initial size of tokens = 5
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 2
# Percentage = 40%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 12
# Cleaning process: Initial size of tokens = 12
# Reduction due to punctuations and stopwords = 6.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 6
# Percentage = 50%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 27
# Cleaning process: Initial size of tokens = 27
# Reduction due to punctuations and stopwords = 11.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 11
# Percentage = 41%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 31
# Cleaning process: Initial size of tokens = 31
# Reduction due to punctuations and stopwords = 16.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 17
# Percentage = 55%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 13
# Cleaning process: Initial size of tokens = 13
# Reduction due to punctuations and stopwords = 5.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 5
# Percentage = 38%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 10
# Cleaning process: Initial size of tokens = 10
# Reduction due to punctuations and stopwords = 6.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 7
# Percentage = 70%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 16
# Cleaning process: Initial size of tokens = 16
# Reduction due to punctuations and stopwords = 7.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 7
# Percentage = 44%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 2
# Cleaning process: Initial size of tokens = 2
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# Percentage = 0%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 37
# Cleaning process: Initial size of tokens = 37
# Reduction due to punctuations and stopwords = 20.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 21
# Percentage = 57%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 9
# Cleaning process: Initial size of tokens = 9
# Reduction due to punctuations and stopwords = 4.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 4
# Percentage = 44%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 19
# Cleaning process: Initial size of tokens = 19
# Reduction due to punctuations and stopwords = 9.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 9
# Percentage = 47%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 31
# Cleaning process: Initial size of tokens = 31
# Reduction due to punctuations and stopwords = 15.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 17
# Percentage = 55%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 26
# Cleaning process: Initial size of tokens = 26
# Reduction due to punctuations and stopwords = 11.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 11
# Percentage = 42%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 3
# Cleaning process: Initial size of tokens = 3
# Reduction due to punctuations and stopwords = 1.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 1
# Percentage = 33%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 33
# Cleaning process: Initial size of tokens = 33
# Reduction due to punctuations and stopwords = 16.
# Reduction due to all numeral terms = 1
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 17
# Percentage = 52%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 27
# Cleaning process: Initial size of tokens = 27
# Reduction due to punctuations and stopwords = 6.
# Reduction due to all numeral terms = 1
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 7
# Percentage = 26%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 33
# Cleaning process: Initial size of tokens = 33
# Reduction due to punctuations and stopwords = 8.
# Reduction due to all numeral terms = 1
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 9
# Percentage = 27%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 15
# Cleaning process: Initial size of tokens = 15
# Reduction due to punctuations and stopwords = 3.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 4
# Percentage = 27%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 15
# Cleaning process: Initial size of tokens = 15
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 3
# Percentage = 20%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 21
# Cleaning process: Initial size of tokens = 21
# Reduction due to punctuations and stopwords = 6.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 2
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 8
# Percentage = 38%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 15
# Cleaning process: Initial size of tokens = 15
# Reduction due to punctuations and stopwords = 4.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 5
# Percentage = 33%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 22
# Cleaning process: Initial size of tokens = 22
# Reduction due to punctuations and stopwords = 7.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 8
# Percentage = 36%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 44
# Cleaning process: Initial size of tokens = 44
# Reduction due to punctuations and stopwords = 18.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 18
# Percentage = 41%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 25
# Cleaning process: Initial size of tokens = 25
# Reduction due to punctuations and stopwords = 11.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 11
# Percentage = 44%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 20
# Cleaning process: Initial size of tokens = 20
# Reduction due to punctuations and stopwords = 7.
# Reduction due to all numeral terms = 1
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 8
# Percentage = 40%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 19
# Cleaning process: Initial size of tokens = 19
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 2
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 4
# Percentage = 21%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 25
# Cleaning process: Initial size of tokens = 25
# Reduction due to punctuations and stopwords = 11.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 12
# Percentage = 48%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# ...
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 15
# Cleaning process: Initial size of tokens = 15
# Reduction due to punctuations and stopwords = 5.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 6
# Percentage = 40%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 9
# Cleaning process: Initial size of tokens = 9
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 3
# Percentage = 33%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 15
# Cleaning process: Initial size of tokens = 15
# Reduction due to punctuations and stopwords = 2.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 3
# Percentage = 20%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 7
# Cleaning process: Initial size of tokens = 7
# Reduction due to punctuations and stopwords = 4.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 5
# Percentage = 71%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 6
# Cleaning process: Initial size of tokens = 6
# Reduction due to punctuations and stopwords = 1.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 1
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 2
# Percentage = 33%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 7
# Cleaning process: Initial size of tokens = 7
# Reduction due to punctuations and stopwords = 1.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 1
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 2
# Percentage = 29%
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.
# Configuring the text cleaner ...
# A single text is provided.
# Extracting the terms ...
# Tokenizing the input text ..
# Done. Number of terms: 0
# Cleaning process: Initial size of tokens = 0
# Reduction due to punctuations and stopwords = 0.
# Reduction due to all numeral terms = 0
# Reduction due to short terms = 0
# Reduction due to rare terms = 0
# Reduction due to partially numeral terms = 0
# Reduction due to terms with not allowed symbols = 0
# The total term count reduction during this cleaning process = 0
# COMPLETED.

# %%
type(acurated_account)
# Out:
# tuple

# %% [markdown]
# ##### Number of tweets found and curated:

# %%
acurated_account[0]
# Out:
# 200

# %%
len(acurated_account[1])
# Out:
# 200

# %% [markdown]
# ##### Fields of curated data

# %%
pp.pprint(acurated_account[1][42])
# Out:
# {'hashtags': {'networks'},
#  'keywords': {'dont',
#               'double',
#               'economics',
#               'everything',
#               'friday',
#               'miss',
#               'networks',
#               'talk',
#               'venice'},
#  'mentions': {'CaFoscari', 'GuidoCaldarelli'},
#  'rt': False,
#  'rt_from': set(),
#  'text': 'This Friday don‘t miss this double talk on „why #networks in '
#          'economics and everything“ at Venice'}

# %%
pp.pprint([{'Mentions':d['mentions'], 'Retweeted from':d['rt_from']} for d in acurated_account[1]])
# Out:
# [{'Mentions': set(), 'Retweeted from': {'vcolizza'}},
#  {'Mentions': set(), 'Retweeted from': {'jkbren'}},
#  {'Mentions': {'alainbarrat', 'netsci2018', 'NetSciPhDs', 'vcolizza', 'jkbren'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'forfinancewatch'}},
#  {'Mentions': set(), 'Retweeted from': {'ISIgrowth'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'NetSciPhDs'}},
#  {'Mentions': {'CEP',
#                'Frank_vanlerven',
#                'NEF',
#                'Pierre_Monnin',
#                'PositiveMoneyEU',
#                'PositiveMoneyUK',
#                'Sharpe_Actuary',
#                'Transitionway',
#                'forfinancewatch',
#                'jryancollins',
#                'lesliehook'},
#   'Retweeted from': set()},
#  {'Mentions': {'CEP',
#                'Frank_vanlerven',
#                'NEF',
#                'Pierre_Monnin',
#                'PositiveMoneyEU',
#                'PositiveMoneyUK',
#                'Sharpe_Actuary',
#                'Transitionway',
#                'forfinancewatch',
#                'jryancollins',
#                'lesliehook'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'CEPweb'}},
#  {'Mentions': set(), 'Retweeted from': {'forfinancewatch'}},
#  {'Mentions': set(), 'Retweeted from': {'CEPweb'}},
#  {'Mentions': {'CEP',
#                'Frank_vanlerven',
#                'NEF',
#                'PositiveMoneyEU',
#                'PositiveMoneyUK',
#                'Sharpe_Actuary',
#                'Transitionway',
#                'forfinancewatch',
#                'jryancollins',
#                'lesliehook'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Frank_vanlerven'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'SPRU'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'LiveSpinoza'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'NVJRobins1'}},
#  {'Mentions': set(), 'Retweeted from': {'emacampiglio'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'emacampiglio'}},
#  {'Mentions': {'AndreaRoventini',
#                'SimPolProject',
#                'Transitionway',
#                'emacampiglio',
#                'mnapoletano1'},
#   'Retweeted from': set()},
#  {'Mentions': {'AndreaRoventini',
#                'GuidoCaldarelli',
#                'Transitionway',
#                'mnapoletano1'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'andytuit'}},
#  {'Mentions': {'Transitionway', 'mnapoletano1', 'FT'}, 'Retweeted from': set()},
#  {'Mentions': {'Transitionway'}, 'Retweeted from': set()},
#  {'Mentions': {'Transitionway', 'PositiveMoneyEU', 'AndreaRoventini', 'eaepe'},
#   'Retweeted from': set()},
#  {'Mentions': {'AndreaRoventini',
#                'GuidoCaldarelli',
#                'Transitionway',
#                'mnapoletano1'},
#   'Retweeted from': set()},
#  {'Mentions': {'AndreaRoventini',
#                'GuidoCaldarelli',
#                'Transitionway',
#                'mnapoletano1'},
#   'Retweeted from': set()},
#  {'Mentions': {'Transitionway', 'PositiveMoneyEU', 'AndreaRoventini', 'eaepe'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'ISIgrowth'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'Transitionway', 'EcologicalEcon', 'eaepe', 'emacampiglio'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'CaFoscari', 'GuidoCaldarelli'}, 'Retweeted from': set()},
#  {'Mentions': {'GuidoCaldarelli‘s', 'CaFoscari.'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'CaFoscari', 'GuidoCaldarelli'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'eaepe'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Pierre_Monnin'}},
#  {'Mentions': set(), 'Retweeted from': {'cosnet_bifi'}},
#  {'Mentions': set(), 'Retweeted from': {'bbuchner13'}},
#  {'Mentions': {'NaturePhysics',
#                'NetSciPhDs',
#                'cosnet_bifi',
#                'fdlevi',
#                'netsci2018',
#                'sonia_kefi'},
#   'Retweeted from': set()},
#  {'Mentions': {'FT', 'acemaxx', '_Kate_Allen', 'ClimateBonds', 'seankidney'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'NetSciPhDs'}},
#  {'Mentions': {'Transitionway', 'justynakrol', 'SGHWarsaw', 'uzh_bf'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'justynakrol', 'hamzaz)?)', 'hamzaz'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'netsci2018'}},
#  {'Mentions': {'Transitionway', 'SGHWarsaw', 'COP24'}, 'Retweeted from': set()},
#  {'Mentions': {'Transitionway', 'SGHWarsaw', 'uzh_bf'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': {'EcologicalEcon',
#                'SUERF',
#                'Transitionway',
#                'emacampiglio',
#                'oenb'},
#   'Retweeted from': set()},
#  {'Mentions': {'EcologicalEcon',
#                'SUERF',
#                'Transitionway',
#                'emacampiglio',
#                'oenb'},
#   'Retweeted from': set()},
#  {'Mentions': {'EcologicalEcon',
#                'SUERF',
#                'Transitionway',
#                'emacampiglio',
#                'oenb'},
#   'Retweeted from': set()},
#  {'Mentions': {'EcologicalEcon',
#                'Pierre_Monnin',
#                'Transitionway',
#                'emacampiglio',
#                'oenb'},
#   'Retweeted from': set()},
#  {'Mentions': {'EcologicalEcon',
#                'HLEG_Sus_Fin',
#                'Transitionway',
#                'emacampiglio',
#                'oenb'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'EcologicalEcon'}},
#  {'Mentions': {'oenb', 'EcologicalEcon', 'Transitionway', 'emacampiglio'},
#   'Retweeted from': set()},
#  {'Mentions': {'oenb', 'jryancollins', 'EcologicalEcon', 'emacampiglio'},
#   'Retweeted from': set()},
#  {'Mentions': {'oenb', 'EcologicalEcon', 'emacampiglio'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'jryancollins'}},
#  {'Mentions': set(), 'Retweeted from': {'eaepe'}},
#  {'Mentions': {'GeorgeMonbiot'}, 'Retweeted from': set()},
#  {'Mentions': {'oenb', 'Transitionway', 'emacampiglio'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'plusvaluetweets'}},
#  {'Mentions': set(), 'Retweeted from': {'TheEconomist'}},
#  {'Mentions': set(), 'Retweeted from': {'BenLallemand'}},
#  {'Mentions': set(), 'Retweeted from': {'NVJRobins1'}},
#  {'Mentions': set(), 'Retweeted from': {'uzh_bf'}},
#  {'Mentions': {'wef'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'ecfin'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'BenLallemand'}},
#  {'Mentions': set(), 'Retweeted from': {'ISIgrowth'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'BenLallemand'}},
#  {'Mentions': set(), 'Retweeted from': {'veronika_st5'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'KR_MachineLearn'}},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'eaepe'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'filippoaddarii'}},
#  {'Mentions': {'FinexusCenter',
#                'RepRisk',
#                'RobecoSAM',
#                'SFGeneva',
#                'SriEvent',
#                'SwissSustFin'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'SriEvent'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': {'EmmanuelMacron', 'realDonaldTrump', 'theresa_may'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'CampanaleMark'}},
#  {'Mentions': set(), 'Retweeted from': {'GaelGiraud_AFD'}},
#  {'Mentions': set(), 'Retweeted from': {'Pierre_Monnin'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'SwissSustFin'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'alexvespi'}},
#  {'Mentions': set(), 'Retweeted from': {'BenLallemand'}},
#  {'Mentions': set(), 'Retweeted from': {'NVJRobins1'}},
#  {'Mentions': set(), 'Retweeted from': {'GuidoCaldarelli'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'FinexusCenter'}},
#  {'Mentions': {'Transitionway', 'SimPolProject', 'JosephEStiglitz'},
#   'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'alexvespi'}},
#  {'Mentions': set(), 'Retweeted from': {'cosnet_bifi'}},
#  {'Mentions': set(), 'Retweeted from': {'VDombrovskis'}},
#  {'Mentions': set(), 'Retweeted from': {'ISIgrowth'}},
#  {'Mentions': set(), 'Retweeted from': {'UNEP_FI'}},
#  {'Mentions': {'EU_Commission', 'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'forfinancewatch'}},
#  {'Mentions': set(), 'Retweeted from': {'IngridHolmes7'}},
#  {'Mentions': set(), 'Retweeted from': {'bplisse'}},
#  {'Mentions': set(), 'Retweeted from': {'Pierre_Monnin'}},
#  {'Mentions': set(), 'Retweeted from': {'bitlumens'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'ivcubic'}},
#  {'Mentions': set(), 'Retweeted from': {'adilson_motter'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'wef', 'bitlumens'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'cosnet_bifi'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'GuidoCaldarelli'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'GuidoCaldarelli', 'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'mnapoletano1', 'SimPolProject'}, 'Retweeted from': set()},
#  {'Mentions': {'mnapoletano1'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'LindaBach14'}},
#  {'Mentions': set(), 'Retweeted from': {'plusvaluetweets'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'RobPasqualino'}},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'fabiofxvanni'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SriEvent'}},
#  {'Mentions': set(), 'Retweeted from': {'monicanagore'}},
#  {'Mentions': set(), 'Retweeted from': {'monicanagore'}},
#  {'Mentions': set(), 'Retweeted from': {'Transitionway'}},
#  {'Mentions': set(), 'Retweeted from': {'forfinancewatch'}},
#  {'Mentions': set(), 'Retweeted from': {'filippoaddarii'}},
#  {'Mentions': set(), 'Retweeted from': {'plusvaluetweets'}},
#  {'Mentions': set(), 'Retweeted from': {'monicanagore'}},
#  {'Mentions': set(), 'Retweeted from': {'uzh_bf'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': {'Transitionway', 'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': {'simpolproject'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': {'_ChiaraPerillo'}, 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': set()},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'zbattiz'}},
#  {'Mentions': set(), 'Retweeted from': {'SriEvent'}},
#  {'Mentions': set(), 'Retweeted from': {'GuidoCaldarelli'}},
#  {'Mentions': set(), 'Retweeted from': {'SimPolProject'}},
#  {'Mentions': set(), 'Retweeted from': {'mnapoletano1'}}]

# %% [markdown]
# #### 4.2 Curating the tweets of each follower

# %%
# if keyword extraction is needed set kw to True
#curated = curate_followers(followers, kw = False)

# %% [markdown]
# #### Load from preveiously curated data.

# %%
fname = './output/simpolproject_curated_new.pickle'
with open(fname, 'rb') as handle:
        curated = pickle.load(handle)

# %%
#pp.pprint(curated)

# %%
curated['bulentozel'].keys()
# Out:
# dict_keys(['ntweets', 'data'])

# %%
curated['bulentozel']['ntweets'], len(curated['bulentozel']['data'])
# Out:
# (81, 80)

# %%
pp.pprint(curated['bulentozel']['data'])
# Out:
# [{'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'make your own smart phone.'},
#  {'hashtags': {'S'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#SözBarışın'},
#  {'hashtags': {'paradisepapers'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'After #paradisepapers, thousands are signing this open letter to '
#           'shut down these insane tax havens:'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': "Until we manage to avoid those tera-scale thefts there won't be any "
#           'political stability anywhere on this planet:'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Zizek a true zeitgeist discovers machine learning and free software '
#           'movement.'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'YouTube'},
#   'rt': False,
#   'rt_from': set(),
#   'text': '"How Elite Financial Networks Rule the World" via'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'OpenSUSE Leap 42.3 comes with packages for streaming, editing '
#           'graphics, creating animation, building 3D printing.'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'A sign of hope: Not coordinated but self-organized; participative '
#           'around a theme though bohemian yet hopeful.'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Culture of sharing:'},
#  {'hashtags': {'AnkaraKatliam'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#AnkaraKatliamı'},
#  {'hashtags': {'Bar'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#BarısKazanacak Bomba, silah, infaz, linç, tutuklama ve yalan haber '
#           'insanca ve baris icinde yaşama iradesine engel olamayacaktır.'},
#  {'hashtags': {'CanD'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#CanDündarYalnızDeğildir'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'YouTube'},
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Ayrık Otu - La Comida La Manana/Yavuz Geliyor (Akustik Performans): '
#           'via'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'RTE (\'cc\'): "Bizim rahmetimiz gazabamizi aşacaktır"'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"... Her iki taraf da Gezi’den ve temsil ettiklerinden, Kürt siyasi '
#           'gücünden, emekçiden, gençlikten, özgürlükten nefret ediyor."'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"Ne adalet duygusu ne imanın gücü; bölüşemedikleri rant, onları '
#           'birbirinden soğutan. Her iki taraf da Gezi’den ve temsil '
#           'ettiklerinden, .."'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'RustemBatum'},
#   'text': ''},
#  {'hashtags': {'DirenGezi'},
#   'keywords': set(),
#   'mentions': {'RT_Erdogan'},
#   'rt': False,
#   'rt_from': set(),
#   'text': 'bu bir rüyanın hikaye edilişi galiba?! Daha dün ölen başka bir '
#           'memleketin genci veya ben kötü bir kabustayım. #DirenGezi'},
#  {'hashtags': {'DirenTMMOB'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"bu hareketi organize etmekle suçlanıyorum. bu bir onurdur ve bu '
#           'uğurda müebbet bile yatarım ama halka haksızlık olur!" m.yapici '
#           '#DirenTMMOB'},
#  {'hashtags': {'Kiral'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"BENİM ADIM ETHEM SARISÜLÜK. ELİMDE SİLAH YOKTU. POLİS BENİ '
#           'BAŞIMDAN VURDU VE ÖLDÜM. KATİLİMİ SERBEST BIRAKTILAR" '
#           '#KiralıkKatilAHMETŞAHBAZ'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'Radyo1959'},
#   'text': ''},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'TheRedHack'},
#   'text': ''},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#direngezi kuklalastirilmis memlektte de guzel seyler oluyor'},
#  {'hashtags': {'direngezi', 'duranadam'},
#   'keywords': set(),
#   'mentions': {'TaksimDayanisma'},
#   'rt': False,
#   'rt_from': set(),
#   'text': '#duranadam #direngezi'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Suç işleme unsurlarından biri olarak prezervatif koydurtmayı '
#           'unutmuş, birileri #direngezi'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"There is always a well-known solution to every human '
#           'problem--neat, plausible, and wrong." H.L.Mencken'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'a centrally taken decisive action as common knowledge may propose '
#           '... #direngezi'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Taksim Square. He explains how certain thresholds would move people '
#           'but not #direngezi'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Wow! right now, I am at a conference and the speaker, Alan Kirman a '
#           'very well known economist is talking about the Revolution at '
#           '#direngezi'},
#  {'hashtags': {'durankadin'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '" -Ne duruyorsun burada? +Arkadaşımı bekliyorum. -Ne zaman gelecek? '
#           '+Bilmiyorum. -Adı ne arkadaşının? +Ethem Sarısülük." #durankadin'},
#  {'hashtags': {'duranadam'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"c&amp;p: -Ne duruyorsun burada? +Arkadaşımı bekliyorum. -Ne zaman '
#           'gelecek? +Bilmiyorum. -Adı ne arkadaşının? +Ethem Sarısülük." '
#           '#duranadam'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"c&amp;p: -Ne duruyorsun burada? +Arkadaşımı bekliyorum. -Ne zaman '
#           'gelecek? +Bilmiyorum. -Adı ne arkadaşının? +Ethem Sarısülük." '
#           '#direngezi'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'damladural'},
#   'text': ''},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#direngezi Trump Towers ikizlerini yerle yeksan edecek muhimmatlar'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': "#direngezi Gezi parkinin 'terorist'lerce ikame edildiginin ilk "
#           "'bulgular'"},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'TheRedHack'},
#   'text': ''},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'TheRedHack'},
#   'text': ''},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'TheRedHack'},
#   'text': ''},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '#direngezi'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Bir otel lobisine giren ve kask numarasi olmayan polisler. Bu bir '
#           'yasa ihlali #direngezi'},
#  {'hashtags': {'direngezi'},
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'İstanbul Barosu Kriz Masası Numaraları: 4445271 - 0212.2529516 - '
#           '0212.2529517 #direngezi gozalti, kayip ve benzeri her turlu hukuki '
#           'yardim.'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': True,
#   'rt_from': {'tugcetackin'},
#   'text': ''},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Time to disappear from Danube'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Liberal Gündelik İslam'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Melankolik Geyiklemeler'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Blues, Sigara ve The Doors'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'My Sunday 9am Coctail'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Getting Ready for a Cool Pose after May 1st Deminstration'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'ITL 504 - Ders Giriş'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Koop - Koop Island Blues'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Internetime Dokunma'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': "Internet'ime Dokunma"},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Yes We Ban!'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Taksim Square, May 1, 2011'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'The dance champion cup in Prague'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'DamlaSargut'},
#   'rt': False,
#   'rt_from': set(),
#   'text': "ya Neco ile konustum. Cafe'yi henuz acmamismis bu sezon :( bir "
#           'dahakine.'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'DamlaSargut'},
#   'rt': False,
#   'rt_from': set(),
#   'text': "Cafe 7'ye gidin bir dahakine ve Neco'ya selamimi soyleyin :)"},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'The Wizard of Oz - If I Only Had A Brain'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Hans Rosling: My new science and humanitarian hero!'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Zaytung - Evlilik Planları Yapan Genç Gazeteci, Ergenekon '
#           'Gözaltısı:'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'LibyanTNC'},
#   'rt': False,
#   'rt_from': set(),
#   'text': 'The libyan Interim Transitional National Council'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': {'LibyanTNC'},
#   'rt': False,
#   'rt_from': set(),
#   'text': 'the libyan Interim Transitional National Council'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Özeleştiri'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Cubita I - Her anı macera dolu Küba'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Dead Kennedys'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'and the mood changes ...'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Mood of the day: Neil Young - Love and War'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Bilgi Computer Science Live: Design Recipe in Action'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'my blue mood for the night: johnny, tom vs leonard (arabesk '
#           'haller)'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Jace Everett - Bad Things'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Mystery Jets - Young Love'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Mystery Jets - Young Love'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'ILHC 2010 - Classic Lindy - Mike Roberts & Laura Glaess'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'How to Design Programs 8.0 - Self-referential Data and Recursion'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Aheng-i Hengame, December 02, 2010, Acik Radyo'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'Aheng-i Hengame, November 24, 2010'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"there is only one truly philosophical question and that is '
#           'suicide…"'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': '"The purpose of computing is insight – not numbers." R. W. Hamming '
#           '(1962)'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'How does a network grows? How prevalent a preferential attachment '
#           'model?'},
#  {'hashtags': set(),
#   'keywords': set(),
#   'mentions': set(),
#   'rt': False,
#   'rt_from': set(),
#   'text': 'it is too late .. so there is nothing else left but opening a '
#           'twitter account!'}]

# %% [markdown]
# ### 5. Analysis

# %%
def count_links(connections):
    co = dict()
    for alist in connections:
        for a in alist:
            if a in co.keys():
                co[a] += 1
            else:
                co[a] = 1
    return co

def get_popularity(net):
    popularity = dict()
    for nodes in net.values():
        for node,weight in nodes.items():
            if node in popularity.keys():
                popularity[node] += weight
            else:
                popularity[node] = weight
    return popularity

def get_rt_ratios(curated):
    rt_ratios = dict()
    for a in curated.keys():
        nt = curated[a]['ntweets']
        nrt = sum([1 for d in curated[a]['data'] if d['rt']])
        ratio = nrt/nt if  nt else 0
        rt_ratios[a] = {'nTweet':nt,
                        'nRTweet':nrt,
                        'rDiffusion':ratio}
    return rt_ratios


def extract_relations(curated, linktype='mentions'):
    relations = dict()
    for a in curated.keys():
        links = [d[linktype] for d in curated[a]['data'] if d[linktype]]
        relations[a] = count_links(links)
    return relations

def select_subnet(net, nodes, isin = True):
    if isin:
        return {n:{m:w for m,w in links.items() if m in nodes} for n,links in net.items() if n in nodes}
    else:
        return {n:{m:w for m,w in links.items() if m not in nodes} for n,links in net.items() if n in nodes}
    
def drop_isolates(net):
    net = {n:{m:w for m,w in links.items() if m != n} for n,links in net.items()}
    isolates = [n for n,w in net.items() if not w]
    nonisolates = {n:w for n,w in net.items() if w}
    return nonisolates, isolates

def get_cohesion_ratios(net, nodes):
    cohesion = dict()
    for node,links in net.items():
        internal = sum([w for n,w in links.items() if n in nodes])
        external = sum([w for n,w in links.items() if n  not in nodes])
        total = internal + external
        cohesion[node] = {'in': internal,
                          'out': external,
                          'ratio': internal / total if total else 0
                         }
    return cohesion

# %% [markdown]
# #### 5.1 Analyzing retweet stats
#  - **nTweet** : Number of tweet from the follower were available (up to latest 200 was possible.)
#  - **nRTweet** : Number of retweets of those retrieved tweets.
#  - **RTweetDiffusion** : A simple information propagation measure. Here it is the ratio of the retweets to the tweets. *(1 - RTweetDiffusion)* could be interpreted as a information sourcing/originating behavioral measure.

# %%
RT_Stats = get_rt_ratios(curated)
pp.pprint(RT_Stats)
# Out:
# {'0ttamatt': {'nRTweet': 68, 'nTweet': 73, 'rDiffusion': 0.9315068493150684},
#  '2dipicchee': {'nRTweet': 156, 'nTweet': 192, 'rDiffusion': 0.8125},
#  '4A50CqwsQqeahlq': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  '7softley': {'nRTweet': 161, 'nTweet': 200, 'rDiffusion': 0.805},
#  '7wData': {'nRTweet': 132, 'nTweet': 200, 'rDiffusion': 0.66},
#  '85Fifteen': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'AEBIOM': {'nRTweet': 119, 'nTweet': 200, 'rDiffusion': 0.595},
#  'APRC_CF': {'nRTweet': 100, 'nTweet': 200, 'rDiffusion': 0.5},
#  'ARNAOYTHSD': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'AdaFerko': {'nRTweet': 56, 'nTweet': 200, 'rDiffusion': 0.28},
#  'AdamPC26': {'nRTweet': 107, 'nTweet': 199, 'rDiffusion': 0.5376884422110553},
#  'Adeline_story': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Adellibya1979': {'nRTweet': 123,
#                    'nTweet': 142,
#                    'rDiffusion': 0.8661971830985915},
#  'AdolfSanchez5': {'nRTweet': 153, 'nTweet': 200, 'rDiffusion': 0.765},
#  'Adoufrancois': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Agent_Jase': {'nRTweet': 45, 'nTweet': 200, 'rDiffusion': 0.225},
#  'Agn_ssa': {'nRTweet': 107, 'nTweet': 136, 'rDiffusion': 0.7867647058823529},
#  'AlanGIsaac': {'nRTweet': 46, 'nTweet': 200, 'rDiffusion': 0.23},
#  'AlbertoMunoz': {'nRTweet': 74, 'nTweet': 200, 'rDiffusion': 0.37},
#  'AldeiDiogo': {'nRTweet': 168,
#                 'nTweet': 176,
#                 'rDiffusion': 0.9545454545454546},
#  'AlessandroLaced': {'nRTweet': 100,
#                      'nTweet': 199,
#                      'rDiffusion': 0.5025125628140703},
#  'Alex_GuerreroR': {'nRTweet': 126, 'nTweet': 200, 'rDiffusion': 0.63},
#  'AlineCosette': {'nRTweet': 129, 'nTweet': 200, 'rDiffusion': 0.645},
#  'Amanuel40Rui': {'nRTweet': 199, 'nTweet': 200, 'rDiffusion': 0.995},
#  'AndreaBindo': {'nRTweet': 118, 'nTweet': 200, 'rDiffusion': 0.59},
#  'AndreaRoventini': {'nRTweet': 135, 'nTweet': 200, 'rDiffusion': 0.675},
#  'Andreas_Chile': {'nRTweet': 0, 'nTweet': 4, 'rDiffusion': 0.0},
#  'Andrewbrum': {'nRTweet': 2, 'nTweet': 200, 'rDiffusion': 0.01},
#  'AngelFe23124123': {'nRTweet': 0, 'nTweet': 9, 'rDiffusion': 0.0},
#  'Angela07261976': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'Anna_Hadorn': {'nRTweet': 12, 'nTweet': 14, 'rDiffusion': 0.8571428571428571},
#  'AnneMur16630871': {'nRTweet': 8, 'nTweet': 200, 'rDiffusion': 0.04},
#  'AppDeveloperHue': {'nRTweet': 50,
#                      'nTweet': 172,
#                      'rDiffusion': 0.29069767441860467},
#  'ArcmorRib': {'nRTweet': 0, 'nTweet': 26, 'rDiffusion': 0.0},
#  'ArnautzPgvila': {'nRTweet': 161, 'nTweet': 200, 'rDiffusion': 0.805},
#  'Arturo311311311': {'nRTweet': 0, 'nTweet': 2, 'rDiffusion': 0.0},
#  'AsaBentley': {'nRTweet': 93, 'nTweet': 200, 'rDiffusion': 0.465},
#  'Asmmar1999': {'nRTweet': 0, 'nTweet': 2, 'rDiffusion': 0.0},
#  'AugustusSouto': {'nRTweet': 181, 'nTweet': 200, 'rDiffusion': 0.905},
#  'BIntendente': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'BUPardeeCenter': {'nRTweet': 138, 'nTweet': 200, 'rDiffusion': 0.69},
#  'Barone54924381': {'nRTweet': 41,
#                     'nTweet': 197,
#                     'rDiffusion': 0.20812182741116753},
#  'BenitoMma': {'nRTweet': 28, 'nTweet': 172, 'rDiffusion': 0.16279069767441862},
#  'Benmccreton1': {'nRTweet': 13, 'nTweet': 200, 'rDiffusion': 0.065},
#  'Better_Finance': {'nRTweet': 128, 'nTweet': 200, 'rDiffusion': 0.64},
#  'Beyond_Ratings': {'nRTweet': 19, 'nTweet': 200, 'rDiffusion': 0.095},
#  'Bifrostonline': {'nRTweet': 104, 'nTweet': 200, 'rDiffusion': 0.52},
#  'BigDataStackEU': {'nRTweet': 0, 'nTweet': 34, 'rDiffusion': 0.0},
#  'BingoLittle1': {'nRTweet': 174, 'nTweet': 200, 'rDiffusion': 0.87},
#  'BlacMambaMMA': {'nRTweet': 143,
#                   'nTweet': 192,
#                   'rDiffusion': 0.7447916666666666},
#  'Blinis': {'nRTweet': 41, 'nTweet': 200, 'rDiffusion': 0.205},
#  'Blueland1': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'BluewaterGlobe': {'nRTweet': 101, 'nTweet': 200, 'rDiffusion': 0.505},
#  'BoekeKatrin': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'BradZarnett': {'nRTweet': 51, 'nTweet': 200, 'rDiffusion': 0.255},
#  'BrainConceptual': {'nRTweet': 2,
#                      'nTweet': 52,
#                      'rDiffusion': 0.038461538461538464},
#  'BsjgMMZetBPIHca': {'nRTweet': 0, 'nTweet': 94, 'rDiffusion': 0.0},
#  'BusinessPartnrs': {'nRTweet': 9, 'nTweet': 200, 'rDiffusion': 0.045},
#  'ByGeorgePerr': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'CASAPUEBLO8': {'nRTweet': 10,
#                  'nTweet': 79,
#                  'rDiffusion': 0.12658227848101267},
#  'CCL_Aus': {'nRTweet': 55, 'nTweet': 200, 'rDiffusion': 0.275},
#  'CGraciaLazaro': {'nRTweet': 142, 'nTweet': 200, 'rDiffusion': 0.71},
#  'CMCSatBU': {'nRTweet': 43, 'nTweet': 200, 'rDiffusion': 0.215},
#  'CT_Coughlin': {'nRTweet': 173, 'nTweet': 200, 'rDiffusion': 0.865},
#  'CanddyShawn': {'nRTweet': 20,
#                  'nTweet': 199,
#                  'rDiffusion': 0.10050251256281408},
#  'CanvasVC': {'nRTweet': 143, 'nTweet': 200, 'rDiffusion': 0.715},
#  'CardanIOTeam': {'nRTweet': 15, 'nTweet': 30, 'rDiffusion': 0.5},
#  'CardanoStiftung': {'nRTweet': 42,
#                      'nTweet': 199,
#                      'rDiffusion': 0.21105527638190955},
#  'CarnesBestia': {'nRTweet': 1, 'nTweet': 16, 'rDiffusion': 0.0625},
#  'CaroleCasuco': {'nRTweet': 123, 'nTweet': 200, 'rDiffusion': 0.615},
#  'CasaEdelVicenza': {'nRTweet': 12, 'nTweet': 24, 'rDiffusion': 0.5},
#  'Casinos95': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Caydennash2': {'nRTweet': 18,
#                  'nTweet': 127,
#                  'rDiffusion': 0.14173228346456693},
#  'CherryEnergy1': {'nRTweet': 88,
#                    'nTweet': 199,
#                    'rDiffusion': 0.44221105527638194},
#  'ChrisGGeorgas': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'ChrisHudgins5': {'nRTweet': 174, 'nTweet': 192, 'rDiffusion': 0.90625},
#  'ChristosEllina1': {'nRTweet': 158, 'nTweet': 200, 'rDiffusion': 0.79},
#  'CigeuInfo': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Climate_Friend': {'nRTweet': 46, 'nTweet': 200, 'rDiffusion': 0.23},
#  'CoeGSS': {'nRTweet': 140, 'nTweet': 199, 'rDiffusion': 0.7035175879396985},
#  'Complexity_Labs': {'nRTweet': 17, 'nTweet': 200, 'rDiffusion': 0.085},
#  'Concerns_You': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'CorneliaDaniel': {'nRTweet': 65, 'nTweet': 200, 'rDiffusion': 0.325},
#  'CriptodivisasMx': {'nRTweet': 190,
#                      'nTweet': 198,
#                      'rDiffusion': 0.9595959595959596},
#  'Crypto20183': {'nRTweet': 87, 'nTweet': 121, 'rDiffusion': 0.71900826446281},
#  'CyprusInno': {'nRTweet': 30, 'nTweet': 200, 'rDiffusion': 0.15},
#  'DELPHIBG': {'nRTweet': 2, 'nTweet': 200, 'rDiffusion': 0.01},
#  'D_young_69': {'nRTweet': 95, 'nTweet': 200, 'rDiffusion': 0.475},
#  'Daimakaimura': {'nRTweet': 190,
#                   'nTweet': 198,
#                   'rDiffusion': 0.9595959595959596},
#  'DarkMatter_Labs': {'nRTweet': 107, 'nTweet': 200, 'rDiffusion': 0.535},
#  'DatingCH': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'DeboyJames21': {'nRTweet': 89,
#                   'nTweet': 185,
#                   'rDiffusion': 0.4810810810810811},
#  'DecentralizedEn': {'nRTweet': 142, 'nTweet': 200, 'rDiffusion': 0.71},
#  'DeepestLearning': {'nRTweet': 0, 'nTweet': 12, 'rDiffusion': 0.0},
#  'Demon666Yt': {'nRTweet': 1, 'nTweet': 32, 'rDiffusion': 0.03125},
#  'DiabetesDaisy': {'nRTweet': 87, 'nTweet': 200, 'rDiffusion': 0.435},
#  'DimasSetyadi5': {'nRTweet': 144,
#                    'nTweet': 146,
#                    'rDiffusion': 0.9863013698630136},
#  'DinoFiorita': {'nRTweet': 18,
#                  'nTweet': 199,
#                  'rDiffusion': 0.09045226130653267},
#  'DistributedNRG': {'nRTweet': 156, 'nTweet': 200, 'rDiffusion': 0.78},
#  'DougThorpe_com': {'nRTweet': 38, 'nTweet': 200, 'rDiffusion': 0.19},
#  'DrDrossosDem': {'nRTweet': 175, 'nTweet': 200, 'rDiffusion': 0.875},
#  'Drideologie': {'nRTweet': 3, 'nTweet': 200, 'rDiffusion': 0.015},
#  'DucThiLuu': {'nRTweet': 35, 'nTweet': 48, 'rDiffusion': 0.7291666666666666},
#  'Duph_Berg': {'nRTweet': 199, 'nTweet': 199, 'rDiffusion': 1.0},
#  'DustyTweak': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'EERwtUeb7HgG8pf': {'nRTweet': 38,
#                      'nTweet': 132,
#                      'rDiffusion': 0.2878787878787879},
#  'EHillBrody': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'EarthWatt': {'nRTweet': 28, 'nTweet': 198, 'rDiffusion': 0.1414141414141414},
#  'Easyimpresa1': {'nRTweet': 4,
#                   'nTweet': 17,
#                   'rDiffusion': 0.23529411764705882},
#  'EcologicalEcon': {'nRTweet': 55, 'nTweet': 200, 'rDiffusion': 0.275},
#  'Eindhoven60': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'Elcada_GmbH': {'nRTweet': 0, 'nTweet': 136, 'rDiffusion': 0.0},
#  'EmreYakr1': {'nRTweet': 19, 'nTweet': 199, 'rDiffusion': 0.09547738693467336},
#  'EnviroNews': {'nRTweet': 98,
#                 'nTweet': 199,
#                 'rDiffusion': 0.49246231155778897},
#  'Etp4H': {'nRTweet': 114, 'nTweet': 200, 'rDiffusion': 0.57},
#  'EuroLuckyStars': {'nRTweet': 1, 'nTweet': 1, 'rDiffusion': 1.0},
#  'FETFX_EU': {'nRTweet': 92, 'nTweet': 200, 'rDiffusion': 0.46},
#  'FETFlagships': {'nRTweet': 174, 'nTweet': 200, 'rDiffusion': 0.87},
#  'FabioCarrirolo': {'nRTweet': 156, 'nTweet': 200, 'rDiffusion': 0.78},
#  'FabriceSabatier': {'nRTweet': 51,
#                      'nTweet': 99,
#                      'rDiffusion': 0.5151515151515151},
#  'Falco810': {'nRTweet': 14, 'nTweet': 200, 'rDiffusion': 0.07},
#  'FcoKienzle': {'nRTweet': 57, 'nTweet': 200, 'rDiffusion': 0.285},
#  'Fede_Botta': {'nRTweet': 149, 'nTweet': 200, 'rDiffusion': 0.745},
#  'Fet2Rin': {'nRTweet': 65, 'nTweet': 200, 'rDiffusion': 0.325},
#  'FightInequalit1': {'nRTweet': 159,
#                      'nTweet': 198,
#                      'rDiffusion': 0.803030303030303},
#  'Filipata__': {'nRTweet': 95,
#                 'nTweet': 199,
#                 'rDiffusion': 0.47738693467336685},
#  'FinexusCenter': {'nRTweet': 0, 'nTweet': 4, 'rDiffusion': 0.0},
#  'FinforTomorrow': {'nRTweet': 64, 'nTweet': 200, 'rDiffusion': 0.32},
#  'FiramisCompany': {'nRTweet': 148, 'nTweet': 200, 'rDiffusion': 0.74},
#  'FootnoteMedia': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'FoundationRMF': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'Frances11022994': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'FranciscoICMC': {'nRTweet': 134,
#                    'nTweet': 199,
#                    'rDiffusion': 0.6733668341708543},
#  'FredAmblard': {'nRTweet': 68, 'nTweet': 78, 'rDiffusion': 0.8717948717948718},
#  'FutSciNow': {'nRTweet': 178, 'nTweet': 194, 'rDiffusion': 0.9175257731958762},
#  'GECoalition': {'nRTweet': 72, 'nTweet': 200, 'rDiffusion': 0.36},
#  'Gabriel_Hatem': {'nRTweet': 3,
#                    'nTweet': 110,
#                    'rDiffusion': 0.02727272727272727},
#  'GautierChauvin': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'GeoVun': {'nRTweet': 30, 'nTweet': 72, 'rDiffusion': 0.4166666666666667},
#  'GiachiniDaniele': {'nRTweet': 110, 'nTweet': 110, 'rDiffusion': 1.0},
#  'Gianlucamisu': {'nRTweet': 144, 'nTweet': 200, 'rDiffusion': 0.72},
#  'Gius_C': {'nRTweet': 63, 'nTweet': 71, 'rDiffusion': 0.8873239436619719},
#  'GladiAAreise': {'nRTweet': 4, 'nTweet': 9, 'rDiffusion': 0.4444444444444444},
#  'GochaT69': {'nRTweet': 12, 'nTweet': 32, 'rDiffusion': 0.375},
#  'GuidoCaldarelli': {'nRTweet': 129, 'nTweet': 200, 'rDiffusion': 0.645},
#  'HNR_org': {'nRTweet': 53, 'nTweet': 200, 'rDiffusion': 0.265},
#  'HamishJWyatt': {'nRTweet': 115, 'nTweet': 200, 'rDiffusion': 0.575},
#  'HanKitcher': {'nRTweet': 18, 'nTweet': 200, 'rDiffusion': 0.09},
#  'HelenJackson0': {'nRTweet': 47, 'nTweet': 200, 'rDiffusion': 0.235},
#  'Helens60': {'nRTweet': 120, 'nTweet': 195, 'rDiffusion': 0.6153846153846154},
#  'HyacintheBuiss1': {'nRTweet': 186, 'nTweet': 200, 'rDiffusion': 0.93},
#  'IASS_DOLFINS': {'nRTweet': 83, 'nTweet': 125, 'rDiffusion': 0.664},
#  'IASS_Potsdam': {'nRTweet': 112, 'nTweet': 200, 'rDiffusion': 0.56},
#  'IBSEN_H2020': {'nRTweet': 168, 'nTweet': 200, 'rDiffusion': 0.84},
#  'IET_online': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'IMPACT_EV': {'nRTweet': 75, 'nTweet': 199, 'rDiffusion': 0.3768844221105528},
#  'IMTipps': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'IOPDAHKA': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'ISEEORG': {'nRTweet': 9, 'nTweet': 200, 'rDiffusion': 0.045},
#  'ISI_Fondazione': {'nRTweet': 154, 'nTweet': 200, 'rDiffusion': 0.77},
#  'ISIgrowth': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65},
#  'Igorsemenoff': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'Ika_Midenistis': {'nRTweet': 46,
#                     'nTweet': 129,
#                     'rDiffusion': 0.35658914728682173},
#  'ImpactShapers': {'nRTweet': 18,
#                    'nTweet': 67,
#                    'rDiffusion': 0.26865671641791045},
#  'Inova_Paciente': {'nRTweet': 11,
#                     'nTweet': 99,
#                     'rDiffusion': 0.1111111111111111},
#  'JBPKGSolutions': {'nRTweet': 59,
#                     'nTweet': 83,
#                     'rDiffusion': 0.7108433734939759},
#  'JFernandoGRE': {'nRTweet': 122, 'nTweet': 200, 'rDiffusion': 0.61},
#  'JacopoSestili': {'nRTweet': 145,
#                    'nTweet': 198,
#                    'rDiffusion': 0.7323232323232324},
#  'JahelMielke': {'nRTweet': 70, 'nTweet': 98, 'rDiffusion': 0.7142857142857143},
#  'James_Vaccaro': {'nRTweet': 92, 'nTweet': 200, 'rDiffusion': 0.46},
#  'JeromeRoch74': {'nRTweet': 149, 'nTweet': 200, 'rDiffusion': 0.745},
#  'JoeRini6': {'nRTweet': 28, 'nTweet': 200, 'rDiffusion': 0.14},
#  'JofreCarnicer': {'nRTweet': 135, 'nTweet': 200, 'rDiffusion': 0.675},
#  'JonathanEcon': {'nRTweet': 0, 'nTweet': 6, 'rDiffusion': 0.0},
#  'JulienHallak': {'nRTweet': 142,
#                   'nTweet': 174,
#                   'rDiffusion': 0.8160919540229885},
#  'KerrieMengersen': {'nRTweet': 91, 'nTweet': 200, 'rDiffusion': 0.455},
#  'KimMarln': {'nRTweet': 138, 'nTweet': 200, 'rDiffusion': 0.69},
#  'KleineBottleM': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'KoljaKleineberg': {'nRTweet': 158, 'nTweet': 200, 'rDiffusion': 0.79},
#  'KushyKush': {'nRTweet': 28, 'nTweet': 200, 'rDiffusion': 0.14},
#  'LDNinst': {'nRTweet': 36, 'nTweet': 104, 'rDiffusion': 0.34615384615384615},
#  'LERUnews': {'nRTweet': 181, 'nTweet': 200, 'rDiffusion': 0.905},
#  'L__Macfarlane': {'nRTweet': 131, 'nTweet': 200, 'rDiffusion': 0.655},
#  'LeadMakelaar': {'nRTweet': 7, 'nTweet': 200, 'rDiffusion': 0.035},
#  'LeanneUssher': {'nRTweet': 6,
#                   'nTweet': 43,
#                   'rDiffusion': 0.13953488372093023},
#  'LetUsShineNow': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'LetsWorkHappy': {'nRTweet': 60, 'nTweet': 200, 'rDiffusion': 0.3},
#  'LieveFransen': {'nRTweet': 125, 'nTweet': 200, 'rDiffusion': 0.625},
#  'LindaBach14': {'nRTweet': 63, 'nTweet': 85, 'rDiffusion': 0.7411764705882353},
#  'Lori_McNeill': {'nRTweet': 120, 'nTweet': 200, 'rDiffusion': 0.6},
#  'LostInMath': {'nRTweet': 18, 'nTweet': 48, 'rDiffusion': 0.375},
#  'Louisbarla': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Lsuttors': {'nRTweet': 148, 'nTweet': 200, 'rDiffusion': 0.74},
#  'LucieKirstein': {'nRTweet': 9, 'nTweet': 15, 'rDiffusion': 0.6},
#  'LuisaDeAmicis': {'nRTweet': 156, 'nTweet': 200, 'rDiffusion': 0.78},
#  'LyndaMansson': {'nRTweet': 113,
#                   'nTweet': 199,
#                   'rDiffusion': 0.5678391959798995},
#  'MARGA_GLEZ_FDEZ': {'nRTweet': 151, 'nTweet': 200, 'rDiffusion': 0.755},
#  'MARIASOLOMONID2': {'nRTweet': 23,
#                      'nTweet': 140,
#                      'rDiffusion': 0.16428571428571428},
#  'MBMConsultancy': {'nRTweet': 7, 'nTweet': 200, 'rDiffusion': 0.035},
#  'MPA37855265': {'nRTweet': 2, 'nTweet': 21, 'rDiffusion': 0.09523809523809523},
#  'MacroPru': {'nRTweet': 82, 'nTweet': 200, 'rDiffusion': 0.41},
#  'Mahfuz__Rahman': {'nRTweet': 60,
#                     'nTweet': 197,
#                     'rDiffusion': 0.30456852791878175},
#  'MariaBejaCosta1': {'nRTweet': 4,
#                      'nTweet': 157,
#                      'rDiffusion': 0.025477707006369428},
#  'MariaMariliam23': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'Marji84': {'nRTweet': 103, 'nTweet': 200, 'rDiffusion': 0.515},
#  'MarlonMasine': {'nRTweet': 54,
#                   'nTweet': 106,
#                   'rDiffusion': 0.5094339622641509},
#  'MartaCalderaro': {'nRTweet': 187, 'nTweet': 200, 'rDiffusion': 0.935},
#  'MartinaOccelli': {'nRTweet': 52,
#                     'nTweet': 117,
#                     'rDiffusion': 0.4444444444444444},
#  'Mattia_Guerini': {'nRTweet': 177, 'nTweet': 200, 'rDiffusion': 0.885},
#  'Maxknew': {'nRTweet': 54, 'nTweet': 199, 'rDiffusion': 0.271356783919598},
#  'MazzucatoM': {'nRTweet': 135, 'nTweet': 200, 'rDiffusion': 0.675},
#  'MiaPhlor': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'MichaelRFerrari': {'nRTweet': 134, 'nTweet': 200, 'rDiffusion': 0.67},
#  'MichellLiberty': {'nRTweet': 192, 'nTweet': 192, 'rDiffusion': 1.0},
#  'MiguelBasire': {'nRTweet': 148,
#                   'nTweet': 199,
#                   'rDiffusion': 0.7437185929648241},
#  'MikeOConnor3': {'nRTweet': 177, 'nTweet': 200, 'rDiffusion': 0.885},
#  'MitchDOPEcom': {'nRTweet': 0, 'nTweet': 14, 'rDiffusion': 0.0},
#  'Mlopezforero': {'nRTweet': 83,
#                   'nTweet': 117,
#                   'rDiffusion': 0.7094017094017094},
#  'MolinariMax_': {'nRTweet': 44, 'nTweet': 200, 'rDiffusion': 0.22},
#  'MoneyWAmission': {'nRTweet': 14, 'nTweet': 200, 'rDiffusion': 0.07},
#  'Monithon': {'nRTweet': 186, 'nTweet': 200, 'rDiffusion': 0.93},
#  'MorganBeaugrand': {'nRTweet': 193,
#                      'nTweet': 199,
#                      'rDiffusion': 0.9698492462311558},
#  'NectuntLab': {'nRTweet': 57, 'nTweet': 57, 'rDiffusion': 1.0},
#  'NgulunguT': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'NickBeglinger': {'nRTweet': 56, 'nTweet': 200, 'rDiffusion': 0.28},
#  'NickJackson81': {'nRTweet': 36,
#                    'nTweet': 73,
#                    'rDiffusion': 0.4931506849315068},
#  'Nietzchrodinger': {'nRTweet': 124, 'nTweet': 200, 'rDiffusion': 0.62},
#  'NomosCSP': {'nRTweet': 10, 'nTweet': 200, 'rDiffusion': 0.05},
#  'OVESCO': {'nRTweet': 102, 'nTweet': 200, 'rDiffusion': 0.51},
#  'Oleatopia': {'nRTweet': 0, 'nTweet': 83, 'rDiffusion': 0.0},
#  'OlgaBuchholz': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'OneClickSolar': {'nRTweet': 36,
#                    'nTweet': 188,
#                    'rDiffusion': 0.19148936170212766},
#  'OnePlanetParis': {'nRTweet': 72,
#                     'nTweet': 184,
#                     'rDiffusion': 0.391304347826087},
#  'OrpheusEU': {'nRTweet': 11, 'nTweet': 200, 'rDiffusion': 0.055},
#  'PEP4UM': {'nRTweet': 3, 'nTweet': 200, 'rDiffusion': 0.015},
#  'PPFEnergia': {'nRTweet': 8, 'nTweet': 199, 'rDiffusion': 0.04020100502512563},
#  'PSalazarO': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'PaoloBarucca': {'nRTweet': 106,
#                   'nTweet': 199,
#                   'rDiffusion': 0.5326633165829145},
#  'Paorazio': {'nRTweet': 45, 'nTweet': 200, 'rDiffusion': 0.225},
#  'PatrikReisinger': {'nRTweet': 34,
#                      'nTweet': 193,
#                      'rDiffusion': 0.17616580310880828},
#  'PatsonBibou1168': {'nRTweet': 186, 'nTweet': 186, 'rDiffusion': 1.0},
#  'Pedromgi19': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'PetraKraljNovak': {'nRTweet': 19,
#                      'nTweet': 33,
#                      'rDiffusion': 0.5757575757575758},
#  'Peveeeric1': {'nRTweet': 138, 'nTweet': 200, 'rDiffusion': 0.69},
#  'PheasantEnergy': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'Phil5571': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'PhillipNunnUK': {'nRTweet': 19, 'nTweet': 200, 'rDiffusion': 0.095},
#  'PhysScala': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Pierre_Monnin': {'nRTweet': 113, 'nTweet': 200, 'rDiffusion': 0.565},
#  'Platy_Kalamatas': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'PolatSihab': {'nRTweet': 63, 'nTweet': 110, 'rDiffusion': 0.5727272727272728},
#  'PolicyCompassEU': {'nRTweet': 104,
#                      'nTweet': 199,
#                      'rDiffusion': 0.5226130653266332},
#  'Project722TMX': {'nRTweet': 23, 'nTweet': 50, 'rDiffusion': 0.46},
#  'PubAffairsEU': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'REANworld': {'nRTweet': 10, 'nTweet': 199, 'rDiffusion': 0.05025125628140704},
#  'RFIFoundation': {'nRTweet': 73, 'nTweet': 200, 'rDiffusion': 0.365},
#  'RRytenband': {'nRTweet': 49, 'nTweet': 200, 'rDiffusion': 0.245},
#  'RakibEnew': {'nRTweet': 91, 'nTweet': 198, 'rDiffusion': 0.4595959595959596},
#  'RebuildMacro': {'nRTweet': 157, 'nTweet': 200, 'rDiffusion': 0.785},
#  'Registry_Blocks': {'nRTweet': 3, 'nTweet': 48, 'rDiffusion': 0.0625},
#  'RitaMaria_dRC': {'nRTweet': 104,
#                    'nTweet': 154,
#                    'rDiffusion': 0.6753246753246753},
#  'RobPasqualino': {'nRTweet': 30,
#                    'nTweet': 58,
#                    'rDiffusion': 0.5172413793103449},
#  'RoccaBam': {'nRTweet': 0, 'nTweet': 2, 'rDiffusion': 0.0},
#  'RockJimford': {'nRTweet': 132, 'nTweet': 200, 'rDiffusion': 0.66},
#  'RogerCremades': {'nRTweet': 184, 'nTweet': 200, 'rDiffusion': 0.92},
#  'RogervEijk': {'nRTweet': 15,
#                 'nTweet': 119,
#                 'rDiffusion': 0.12605042016806722},
#  'RothcoPepp': {'nRTweet': 40, 'nTweet': 200, 'rDiffusion': 0.2},
#  'RubyBretislav': {'nRTweet': 16, 'nTweet': 200, 'rDiffusion': 0.08},
#  'SFL_nl': {'nRTweet': 76, 'nTweet': 200, 'rDiffusion': 0.38},
#  'SICommunity_EU': {'nRTweet': 153, 'nTweet': 200, 'rDiffusion': 0.765},
#  'SSEinitiative': {'nRTweet': 64, 'nTweet': 200, 'rDiffusion': 0.32},
#  'SUPERTWIN_H2020': {'nRTweet': 3,
#                      'nTweet': 73,
#                      'rDiffusion': 0.0410958904109589},
#  'Sandra_G_Urbano': {'nRTweet': 51,
#                      'nTweet': 82,
#                      'rDiffusion': 0.6219512195121951},
#  'Saracris95': {'nRTweet': 65,
#                 'nTweet': 199,
#                 'rDiffusion': 0.32663316582914576},
#  'Sb4GvLAuBrNkc93': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Schumannpoet': {'nRTweet': 6,
#                   'nTweet': 89,
#                   'rDiffusion': 0.06741573033707865},
#  'Seavangelesse': {'nRTweet': 134, 'nTweet': 200, 'rDiffusion': 0.67},
#  'Sebespejo': {'nRTweet': 67, 'nTweet': 196, 'rDiffusion': 0.34183673469387754},
#  'SelinaStoller': {'nRTweet': 33, 'nTweet': 200, 'rDiffusion': 0.165},
#  'SeloSlav': {'nRTweet': 31, 'nTweet': 200, 'rDiffusion': 0.155},
#  'ShaunFrankson': {'nRTweet': 180, 'nTweet': 200, 'rDiffusion': 0.9},
#  'SiQuizas': {'nRTweet': 132, 'nTweet': 199, 'rDiffusion': 0.6633165829145728},
#  'SimPolProject': {'nRTweet': 165, 'nTweet': 200, 'rDiffusion': 0.825},
#  'SimonThordal': {'nRTweet': 20,
#                   'nTweet': 42,
#                   'rDiffusion': 0.47619047619047616},
#  'SimulPast': {'nRTweet': 182, 'nTweet': 199, 'rDiffusion': 0.914572864321608},
#  'SodreLuciana': {'nRTweet': 8, 'nTweet': 200, 'rDiffusion': 0.04},
#  'StarwarsMaker': {'nRTweet': 10,
#                    'nTweet': 29,
#                    'rDiffusion': 0.3448275862068966},
#  'StephaneNappo': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'StieberHarald': {'nRTweet': 15,
#                    'nTweet': 37,
#                    'rDiffusion': 0.40540540540540543},
#  'SunilMalhotra': {'nRTweet': 56, 'nTweet': 200, 'rDiffusion': 0.28},
#  'SusFinLab': {'nRTweet': 166, 'nTweet': 199, 'rDiffusion': 0.8341708542713567},
#  'SusieMod88': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'SvyatoslavHrync': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'SwissCognitive': {'nRTweet': 2, 'nTweet': 200, 'rDiffusion': 0.01},
#  'TMWFTE': {'nRTweet': 52, 'nTweet': 200, 'rDiffusion': 0.26},
#  'TSERETELI_0102': {'nRTweet': 9,
#                     'nTweet': 22,
#                     'rDiffusion': 0.4090909090909091},
#  'TagederSonne': {'nRTweet': 107, 'nTweet': 200, 'rDiffusion': 0.535},
#  'TehRaio': {'nRTweet': 21, 'nTweet': 200, 'rDiffusion': 0.105},
#  'TheRealShankar': {'nRTweet': 182,
#                     'nTweet': 197,
#                     'rDiffusion': 0.9238578680203046},
#  'Thierry_Kame': {'nRTweet': 199, 'nTweet': 199, 'rDiffusion': 1.0},
#  'TiberiuPetre': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'TipGhosh': {'nRTweet': 89, 'nTweet': 200, 'rDiffusion': 0.445},
#  'TomasBalint': {'nRTweet': 158, 'nTweet': 200, 'rDiffusion': 0.79},
#  'TorreyShine': {'nRTweet': 0, 'nTweet': 15, 'rDiffusion': 0.0},
#  'Transitionway': {'nRTweet': 75, 'nTweet': 200, 'rDiffusion': 0.375},
#  'UB_ICS': {'nRTweet': 80, 'nTweet': 200, 'rDiffusion': 0.4},
#  'UNEP_FI': {'nRTweet': 69, 'nTweet': 200, 'rDiffusion': 0.345},
#  'ValerioVolpati': {'nRTweet': 5,
#                     'nTweet': 6,
#                     'rDiffusion': 0.8333333333333334},
#  'Vangel_artist': {'nRTweet': 186, 'nTweet': 200, 'rDiffusion': 0.93},
#  'VeronicaClima': {'nRTweet': 139, 'nTweet': 200, 'rDiffusion': 0.695},
#  'Vibeka': {'nRTweet': 137, 'nTweet': 197, 'rDiffusion': 0.6954314720812182},
#  'VilmaBerta17': {'nRTweet': 175,
#                   'nTweet': 197,
#                   'rDiffusion': 0.8883248730964467},
#  'VivereLanzarote': {'nRTweet': 121,
#                      'nTweet': 190,
#                      'rDiffusion': 0.6368421052631579},
#  'VlPetrovV': {'nRTweet': 80, 'nTweet': 193, 'rDiffusion': 0.41450777202072536},
#  'WJFTechnical': {'nRTweet': 23, 'nTweet': 200, 'rDiffusion': 0.115},
#  'WOETUK': {'nRTweet': 1, 'nTweet': 23, 'rDiffusion': 0.043478260869565216},
#  'WRIClimate': {'nRTweet': 50, 'nTweet': 200, 'rDiffusion': 0.25},
#  'WarrenWhitlock': {'nRTweet': 18, 'nTweet': 200, 'rDiffusion': 0.09},
#  'WelfareUnited': {'nRTweet': 68,
#                    'nTweet': 132,
#                    'rDiffusion': 0.5151515151515151},
#  'WiedmannBibel': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'Xilbshi': {'nRTweet': 119, 'nTweet': 185, 'rDiffusion': 0.6432432432432432},
#  'YannisDafermos': {'nRTweet': 55,
#                     'nTweet': 65,
#                     'rDiffusion': 0.8461538461538461},
#  'ZeGordon': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'Zen3dT': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'ZhengIsabelle': {'nRTweet': 41, 'nTweet': 41, 'rDiffusion': 1.0},
#  'ZoeGold69': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'ZofiaWemanska': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  '_ChiaraPerillo': {'nRTweet': 46,
#                     'nTweet': 47,
#                     'rDiffusion': 0.9787234042553191},
#  '_NicoFrey': {'nRTweet': 144, 'nTweet': 200, 'rDiffusion': 0.72},
#  '__jasmy': {'nRTweet': 4, 'nTweet': 4, 'rDiffusion': 1.0},
#  '_ch3m': {'nRTweet': 155, 'nTweet': 199, 'rDiffusion': 0.7788944723618091},
#  '_marameo_': {'nRTweet': 166, 'nTweet': 200, 'rDiffusion': 0.83},
#  '_ndrd_': {'nRTweet': 20, 'nTweet': 37, 'rDiffusion': 0.5405405405405406},
#  'a_yang_w': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'adilson_motter': {'nRTweet': 17,
#                     'nTweet': 143,
#                     'rDiffusion': 0.11888111888111888},
#  'adria_plazas': {'nRTweet': 6, 'nTweet': 200, 'rDiffusion': 0.03},
#  'aebiondo': {'nRTweet': 97, 'nTweet': 106, 'rDiffusion': 0.9150943396226415},
#  'aetw15': {'nRTweet': 199, 'nTweet': 200, 'rDiffusion': 0.995},
#  'afrochia': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'agabardo': {'nRTweet': 18, 'nTweet': 199, 'rDiffusion': 0.09045226130653267},
#  'ailatan1898': {'nRTweet': 50, 'nTweet': 69, 'rDiffusion': 0.7246376811594203},
#  'ale_marichela': {'nRTweet': 114, 'nTweet': 200, 'rDiffusion': 0.57},
#  'aleaf_h2020': {'nRTweet': 64,
#                  'nTweet': 171,
#                  'rDiffusion': 0.3742690058479532},
#  'alediemmee': {'nRTweet': 4, 'nTweet': 20, 'rDiffusion': 0.2},
#  'alfonso_soldano': {'nRTweet': 2, 'nTweet': 4, 'rDiffusion': 0.5},
#  'alp08989139': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'alvarofenomeno': {'nRTweet': 148,
#                     'nTweet': 195,
#                     'rDiffusion': 0.7589743589743589},
#  'amanahramadiah': {'nRTweet': 99, 'nTweet': 200, 'rDiffusion': 0.495},
#  'amapr1': {'nRTweet': 0, 'nTweet': 45, 'rDiffusion': 0.0},
#  'ambatellova8u9': {'nRTweet': 0, 'nTweet': 24, 'rDiffusion': 0.0},
#  'amritasaha': {'nRTweet': 81, 'nTweet': 200, 'rDiffusion': 0.405},
#  'amsterdam_bill': {'nRTweet': 52, 'nTweet': 200, 'rDiffusion': 0.26},
#  'anaishannah': {'nRTweet': 90, 'nTweet': 200, 'rDiffusion': 0.45},
#  'andkarpf': {'nRTweet': 1, 'nTweet': 2, 'rDiffusion': 0.5},
#  'andrasonea': {'nRTweet': 163, 'nTweet': 200, 'rDiffusion': 0.815},
#  'anduviera': {'nRTweet': 177, 'nTweet': 200, 'rDiffusion': 0.885},
#  'anewmediaprof': {'nRTweet': 22, 'nTweet': 200, 'rDiffusion': 0.11},
#  'angelnunhez': {'nRTweet': 91, 'nTweet': 199, 'rDiffusion': 0.457286432160804},
#  'anhvan_dz': {'nRTweet': 15, 'nTweet': 23, 'rDiffusion': 0.6521739130434783},
#  'anielloiorio197': {'nRTweet': 100, 'nTweet': 200, 'rDiffusion': 0.5},
#  'anima_tu': {'nRTweet': 3, 'nTweet': 200, 'rDiffusion': 0.015},
#  'anxosan': {'nRTweet': 170, 'nTweet': 200, 'rDiffusion': 0.85},
#  'aparpau': {'nRTweet': 42, 'nTweet': 200, 'rDiffusion': 0.21},
#  'arthurturrell': {'nRTweet': 131, 'nTweet': 200, 'rDiffusion': 0.655},
#  'asgeirbt': {'nRTweet': 116, 'nTweet': 199, 'rDiffusion': 0.5829145728643216},
#  'aurorab96124853': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'avogli': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'axekoukou': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'ayazarka88': {'nRTweet': 141,
#                 'nTweet': 199,
#                 'rDiffusion': 0.7085427135678392},
#  'aymeric_vie': {'nRTweet': 198, 'nTweet': 200, 'rDiffusion': 0.99},
#  'bandigsm': {'nRTweet': 28, 'nTweet': 36, 'rDiffusion': 0.7777777777777778},
#  'barcomerni': {'nRTweet': 59, 'nTweet': 200, 'rDiffusion': 0.295},
#  'barryejames': {'nRTweet': 48, 'nTweet': 200, 'rDiffusion': 0.24},
#  'baryshnevadn0': {'nRTweet': 0, 'nTweet': 30, 'rDiffusion': 0.0},
#  'bassindales': {'nRTweet': 65, 'nTweet': 200, 'rDiffusion': 0.325},
#  'bastidas_d': {'nRTweet': 118,
#                 'nTweet': 195,
#                 'rDiffusion': 0.6051282051282051},
#  'bb_pedromartins': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'bdp_smith': {'nRTweet': 87, 'nTweet': 200, 'rDiffusion': 0.435},
#  'bellacindylee': {'nRTweet': 17,
#                    'nTweet': 176,
#                    'rDiffusion': 0.09659090909090909},
#  'bergautier': {'nRTweet': 99,
#                 'nTweet': 199,
#                 'rDiffusion': 0.49748743718592964},
#  'bethscleft': {'nRTweet': 16, 'nTweet': 69, 'rDiffusion': 0.2318840579710145},
#  'bginoc': {'nRTweet': 19, 'nTweet': 199, 'rDiffusion': 0.09547738693467336},
#  'bh7u86u5tvfsn': {'nRTweet': 0, 'nTweet': 6, 'rDiffusion': 0.0},
#  'bitlumens': {'nRTweet': 43, 'nTweet': 200, 'rDiffusion': 0.215},
#  'bobbyreyes20': {'nRTweet': 40,
#                   'nTweet': 198,
#                   'rDiffusion': 0.20202020202020202},
#  'bonosverdes': {'nRTweet': 90,
#                  'nTweet': 194,
#                  'rDiffusion': 0.4639175257731959},
#  'bplisse': {'nRTweet': 71, 'nTweet': 81, 'rDiffusion': 0.8765432098765432},
#  'brianehenyo': {'nRTweet': 55, 'nTweet': 200, 'rDiffusion': 0.275},
#  'brianla1': {'nRTweet': 112, 'nTweet': 196, 'rDiffusion': 0.5714285714285714},
#  'brjmoez': {'nRTweet': 145, 'nTweet': 200, 'rDiffusion': 0.725},
#  'bulentozel': {'nRTweet': 8, 'nTweet': 81, 'rDiffusion': 0.09876543209876543},
#  'burrolahola': {'nRTweet': 89, 'nTweet': 200, 'rDiffusion': 0.445},
#  'camilleoudinot': {'nRTweet': 30, 'nTweet': 200, 'rDiffusion': 0.15},
#  'carinacarinas': {'nRTweet': 149, 'nTweet': 200, 'rDiffusion': 0.745},
#  'carnadani': {'nRTweet': 82, 'nTweet': 82, 'rDiffusion': 1.0},
#  'cbbagsic': {'nRTweet': 178, 'nTweet': 200, 'rDiffusion': 0.89},
#  'chrizau': {'nRTweet': 42, 'nTweet': 200, 'rDiffusion': 0.21},
#  'ciro': {'nRTweet': 172, 'nTweet': 200, 'rDiffusion': 0.86},
#  'claudia_mihai': {'nRTweet': 39,
#                    'nTweet': 197,
#                    'rDiffusion': 0.19796954314720813},
#  'complex_warsaw': {'nRTweet': 27,
#                     'nTweet': 113,
#                     'rDiffusion': 0.23893805309734514},
#  'coonchi14': {'nRTweet': 14, 'nTweet': 14, 'rDiffusion': 1.0},
#  'cosnet_bifi': {'nRTweet': 135, 'nTweet': 200, 'rDiffusion': 0.675},
#  'crie_ufrj': {'nRTweet': 39, 'nTweet': 168, 'rDiffusion': 0.23214285714285715},
#  'daniel_eth': {'nRTweet': 6, 'nTweet': 200, 'rDiffusion': 0.03},
#  'daniel_goldsmth': {'nRTweet': 34, 'nTweet': 200, 'rDiffusion': 0.17},
#  'danilo_liuzzi': {'nRTweet': 14,
#                    'nTweet': 27,
#                    'rDiffusion': 0.5185185185185185},
#  'danilushkinaed1': {'nRTweet': 0, 'nTweet': 25, 'rDiffusion': 0.0},
#  'darden2032': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'dariomarmo_lama': {'nRTweet': 164, 'nTweet': 200, 'rDiffusion': 0.82},
#  'darko_darkoa': {'nRTweet': 10,
#                   'nTweet': 15,
#                   'rDiffusion': 0.6666666666666666},
#  'dataforpolicy': {'nRTweet': 127, 'nTweet': 200, 'rDiffusion': 0.635},
#  'davidecellai': {'nRTweet': 172, 'nTweet': 200, 'rDiffusion': 0.86},
#  'destiny_dii': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'dgpapanikas': {'nRTweet': 75, 'nTweet': 200, 'rDiffusion': 0.375},
#  'dindjic': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'dlacalle_IA': {'nRTweet': 68, 'nTweet': 200, 'rDiffusion': 0.34},
#  'dormiveglia': {'nRTweet': 11,
#                  'nTweet': 51,
#                  'rDiffusion': 0.21568627450980393},
#  'dpcwiseman': {'nRTweet': 160, 'nTweet': 200, 'rDiffusion': 0.8},
#  'dsuker': {'nRTweet': 49, 'nTweet': 200, 'rDiffusion': 0.245},
#  'duyennguyen286': {'nRTweet': 27,
#                     'nTweet': 61,
#                     'rDiffusion': 0.4426229508196721},
#  'e77876519af54a6': {'nRTweet': 100,
#                      'nTweet': 132,
#                      'rDiffusion': 0.7575757575757576},
#  'economics_twitr': {'nRTweet': 2,
#                      'nTweet': 3,
#                      'rDiffusion': 0.6666666666666666},
#  'ecozzo': {'nRTweet': 164, 'nTweet': 200, 'rDiffusion': 0.82},
#  'edzaizvobwo': {'nRTweet': 25,
#                  'nTweet': 184,
#                  'rDiffusion': 0.1358695652173913},
#  'egbr916': {'nRTweet': 195, 'nTweet': 200, 'rDiffusion': 0.975},
#  'eleni_choidas': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65},
#  'elifgunduzyeli': {'nRTweet': 149, 'nTweet': 200, 'rDiffusion': 0.745},
#  'elisa_letizia': {'nRTweet': 28,
#                    'nTweet': 36,
#                    'rDiffusion': 0.7777777777777778},
#  'elisa_omodei': {'nRTweet': 116, 'nTweet': 200, 'rDiffusion': 0.58},
#  'emacampiglio': {'nRTweet': 96,
#                   'nTweet': 199,
#                   'rDiffusion': 0.4824120603015075},
#  'emergir_co': {'nRTweet': 43, 'nTweet': 164, 'rDiffusion': 0.2621951219512195},
#  'energynewsnowtv': {'nRTweet': 83, 'nTweet': 200, 'rDiffusion': 0.415},
#  'envproceng': {'nRTweet': 0, 'nTweet': 40, 'rDiffusion': 0.0},
#  'enzomanzo1': {'nRTweet': 25, 'nTweet': 41, 'rDiffusion': 0.6097560975609756},
#  'epathlo': {'nRTweet': 0, 'nTweet': 17, 'rDiffusion': 0.0},
#  'er_chechi': {'nRTweet': 24, 'nTweet': 24, 'rDiffusion': 1.0},
#  'eric_vanpraag': {'nRTweet': 190, 'nTweet': 200, 'rDiffusion': 0.95},
#  'eswissolar': {'nRTweet': 4, 'nTweet': 58, 'rDiffusion': 0.06896551724137931},
#  'eurohumph': {'nRTweet': 106, 'nTweet': 200, 'rDiffusion': 0.53},
#  'ey0758': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'f_bontadini': {'nRTweet': 177, 'nTweet': 192, 'rDiffusion': 0.921875},
#  'fabiofxvanni': {'nRTweet': 32, 'nTweet': 200, 'rDiffusion': 0.16},
#  'fbonmatiB': {'nRTweet': 187, 'nTweet': 200, 'rDiffusion': 0.935},
#  'feducaydesarrol': {'nRTweet': 78, 'nTweet': 200, 'rDiffusion': 0.39},
#  'ferminserrano': {'nRTweet': 48, 'nTweet': 200, 'rDiffusion': 0.24},
#  'fet_eu': {'nRTweet': 90, 'nTweet': 200, 'rDiffusion': 0.45},
#  'filevaig41': {'nRTweet': 0, 'nTweet': 34, 'rDiffusion': 0.0},
#  'filipe2747': {'nRTweet': 102, 'nTweet': 200, 'rDiffusion': 0.51},
#  'filippoaddarii': {'nRTweet': 119, 'nTweet': 200, 'rDiffusion': 0.595},
#  'firth_john': {'nRTweet': 139, 'nTweet': 200, 'rDiffusion': 0.695},
#  'flaskn6': {'nRTweet': 31, 'nTweet': 200, 'rDiffusion': 0.155},
#  'flipparini': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65},
#  'forfinancewatch': {'nRTweet': 105, 'nTweet': 200, 'rDiffusion': 0.525},
#  'fotinipolichro': {'nRTweet': 0, 'nTweet': 4, 'rDiffusion': 0.0},
#  'francrsci': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'fun_rich': {'nRTweet': 49, 'nTweet': 200, 'rDiffusion': 0.245},
#  'futsofwelfare': {'nRTweet': 152, 'nTweet': 200, 'rDiffusion': 0.76},
#  'gagliol': {'nRTweet': 143, 'nTweet': 200, 'rDiffusion': 0.715},
#  'galeanojav': {'nRTweet': 166, 'nTweet': 200, 'rDiffusion': 0.83},
#  'gary6115': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'gbracci_des': {'nRTweet': 58, 'nTweet': 200, 'rDiffusion': 0.29},
#  'georguensberg': {'nRTweet': 58, 'nTweet': 200, 'rDiffusion': 0.29},
#  'georsara11': {'nRTweet': 20, 'nTweet': 64, 'rDiffusion': 0.3125},
#  'germanacanzi': {'nRTweet': 141, 'nTweet': 200, 'rDiffusion': 0.705},
#  'gerrad12456789': {'nRTweet': 0, 'nTweet': 6, 'rDiffusion': 0.0},
#  'giacomo_rella': {'nRTweet': 3, 'nTweet': 4, 'rDiffusion': 0.75},
#  'giacomolivan': {'nRTweet': 44,
#                   'nTweet': 153,
#                   'rDiffusion': 0.2875816993464052},
#  'giannismanidis1': {'nRTweet': 1,
#                      'nTweet': 13,
#                      'rDiffusion': 0.07692307692307693},
#  'gilologi': {'nRTweet': 40, 'nTweet': 200, 'rDiffusion': 0.2},
#  'giorgosvarzelio': {'nRTweet': 0, 'nTweet': 13, 'rDiffusion': 0.0},
#  'giuliaporino': {'nRTweet': 6, 'nTweet': 11, 'rDiffusion': 0.5454545454545454},
#  'globalromance16': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'godinfred': {'nRTweet': 17, 'nTweet': 90, 'rDiffusion': 0.18888888888888888},
#  'goldthau': {'nRTweet': 55, 'nTweet': 200, 'rDiffusion': 0.275},
#  'gomezramirez_ac': {'nRTweet': 43, 'nTweet': 200, 'rDiffusion': 0.215},
#  'goodhartlaw': {'nRTweet': 192,
#                  'nTweet': 199,
#                  'rDiffusion': 0.964824120603015},
#  'greenblut_kris': {'nRTweet': 10, 'nTweet': 200, 'rDiffusion': 0.05},
#  'greencareersorg': {'nRTweet': 186,
#                      'nTweet': 199,
#                      'rDiffusion': 0.9346733668341709},
#  'greenetworksco': {'nRTweet': 27, 'nTweet': 200, 'rDiffusion': 0.135},
#  'greenwinproject': {'nRTweet': 128, 'nTweet': 200, 'rDiffusion': 0.64},
#  'grippt': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'guyyeomans': {'nRTweet': 2, 'nTweet': 200, 'rDiffusion': 0.01},
#  'gzkbs': {'nRTweet': 24, 'nTweet': 24, 'rDiffusion': 1.0},
#  'hamzaz': {'nRTweet': 100, 'nTweet': 190, 'rDiffusion': 0.5263157894736842},
#  'hans_taeubler': {'nRTweet': 49, 'nTweet': 200, 'rDiffusion': 0.245},
#  'harshalhayat': {'nRTweet': 165, 'nTweet': 200, 'rDiffusion': 0.825},
#  'helloplanetmars': {'nRTweet': 197, 'nTweet': 200, 'rDiffusion': 0.985},
#  'heloisa58879287': {'nRTweet': 0, 'nTweet': 11, 'rDiffusion': 0.0},
#  'hjybuptster': {'nRTweet': 99,
#                  'nTweet': 194,
#                  'rDiffusion': 0.5103092783505154},
#  'hsissom': {'nRTweet': 0, 'nTweet': 69, 'rDiffusion': 0.0},
#  'huumanhlc1980': {'nRTweet': 149, 'nTweet': 200, 'rDiffusion': 0.745},
#  'i_anag': {'nRTweet': 30, 'nTweet': 46, 'rDiffusion': 0.6521739130434783},
#  'iacobet79': {'nRTweet': 0, 'nTweet': 10, 'rDiffusion': 0.0},
#  'ideeverdi': {'nRTweet': 4, 'nTweet': 6, 'rDiffusion': 0.6666666666666666},
#  'igor_mozetic': {'nRTweet': 123,
#                   'nTweet': 127,
#                   'rDiffusion': 0.968503937007874},
#  'ilhanakbas': {'nRTweet': 131,
#                 'nTweet': 199,
#                 'rDiffusion': 0.6582914572864321},
#  'imleslahdin': {'nRTweet': 22, 'nTweet': 200, 'rDiffusion': 0.11},
#  'impactdottech': {'nRTweet': 111,
#                    'nTweet': 193,
#                    'rDiffusion': 0.5751295336787565},
#  'impactvesting': {'nRTweet': 6, 'nTweet': 200, 'rDiffusion': 0.03},
#  'impaqt_io': {'nRTweet': 9, 'nTweet': 200, 'rDiffusion': 0.045},
#  'imsumitchouhan': {'nRTweet': 159, 'nTweet': 200, 'rDiffusion': 0.795},
#  'indy_johar': {'nRTweet': 180, 'nTweet': 200, 'rDiffusion': 0.9},
#  'iormazabali': {'nRTweet': 186, 'nTweet': 200, 'rDiffusion': 0.93},
#  'ivan8848': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65},
#  'ivancitocostasm': {'nRTweet': 5,
#                      'nTweet': 11,
#                      'rDiffusion': 0.45454545454545453},
#  'jarekkla': {'nRTweet': 1, 'nTweet': 1, 'rDiffusion': 1.0},
#  'jferretm': {'nRTweet': 157, 'nTweet': 197, 'rDiffusion': 0.7969543147208121},
#  'jgliu626': {'nRTweet': 0, 'nTweet': 4, 'rDiffusion': 0.0},
#  'jimodonnell2': {'nRTweet': 97, 'nTweet': 200, 'rDiffusion': 0.485},
#  'jiyanstorymovie': {'nRTweet': 0, 'nTweet': 12, 'rDiffusion': 0.0},
#  'jkpaulin': {'nRTweet': 60, 'nTweet': 200, 'rDiffusion': 0.3},
#  'jlmateos': {'nRTweet': 135, 'nTweet': 199, 'rDiffusion': 0.678391959798995},
#  'jmblanch': {'nRTweet': 189, 'nTweet': 199, 'rDiffusion': 0.949748743718593},
#  'jnode': {'nRTweet': 83, 'nTweet': 199, 'rDiffusion': 0.41708542713567837},
#  'joaquimfialho19': {'nRTweet': 0, 'nTweet': 2, 'rDiffusion': 0.0},
#  'joelcomm': {'nRTweet': 21, 'nTweet': 200, 'rDiffusion': 0.105},
#  'johemart55': {'nRTweet': 170, 'nTweet': 200, 'rDiffusion': 0.85},
#  'johnbirdswords': {'nRTweet': 86, 'nTweet': 200, 'rDiffusion': 0.43},
#  'joostmulder': {'nRTweet': 35, 'nTweet': 200, 'rDiffusion': 0.175},
#  'jordywos': {'nRTweet': 6, 'nTweet': 200, 'rDiffusion': 0.03},
#  'joseph_sattler': {'nRTweet': 158,
#                     'nTweet': 197,
#                     'rDiffusion': 0.8020304568527918},
#  'juancerdap': {'nRTweet': 120,
#                 'nTweet': 199,
#                 'rDiffusion': 0.6030150753768844},
#  'jviver': {'nRTweet': 58, 'nTweet': 187, 'rDiffusion': 0.31016042780748665},
#  'kaliterilamia': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'karlape45': {'nRTweet': 181, 'nTweet': 200, 'rDiffusion': 0.905},
#  'katausten': {'nRTweet': 86, 'nTweet': 200, 'rDiffusion': 0.43},
#  'kate3lakes': {'nRTweet': 74,
#                 'nTweet': 196,
#                 'rDiffusion': 0.37755102040816324},
#  'kevinpuisieux': {'nRTweet': 12, 'nTweet': 16, 'rDiffusion': 0.75},
#  'koptermaharania': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'kostasdimou5': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'kostasgal50': {'nRTweet': 0, 'nTweet': 11, 'rDiffusion': 0.0},
#  'kostastt1': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'kosttttoziss': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'kurganskayapos': {'nRTweet': 0, 'nTweet': 27, 'rDiffusion': 0.0},
#  'laografikos': {'nRTweet': 0, 'nTweet': 3, 'rDiffusion': 0.0},
#  'larryclane': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'laurasabatini3': {'nRTweet': 196, 'nTweet': 200, 'rDiffusion': 0.98},
#  'laurentbaheux': {'nRTweet': 168, 'nTweet': 200, 'rDiffusion': 0.84},
#  'laurettaeliana': {'nRTweet': 30,
#                     'nTweet': 61,
#                     'rDiffusion': 0.4918032786885246},
#  'lectureverb': {'nRTweet': 28, 'nTweet': 200, 'rDiffusion': 0.14},
#  'lgaalves': {'nRTweet': 170, 'nTweet': 200, 'rDiffusion': 0.85},
#  'licht_anna': {'nRTweet': 2, 'nTweet': 3, 'rDiffusion': 0.6666666666666666},
#  'lilitpopoyan': {'nRTweet': 155,
#                   'nTweet': 178,
#                   'rDiffusion': 0.8707865168539326},
#  'lindod1972': {'nRTweet': 25, 'nTweet': 200, 'rDiffusion': 0.125},
#  'lista_redes': {'nRTweet': 75, 'nTweet': 200, 'rDiffusion': 0.375},
#  'lperodabasioglu': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'm_dalp': {'nRTweet': 11, 'nTweet': 25, 'rDiffusion': 0.44},
#  'm_waeck': {'nRTweet': 89, 'nTweet': 93, 'rDiffusion': 0.956989247311828},
#  'maggie_q_q': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'mallenbaker': {'nRTweet': 67, 'nTweet': 200, 'rDiffusion': 0.335},
#  'manlius84': {'nRTweet': 113, 'nTweet': 200, 'rDiffusion': 0.565},
#  'manuelhurt': {'nRTweet': 0, 'nTweet': 27, 'rDiffusion': 0.0},
#  'marcobardoscia': {'nRTweet': 66, 'nTweet': 200, 'rDiffusion': 0.33},
#  'marcoderrico': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'marcos_mancini': {'nRTweet': 152, 'nTweet': 200, 'rDiffusion': 0.76},
#  'marialaxa541': {'nRTweet': 10, 'nTweet': 200, 'rDiffusion': 0.05},
#  'mariusjoh': {'nRTweet': 42, 'nTweet': 200, 'rDiffusion': 0.21},
#  'marlin_meier': {'nRTweet': 5,
#                   'nTweet': 37,
#                   'rDiffusion': 0.13513513513513514},
#  'mateusevil10': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'maxidana1': {'nRTweet': 5, 'nTweet': 27, 'rDiffusion': 0.18518518518518517},
#  'mennoliauw': {'nRTweet': 3, 'nTweet': 4, 'rDiffusion': 0.75},
#  'mercadomagico': {'nRTweet': 111, 'nTweet': 200, 'rDiffusion': 0.555},
#  'michele_slowey': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'mientje1000000': {'nRTweet': 2, 'nTweet': 200, 'rDiffusion': 0.01},
#  'mike_n_martin': {'nRTweet': 102,
#                    'nTweet': 198,
#                    'rDiffusion': 0.5151515151515151},
#  'min_standardism': {'nRTweet': 53, 'nTweet': 200, 'rDiffusion': 0.265},
#  'mireillmartini': {'nRTweet': 144, 'nTweet': 200, 'rDiffusion': 0.72},
#  'miromarchi': {'nRTweet': 171,
#                 'nTweet': 199,
#                 'rDiffusion': 0.8592964824120602},
#  'mixalis_papako': {'nRTweet': 28, 'nTweet': 200, 'rDiffusion': 0.14},
#  'mkhm': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'mm1112322234': {'nRTweet': 73, 'nTweet': 200, 'rDiffusion': 0.365},
#  'mnapoletano1': {'nRTweet': 153, 'nTweet': 200, 'rDiffusion': 0.765},
#  'monicanagore': {'nRTweet': 119, 'nTweet': 200, 'rDiffusion': 0.595},
#  'moritszsz': {'nRTweet': 139, 'nTweet': 168, 'rDiffusion': 0.8273809523809523},
#  'mqdicer': {'nRTweet': 89, 'nTweet': 200, 'rDiffusion': 0.445},
#  'mszll': {'nRTweet': 117, 'nTweet': 199, 'rDiffusion': 0.5879396984924623},
#  'multiplex_fet': {'nRTweet': 6,
#                    'nTweet': 11,
#                    'rDiffusion': 0.5454545454545454},
#  'mvly3': {'nRTweet': 170, 'nTweet': 172, 'rDiffusion': 0.9883720930232558},
#  'my_pochemuchka': {'nRTweet': 50,
#                     'nTweet': 131,
#                     'rDiffusion': 0.3816793893129771},
#  'mydailynews24': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'n33dstfu': {'nRTweet': 0, 'nTweet': 10, 'rDiffusion': 0.0},
#  'nachoenblanco': {'nRTweet': 61,
#                    'nTweet': 72,
#                    'rDiffusion': 0.8472222222222222},
#  'nalsrarekli': {'nRTweet': 161,
#                  'nTweet': 199,
#                  'rDiffusion': 0.8090452261306532},
#  'nanumyan': {'nRTweet': 82, 'nTweet': 133, 'rDiffusion': 0.6165413533834586},
#  'netizait': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'netsci15': {'nRTweet': 200, 'nTweet': 200, 'rDiffusion': 1.0},
#  'netsci2017': {'nRTweet': 104, 'nTweet': 200, 'rDiffusion': 0.52},
#  'ngominhthanh4': {'nRTweet': 137,
#                    'nTweet': 199,
#                    'rDiffusion': 0.6884422110552764},
#  'nicolerycroft1': {'nRTweet': 37, 'nTweet': 200, 'rDiffusion': 0.185},
#  'nyaghouti': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'oddsku007': {'nRTweet': 31, 'nTweet': 198, 'rDiffusion': 0.15656565656565657},
#  'oikonomopoulo14': {'nRTweet': 17,
#                      'nTweet': 119,
#                      'rDiffusion': 0.14285714285714285},
#  'oil_products': {'nRTweet': 12,
#                   'nTweet': 54,
#                   'rDiffusion': 0.2222222222222222},
#  'olivierhoedeman': {'nRTweet': 199, 'nTweet': 200, 'rDiffusion': 0.995},
#  'openmaker': {'nRTweet': 123, 'nTweet': 200, 'rDiffusion': 0.615},
#  'openp2pdesign': {'nRTweet': 176, 'nTweet': 200, 'rDiffusion': 0.88},
#  'orbassano2000': {'nRTweet': 171, 'nTweet': 200, 'rDiffusion': 0.855},
#  'oskayipek': {'nRTweet': 159, 'nTweet': 199, 'rDiffusion': 0.7989949748743719},
#  'p_chiocchetti': {'nRTweet': 45, 'nTweet': 200, 'rDiffusion': 0.225},
#  'p_messages': {'nRTweet': 62, 'nTweet': 200, 'rDiffusion': 0.31},
#  'palabresgroup': {'nRTweet': 29,
#                    'nTweet': 76,
#                    'rDiffusion': 0.3815789473684211},
#  'palpi643': {'nRTweet': 172, 'nTweet': 193, 'rDiffusion': 0.8911917098445595},
#  'panchulzz': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'panteshkinati8': {'nRTweet': 0, 'nTweet': 28, 'rDiffusion': 0.0},
#  'parraguezr': {'nRTweet': 97, 'nTweet': 200, 'rDiffusion': 0.485},
#  'partickaya7wa1': {'nRTweet': 0, 'nTweet': 30, 'rDiffusion': 0.0},
#  'pdjahnke': {'nRTweet': 44, 'nTweet': 176, 'rDiffusion': 0.25},
#  'ph_desfosses': {'nRTweet': 22, 'nTweet': 200, 'rDiffusion': 0.11},
#  'pikosapikosgr': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'plusvaluetweets': {'nRTweet': 74, 'nTweet': 200, 'rDiffusion': 0.37},
#  'poesiaculina': {'nRTweet': 4,
#                   'nTweet': 144,
#                   'rDiffusion': 0.027777777777777776},
#  'popeye4__': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'prabprab': {'nRTweet': 74, 'nTweet': 200, 'rDiffusion': 0.37},
#  'promitmoitra': {'nRTweet': 86, 'nTweet': 200, 'rDiffusion': 0.43},
#  'querforscher': {'nRTweet': 63, 'nTweet': 72, 'rDiffusion': 0.875},
#  'r0guetrainer': {'nRTweet': 66,
#                   'nTweet': 199,
#                   'rDiffusion': 0.3316582914572864},
#  'rcabinte': {'nRTweet': 137, 'nTweet': 200, 'rDiffusion': 0.685},
#  'recofunghi': {'nRTweet': 34, 'nTweet': 200, 'rDiffusion': 0.17},
#  'renesugar': {'nRTweet': 66, 'nTweet': 200, 'rDiffusion': 0.33},
#  'repecCitEc': {'nRTweet': 179, 'nTweet': 200, 'rDiffusion': 0.895},
#  'resume_unilu': {'nRTweet': 116, 'nTweet': 200, 'rDiffusion': 0.58},
#  'rgod777': {'nRTweet': 3, 'nTweet': 200, 'rDiffusion': 0.015},
#  'ricardo11701135': {'nRTweet': 0, 'nTweet': 23, 'rDiffusion': 0.0},
#  'riddick19811': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'rubene822': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'saitej786': {'nRTweet': 186, 'nTweet': 197, 'rDiffusion': 0.9441624365482234},
#  'sambaravioli': {'nRTweet': 37,
#                   'nTweet': 199,
#                   'rDiffusion': 0.18592964824120603},
#  'sandrosapio': {'nRTweet': 18, 'nTweet': 25, 'rDiffusion': 0.72},
#  'sarahncorry': {'nRTweet': 78, 'nTweet': 200, 'rDiffusion': 0.39},
#  'sarresd8': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'sartin': {'nRTweet': 102, 'nTweet': 200, 'rDiffusion': 0.51},
#  'saxorut': {'nRTweet': 126, 'nTweet': 131, 'rDiffusion': 0.9618320610687023},
#  'schulte_stef': {'nRTweet': 11, 'nTweet': 200, 'rDiffusion': 0.055},
#  'sconquer8': {'nRTweet': 9, 'nTweet': 9, 'rDiffusion': 1.0},
#  'sebastienwathle': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'sees_lab': {'nRTweet': 135, 'nTweet': 200, 'rDiffusion': 0.675},
#  'sergiocabrero': {'nRTweet': 144, 'nTweet': 200, 'rDiffusion': 0.72},
#  'shakgohir': {'nRTweet': 139, 'nTweet': 199, 'rDiffusion': 0.6984924623115578},
#  'shanegibson': {'nRTweet': 60, 'nTweet': 200, 'rDiffusion': 0.3},
#  'shopwearblack': {'nRTweet': 2,
#                    'nTweet': 31,
#                    'rDiffusion': 0.06451612903225806},
#  'simply_jaehyuk': {'nRTweet': 48,
#                     'nTweet': 198,
#                     'rDiffusion': 0.24242424242424243},
#  'sjnwoh': {'nRTweet': 10, 'nTweet': 200, 'rDiffusion': 0.05},
#  'smalkina5e1': {'nRTweet': 0, 'nTweet': 38, 'rDiffusion': 0.0},
#  'solarcollab': {'nRTweet': 0, 'nTweet': 200, 'rDiffusion': 0.0},
#  'solarfornia': {'nRTweet': 2, 'nTweet': 12, 'rDiffusion': 0.16666666666666666},
#  'spiros_patelis': {'nRTweet': 1,
#                     'nTweet': 11,
#                     'rDiffusion': 0.09090909090909091},
#  'stefanodigiorg3': {'nRTweet': 37,
#                      'nTweet': 161,
#                      'rDiffusion': 0.22981366459627328},
#  'stefatos_kostas': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'stephenkinsella': {'nRTweet': 40, 'nTweet': 200, 'rDiffusion': 0.2},
#  'stf18': {'nRTweet': 75, 'nTweet': 200, 'rDiffusion': 0.375},
#  'strategypod': {'nRTweet': 24, 'nTweet': 200, 'rDiffusion': 0.12},
#  'styvencr7': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'su_re_co': {'nRTweet': 65, 'nTweet': 199, 'rDiffusion': 0.32663316582914576},
#  'syaltout': {'nRTweet': 144, 'nTweet': 199, 'rDiffusion': 0.7236180904522613},
#  'syroter_': {'nRTweet': 0, 'nTweet': 23, 'rDiffusion': 0.0},
#  'systemRK': {'nRTweet': 26, 'nTweet': 83, 'rDiffusion': 0.3132530120481928},
#  'tachristopoulos': {'nRTweet': 60, 'nTweet': 200, 'rDiffusion': 0.3},
#  'takis_kt': {'nRTweet': 146, 'nTweet': 200, 'rDiffusion': 0.73},
#  'tarik_rko': {'nRTweet': 78, 'nTweet': 198, 'rDiffusion': 0.3939393939393939},
#  'thanhbong06': {'nRTweet': 55,
#                  'nTweet': 135,
#                  'rDiffusion': 0.4074074074074074},
#  'the_young_fdn': {'nRTweet': 87, 'nTweet': 200, 'rDiffusion': 0.435},
#  'theceschi': {'nRTweet': 77, 'nTweet': 200, 'rDiffusion': 0.385},
#  'thekokytus': {'nRTweet': 35,
#                 'nTweet': 193,
#                 'rDiffusion': 0.18134715025906736},
#  'thetippytopblog': {'nRTweet': 1,
#                      'nTweet': 199,
#                      'rDiffusion': 0.005025125628140704},
#  'titarchukaj2s': {'nRTweet': 0, 'nTweet': 39, 'rDiffusion': 0.0},
#  'tiveleva4ie': {'nRTweet': 0, 'nTweet': 34, 'rDiffusion': 0.0},
#  'tommaschera': {'nRTweet': 0, 'nTweet': 11, 'rDiffusion': 0.0},
#  'tori_henry2': {'nRTweet': 0, 'nTweet': 1, 'rDiffusion': 0.0},
#  'tozhs': {'nRTweet': 0, 'nTweet': 0, 'rDiffusion': 0},
#  'tricks_y': {'nRTweet': 109, 'nTweet': 176, 'rDiffusion': 0.6193181818181818},
#  'trxias': {'nRTweet': 1, 'nTweet': 10, 'rDiffusion': 0.1},
#  'uzh_bf': {'nRTweet': 29, 'nTweet': 103, 'rDiffusion': 0.2815533980582524},
#  'valteraguiar654': {'nRTweet': 172,
#                      'nTweet': 198,
#                      'rDiffusion': 0.8686868686868687},
#  'vectracrome111': {'nRTweet': 1, 'nTweet': 200, 'rDiffusion': 0.005},
#  'veronika_st5': {'nRTweet': 55,
#                   'nTweet': 68,
#                   'rDiffusion': 0.8088235294117647},
#  'vijayakumarmad6': {'nRTweet': 1, 'nTweet': 1, 'rDiffusion': 1.0},
#  'vtchakarova': {'nRTweet': 117, 'nTweet': 200, 'rDiffusion': 0.585},
#  'xavierhervas': {'nRTweet': 146,
#                   'nTweet': 199,
#                   'rDiffusion': 0.7336683417085427},
#  'yanhua_yanhua7': {'nRTweet': 1, 'nTweet': 1, 'rDiffusion': 1.0},
#  'yuliay': {'nRTweet': 121, 'nTweet': 199, 'rDiffusion': 0.6080402010050251},
#  'yuridayana10': {'nRTweet': 77,
#                   'nTweet': 97,
#                   'rDiffusion': 0.7938144329896907},
#  'zbattiz': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65},
#  'zoozanne': {'nRTweet': 130, 'nTweet': 200, 'rDiffusion': 0.65}}

# %% [markdown]
# #### 5.2 Constructing and analyzing: who-retweets-whom network
#
# - **RTPopularity** : Of all harvested tweets how often the tweets from the follower is retweeted by the other followers.
# - **RTInternal** : Of all the retweets by the follower, the number of times the follower is retweeting the tweet of another followers from the community.
# - **RTExternal** : Of all the retweets by the follower, the number of times the follower is retweeting a tweet from a non-follower user.
# - **RTCohesion** : The ratio of the internal tweets to the total retweets. The measure can be used as a proxy on 'to what extend the community under investigation is within the focus of the user?'. A cumulative statistics over all the followers may give an idea on the cohesion between followers.

# %%
RT_Network = extract_relations(curated, linktype = 'rt_from')
RT_Network_Cohesion = get_cohesion_ratios(RT_Network, followers)
RT_Network_Internal = select_subnet(RT_Network, followers)
RT_Network_Internal_Connected, RT_Network_Internal_Isolates = drop_isolates(RT_Network_Internal)

# %%
pp.pprint(RT_Network_Cohesion)
# Out:
# {'0ttamatt': {'in': 31, 'out': 37, 'ratio': 0.45588235294117646},
#  '2dipicchee': {'in': 82, 'out': 74, 'ratio': 0.5256410256410257},
#  '4A50CqwsQqeahlq': {'in': 0, 'out': 0, 'ratio': 0},
#  '7softley': {'in': 0, 'out': 161, 'ratio': 0.0},
#  '7wData': {'in': 0, 'out': 132, 'ratio': 0.0},
#  '85Fifteen': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'AEBIOM': {'in': 1, 'out': 118, 'ratio': 0.008403361344537815},
#  'APRC_CF': {'in': 4, 'out': 96, 'ratio': 0.04},
#  'ARNAOYTHSD': {'in': 0, 'out': 0, 'ratio': 0},
#  'AdaFerko': {'in': 0, 'out': 56, 'ratio': 0.0},
#  'AdamPC26': {'in': 0, 'out': 107, 'ratio': 0.0},
#  'Adeline_story': {'in': 0, 'out': 0, 'ratio': 0},
#  'Adellibya1979': {'in': 0, 'out': 123, 'ratio': 0.0},
#  'AdolfSanchez5': {'in': 0, 'out': 153, 'ratio': 0.0},
#  'Adoufrancois': {'in': 0, 'out': 0, 'ratio': 0},
#  'Agent_Jase': {'in': 2, 'out': 43, 'ratio': 0.044444444444444446},
#  'Agn_ssa': {'in': 77, 'out': 30, 'ratio': 0.719626168224299},
#  'AlanGIsaac': {'in': 1, 'out': 45, 'ratio': 0.021739130434782608},
#  'AlbertoMunoz': {'in': 2, 'out': 72, 'ratio': 0.02702702702702703},
#  'AldeiDiogo': {'in': 3, 'out': 165, 'ratio': 0.017857142857142856},
#  'AlessandroLaced': {'in': 1, 'out': 99, 'ratio': 0.01},
#  'Alex_GuerreroR': {'in': 0, 'out': 126, 'ratio': 0.0},
#  'AlineCosette': {'in': 3, 'out': 126, 'ratio': 0.023255813953488372},
#  'Amanuel40Rui': {'in': 0, 'out': 199, 'ratio': 0.0},
#  'AndreaBindo': {'in': 70, 'out': 48, 'ratio': 0.5932203389830508},
#  'AndreaRoventini': {'in': 84, 'out': 51, 'ratio': 0.6222222222222222},
#  'Andreas_Chile': {'in': 0, 'out': 0, 'ratio': 0},
#  'Andrewbrum': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'AngelFe23124123': {'in': 0, 'out': 0, 'ratio': 0},
#  'Angela07261976': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'Anna_Hadorn': {'in': 0, 'out': 12, 'ratio': 0.0},
#  'AnneMur16630871': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'AppDeveloperHue': {'in': 1, 'out': 49, 'ratio': 0.02},
#  'ArcmorRib': {'in': 0, 'out': 0, 'ratio': 0},
#  'ArnautzPgvila': {'in': 0, 'out': 161, 'ratio': 0.0},
#  'Arturo311311311': {'in': 0, 'out': 0, 'ratio': 0},
#  'AsaBentley': {'in': 13, 'out': 80, 'ratio': 0.13978494623655913},
#  'Asmmar1999': {'in': 0, 'out': 0, 'ratio': 0},
#  'AugustusSouto': {'in': 3, 'out': 178, 'ratio': 0.016574585635359115},
#  'BIntendente': {'in': 0, 'out': 0, 'ratio': 0},
#  'BUPardeeCenter': {'in': 7, 'out': 131, 'ratio': 0.050724637681159424},
#  'Barone54924381': {'in': 0, 'out': 41, 'ratio': 0.0},
#  'BenitoMma': {'in': 4, 'out': 24, 'ratio': 0.14285714285714285},
#  'Benmccreton1': {'in': 1, 'out': 12, 'ratio': 0.07692307692307693},
#  'Better_Finance': {'in': 3, 'out': 125, 'ratio': 0.0234375},
#  'Beyond_Ratings': {'in': 2, 'out': 17, 'ratio': 0.10526315789473684},
#  'Bifrostonline': {'in': 2, 'out': 102, 'ratio': 0.019230769230769232},
#  'BigDataStackEU': {'in': 0, 'out': 0, 'ratio': 0},
#  'BingoLittle1': {'in': 6, 'out': 168, 'ratio': 0.034482758620689655},
#  'BlacMambaMMA': {'in': 0, 'out': 143, 'ratio': 0.0},
#  'Blinis': {'in': 0, 'out': 41, 'ratio': 0.0},
#  'Blueland1': {'in': 0, 'out': 0, 'ratio': 0},
#  'BluewaterGlobe': {'in': 1, 'out': 100, 'ratio': 0.009900990099009901},
#  'BoekeKatrin': {'in': 0, 'out': 0, 'ratio': 0},
#  'BradZarnett': {'in': 0, 'out': 51, 'ratio': 0.0},
#  'BrainConceptual': {'in': 2, 'out': 0, 'ratio': 1.0},
#  'BsjgMMZetBPIHca': {'in': 0, 'out': 0, 'ratio': 0},
#  'BusinessPartnrs': {'in': 1, 'out': 8, 'ratio': 0.1111111111111111},
#  'ByGeorgePerr': {'in': 0, 'out': 0, 'ratio': 0},
#  'CASAPUEBLO8': {'in': 4, 'out': 6, 'ratio': 0.4},
#  'CCL_Aus': {'in': 1, 'out': 54, 'ratio': 0.01818181818181818},
#  'CGraciaLazaro': {'in': 86, 'out': 56, 'ratio': 0.6056338028169014},
#  'CMCSatBU': {'in': 14, 'out': 29, 'ratio': 0.32558139534883723},
#  'CT_Coughlin': {'in': 1, 'out': 172, 'ratio': 0.005780346820809248},
#  'CanddyShawn': {'in': 2, 'out': 18, 'ratio': 0.1},
#  'CanvasVC': {'in': 0, 'out': 143, 'ratio': 0.0},
#  'CardanIOTeam': {'in': 5, 'out': 10, 'ratio': 0.3333333333333333},
#  'CardanoStiftung': {'in': 0, 'out': 42, 'ratio': 0.0},
#  'CarnesBestia': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'CaroleCasuco': {'in': 0, 'out': 123, 'ratio': 0.0},
#  'CasaEdelVicenza': {'in': 7, 'out': 5, 'ratio': 0.5833333333333334},
#  'Casinos95': {'in': 0, 'out': 0, 'ratio': 0},
#  'Caydennash2': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'CherryEnergy1': {'in': 0, 'out': 88, 'ratio': 0.0},
#  'ChrisGGeorgas': {'in': 0, 'out': 0, 'ratio': 0},
#  'ChrisHudgins5': {'in': 1, 'out': 173, 'ratio': 0.005747126436781609},
#  'ChristosEllina1': {'in': 9, 'out': 149, 'ratio': 0.056962025316455694},
#  'CigeuInfo': {'in': 0, 'out': 0, 'ratio': 0},
#  'Climate_Friend': {'in': 4, 'out': 42, 'ratio': 0.08695652173913043},
#  'CoeGSS': {'in': 9, 'out': 131, 'ratio': 0.06428571428571428},
#  'Complexity_Labs': {'in': 10, 'out': 7, 'ratio': 0.5882352941176471},
#  'Concerns_You': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'CorneliaDaniel': {'in': 1, 'out': 64, 'ratio': 0.015384615384615385},
#  'CriptodivisasMx': {'in': 2, 'out': 188, 'ratio': 0.010526315789473684},
#  'Crypto20183': {'in': 1, 'out': 86, 'ratio': 0.011494252873563218},
#  'CyprusInno': {'in': 0, 'out': 30, 'ratio': 0.0},
#  'DELPHIBG': {'in': 2, 'out': 0, 'ratio': 1.0},
#  'D_young_69': {'in': 5, 'out': 90, 'ratio': 0.05263157894736842},
#  'Daimakaimura': {'in': 0, 'out': 190, 'ratio': 0.0},
#  'DarkMatter_Labs': {'in': 44, 'out': 63, 'ratio': 0.411214953271028},
#  'DatingCH': {'in': 0, 'out': 0, 'ratio': 0},
#  'DeboyJames21': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'DecentralizedEn': {'in': 6, 'out': 136, 'ratio': 0.04225352112676056},
#  'DeepestLearning': {'in': 0, 'out': 0, 'ratio': 0},
#  'Demon666Yt': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'DiabetesDaisy': {'in': 85, 'out': 2, 'ratio': 0.9770114942528736},
#  'DimasSetyadi5': {'in': 0, 'out': 144, 'ratio': 0.0},
#  'DinoFiorita': {'in': 17, 'out': 1, 'ratio': 0.9444444444444444},
#  'DistributedNRG': {'in': 3, 'out': 153, 'ratio': 0.019230769230769232},
#  'DougThorpe_com': {'in': 0, 'out': 38, 'ratio': 0.0},
#  'DrDrossosDem': {'in': 0, 'out': 175, 'ratio': 0.0},
#  'Drideologie': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'DucThiLuu': {'in': 26, 'out': 9, 'ratio': 0.7428571428571429},
#  'Duph_Berg': {'in': 7, 'out': 192, 'ratio': 0.035175879396984924},
#  'DustyTweak': {'in': 0, 'out': 0, 'ratio': 0},
#  'EERwtUeb7HgG8pf': {'in': 0, 'out': 38, 'ratio': 0.0},
#  'EHillBrody': {'in': 0, 'out': 0, 'ratio': 0},
#  'EarthWatt': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'Easyimpresa1': {'in': 4, 'out': 0, 'ratio': 1.0},
#  'EcologicalEcon': {'in': 16, 'out': 39, 'ratio': 0.2909090909090909},
#  'Eindhoven60': {'in': 0, 'out': 0, 'ratio': 0},
#  'Elcada_GmbH': {'in': 0, 'out': 0, 'ratio': 0},
#  'EmreYakr1': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'EnviroNews': {'in': 23, 'out': 75, 'ratio': 0.23469387755102042},
#  'Etp4H': {'in': 0, 'out': 114, 'ratio': 0.0},
#  'EuroLuckyStars': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'FETFX_EU': {'in': 33, 'out': 59, 'ratio': 0.358695652173913},
#  'FETFlagships': {'in': 10, 'out': 164, 'ratio': 0.05747126436781609},
#  'FabioCarrirolo': {'in': 0, 'out': 156, 'ratio': 0.0},
#  'FabriceSabatier': {'in': 5, 'out': 46, 'ratio': 0.09803921568627451},
#  'Falco810': {'in': 9, 'out': 5, 'ratio': 0.6428571428571429},
#  'FcoKienzle': {'in': 17, 'out': 40, 'ratio': 0.2982456140350877},
#  'Fede_Botta': {'in': 2, 'out': 147, 'ratio': 0.013422818791946308},
#  'Fet2Rin': {'in': 6, 'out': 59, 'ratio': 0.09230769230769231},
#  'FightInequalit1': {'in': 55, 'out': 104, 'ratio': 0.34591194968553457},
#  'Filipata__': {'in': 0, 'out': 95, 'ratio': 0.0},
#  'FinexusCenter': {'in': 0, 'out': 0, 'ratio': 0},
#  'FinforTomorrow': {'in': 9, 'out': 55, 'ratio': 0.140625},
#  'FiramisCompany': {'in': 1, 'out': 147, 'ratio': 0.006756756756756757},
#  'FootnoteMedia': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'FoundationRMF': {'in': 2, 'out': 22, 'ratio': 0.08333333333333333},
#  'Frances11022994': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'FranciscoICMC': {'in': 33, 'out': 101, 'ratio': 0.2462686567164179},
#  'FredAmblard': {'in': 3, 'out': 65, 'ratio': 0.04411764705882353},
#  'FutSciNow': {'in': 0, 'out': 178, 'ratio': 0.0},
#  'GECoalition': {'in': 4, 'out': 68, 'ratio': 0.05555555555555555},
#  'Gabriel_Hatem': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'GautierChauvin': {'in': 0, 'out': 0, 'ratio': 0},
#  'GeoVun': {'in': 2, 'out': 28, 'ratio': 0.06666666666666667},
#  'GiachiniDaniele': {'in': 108, 'out': 2, 'ratio': 0.9818181818181818},
#  'Gianlucamisu': {'in': 6, 'out': 138, 'ratio': 0.041666666666666664},
#  'Gius_C': {'in': 57, 'out': 6, 'ratio': 0.9047619047619048},
#  'GladiAAreise': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'GochaT69': {'in': 1, 'out': 11, 'ratio': 0.08333333333333333},
#  'GuidoCaldarelli': {'in': 32, 'out': 97, 'ratio': 0.24806201550387597},
#  'HNR_org': {'in': 1, 'out': 52, 'ratio': 0.018867924528301886},
#  'HamishJWyatt': {'in': 36, 'out': 79, 'ratio': 0.3130434782608696},
#  'HanKitcher': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'HelenJackson0': {'in': 1, 'out': 46, 'ratio': 0.02127659574468085},
#  'Helens60': {'in': 0, 'out': 120, 'ratio': 0.0},
#  'HyacintheBuiss1': {'in': 1, 'out': 185, 'ratio': 0.005376344086021506},
#  'IASS_DOLFINS': {'in': 71, 'out': 12, 'ratio': 0.8554216867469879},
#  'IASS_Potsdam': {'in': 2, 'out': 110, 'ratio': 0.017857142857142856},
#  'IBSEN_H2020': {'in': 77, 'out': 90, 'ratio': 0.46107784431137727},
#  'IET_online': {'in': 0, 'out': 0, 'ratio': 0},
#  'IMPACT_EV': {'in': 0, 'out': 75, 'ratio': 0.0},
#  'IMTipps': {'in': 0, 'out': 0, 'ratio': 0},
#  'IOPDAHKA': {'in': 0, 'out': 0, 'ratio': 0},
#  'ISEEORG': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'ISI_Fondazione': {'in': 28, 'out': 126, 'ratio': 0.18181818181818182},
#  'ISIgrowth': {'in': 80, 'out': 50, 'ratio': 0.6153846153846154},
#  'Igorsemenoff': {'in': 0, 'out': 0, 'ratio': 0},
#  'Ika_Midenistis': {'in': 0, 'out': 46, 'ratio': 0.0},
#  'ImpactShapers': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'Inova_Paciente': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'JBPKGSolutions': {'in': 5, 'out': 54, 'ratio': 0.0847457627118644},
#  'JFernandoGRE': {'in': 3, 'out': 119, 'ratio': 0.02459016393442623},
#  'JacopoSestili': {'in': 2, 'out': 143, 'ratio': 0.013793103448275862},
#  'JahelMielke': {'in': 6, 'out': 64, 'ratio': 0.08571428571428572},
#  'James_Vaccaro': {'in': 5, 'out': 87, 'ratio': 0.05434782608695652},
#  'JeromeRoch74': {'in': 0, 'out': 149, 'ratio': 0.0},
#  'JoeRini6': {'in': 7, 'out': 21, 'ratio': 0.25},
#  'JofreCarnicer': {'in': 0, 'out': 135, 'ratio': 0.0},
#  'JonathanEcon': {'in': 0, 'out': 0, 'ratio': 0},
#  'JulienHallak': {'in': 0, 'out': 142, 'ratio': 0.0},
#  'KerrieMengersen': {'in': 0, 'out': 91, 'ratio': 0.0},
#  'KimMarln': {'in': 0, 'out': 136, 'ratio': 0.0},
#  'KleineBottleM': {'in': 0, 'out': 0, 'ratio': 0},
#  'KoljaKleineberg': {'in': 6, 'out': 152, 'ratio': 0.0379746835443038},
#  'KushyKush': {'in': 1, 'out': 32, 'ratio': 0.030303030303030304},
#  'LDNinst': {'in': 3, 'out': 33, 'ratio': 0.08333333333333333},
#  'LERUnews': {'in': 13, 'out': 168, 'ratio': 0.0718232044198895},
#  'L__Macfarlane': {'in': 10, 'out': 121, 'ratio': 0.07633587786259542},
#  'LeadMakelaar': {'in': 2, 'out': 5, 'ratio': 0.2857142857142857},
#  'LeanneUssher': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'LetUsShineNow': {'in': 0, 'out': 0, 'ratio': 0},
#  'LetsWorkHappy': {'in': 11, 'out': 49, 'ratio': 0.18333333333333332},
#  'LieveFransen': {'in': 9, 'out': 116, 'ratio': 0.072},
#  'LindaBach14': {'in': 0, 'out': 63, 'ratio': 0.0},
#  'Lori_McNeill': {'in': 1, 'out': 119, 'ratio': 0.008333333333333333},
#  'LostInMath': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'Louisbarla': {'in': 0, 'out': 0, 'ratio': 0},
#  'Lsuttors': {'in': 34, 'out': 114, 'ratio': 0.22972972972972974},
#  'LucieKirstein': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'LuisaDeAmicis': {'in': 72, 'out': 84, 'ratio': 0.46153846153846156},
#  'LyndaMansson': {'in': 1, 'out': 112, 'ratio': 0.008849557522123894},
#  'MARGA_GLEZ_FDEZ': {'in': 2, 'out': 149, 'ratio': 0.013245033112582781},
#  'MARIASOLOMONID2': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'MBMConsultancy': {'in': 3, 'out': 4, 'ratio': 0.42857142857142855},
#  'MPA37855265': {'in': 2, 'out': 0, 'ratio': 1.0},
#  'MacroPru': {'in': 6, 'out': 76, 'ratio': 0.07317073170731707},
#  'Mahfuz__Rahman': {'in': 5, 'out': 55, 'ratio': 0.08333333333333333},
#  'MariaBejaCosta1': {'in': 4, 'out': 0, 'ratio': 1.0},
#  'MariaMariliam23': {'in': 0, 'out': 0, 'ratio': 0},
#  'Marji84': {'in': 4, 'out': 99, 'ratio': 0.038834951456310676},
#  'MarlonMasine': {'in': 0, 'out': 54, 'ratio': 0.0},
#  'MartaCalderaro': {'in': 73, 'out': 114, 'ratio': 0.39037433155080214},
#  'MartinaOccelli': {'in': 3, 'out': 49, 'ratio': 0.057692307692307696},
#  'Mattia_Guerini': {'in': 103, 'out': 74, 'ratio': 0.5819209039548022},
#  'Maxknew': {'in': 0, 'out': 54, 'ratio': 0.0},
#  'MazzucatoM': {'in': 3, 'out': 132, 'ratio': 0.022222222222222223},
#  'MiaPhlor': {'in': 0, 'out': 0, 'ratio': 0},
#  'MichaelRFerrari': {'in': 0, 'out': 134, 'ratio': 0.0},
#  'MichellLiberty': {'in': 0, 'out': 192, 'ratio': 0.0},
#  'MiguelBasire': {'in': 0, 'out': 148, 'ratio': 0.0},
#  'MikeOConnor3': {'in': 0, 'out': 177, 'ratio': 0.0},
#  'MitchDOPEcom': {'in': 0, 'out': 0, 'ratio': 0},
#  'Mlopezforero': {'in': 0, 'out': 83, 'ratio': 0.0},
#  'MolinariMax_': {'in': 6, 'out': 38, 'ratio': 0.13636363636363635},
#  'MoneyWAmission': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'Monithon': {'in': 1, 'out': 185, 'ratio': 0.005376344086021506},
#  'MorganBeaugrand': {'in': 0, 'out': 193, 'ratio': 0.0},
#  'NectuntLab': {'in': 42, 'out': 15, 'ratio': 0.7368421052631579},
#  'NgulunguT': {'in': 0, 'out': 0, 'ratio': 0},
#  'NickBeglinger': {'in': 4, 'out': 52, 'ratio': 0.07142857142857142},
#  'NickJackson81': {'in': 0, 'out': 32, 'ratio': 0.0},
#  'Nietzchrodinger': {'in': 3, 'out': 121, 'ratio': 0.024193548387096774},
#  'NomosCSP': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'OVESCO': {'in': 5, 'out': 97, 'ratio': 0.049019607843137254},
#  'Oleatopia': {'in': 0, 'out': 0, 'ratio': 0},
#  'OlgaBuchholz': {'in': 0, 'out': 0, 'ratio': 0},
#  'OneClickSolar': {'in': 3, 'out': 33, 'ratio': 0.08333333333333333},
#  'OnePlanetParis': {'in': 1, 'out': 71, 'ratio': 0.013888888888888888},
#  'OrpheusEU': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'PEP4UM': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'PPFEnergia': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'PSalazarO': {'in': 0, 'out': 0, 'ratio': 0},
#  'PaoloBarucca': {'in': 24, 'out': 82, 'ratio': 0.22641509433962265},
#  'Paorazio': {'in': 4, 'out': 41, 'ratio': 0.08888888888888889},
#  'PatrikReisinger': {'in': 20, 'out': 14, 'ratio': 0.5882352941176471},
#  'PatsonBibou1168': {'in': 0, 'out': 186, 'ratio': 0.0},
#  'Pedromgi19': {'in': 0, 'out': 0, 'ratio': 0},
#  'PetraKraljNovak': {'in': 10, 'out': 9, 'ratio': 0.5263157894736842},
#  'Peveeeric1': {'in': 0, 'out': 138, 'ratio': 0.0},
#  'PheasantEnergy': {'in': 0, 'out': 0, 'ratio': 0},
#  'Phil5571': {'in': 0, 'out': 0, 'ratio': 0},
#  'PhillipNunnUK': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'PhysScala': {'in': 0, 'out': 0, 'ratio': 0},
#  'Pierre_Monnin': {'in': 16, 'out': 97, 'ratio': 0.1415929203539823},
#  'Platy_Kalamatas': {'in': 0, 'out': 0, 'ratio': 0},
#  'PolatSihab': {'in': 0, 'out': 63, 'ratio': 0.0},
#  'PolicyCompassEU': {'in': 3, 'out': 101, 'ratio': 0.028846153846153848},
#  'Project722TMX': {'in': 1, 'out': 22, 'ratio': 0.043478260869565216},
#  'PubAffairsEU': {'in': 10, 'out': 14, 'ratio': 0.4166666666666667},
#  'REANworld': {'in': 2, 'out': 8, 'ratio': 0.2},
#  'RFIFoundation': {'in': 2, 'out': 71, 'ratio': 0.0273972602739726},
#  'RRytenband': {'in': 3, 'out': 46, 'ratio': 0.061224489795918366},
#  'RakibEnew': {'in': 0, 'out': 91, 'ratio': 0.0},
#  'RebuildMacro': {'in': 31, 'out': 126, 'ratio': 0.19745222929936307},
#  'Registry_Blocks': {'in': 1, 'out': 2, 'ratio': 0.3333333333333333},
#  'RitaMaria_dRC': {'in': 0, 'out': 104, 'ratio': 0.0},
#  'RobPasqualino': {'in': 3, 'out': 27, 'ratio': 0.1},
#  'RoccaBam': {'in': 0, 'out': 0, 'ratio': 0},
#  'RockJimford': {'in': 1, 'out': 131, 'ratio': 0.007575757575757576},
#  'RogerCremades': {'in': 16, 'out': 168, 'ratio': 0.08695652173913043},
#  'RogervEijk': {'in': 10, 'out': 5, 'ratio': 0.6666666666666666},
#  'RothcoPepp': {'in': 2, 'out': 38, 'ratio': 0.05},
#  'RubyBretislav': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'SFL_nl': {'in': 2, 'out': 74, 'ratio': 0.02631578947368421},
#  'SICommunity_EU': {'in': 14, 'out': 139, 'ratio': 0.0915032679738562},
#  'SSEinitiative': {'in': 2, 'out': 62, 'ratio': 0.03125},
#  'SUPERTWIN_H2020': {'in': 1, 'out': 2, 'ratio': 0.3333333333333333},
#  'Sandra_G_Urbano': {'in': 0, 'out': 51, 'ratio': 0.0},
#  'Saracris95': {'in': 0, 'out': 65, 'ratio': 0.0},
#  'Sb4GvLAuBrNkc93': {'in': 0, 'out': 0, 'ratio': 0},
#  'Schumannpoet': {'in': 6, 'out': 0, 'ratio': 1.0},
#  'Seavangelesse': {'in': 3, 'out': 131, 'ratio': 0.022388059701492536},
#  'Sebespejo': {'in': 0, 'out': 67, 'ratio': 0.0},
#  'SelinaStoller': {'in': 32, 'out': 1, 'ratio': 0.9696969696969697},
#  'SeloSlav': {'in': 1, 'out': 30, 'ratio': 0.03225806451612903},
#  'ShaunFrankson': {'in': 11, 'out': 169, 'ratio': 0.06111111111111111},
#  'SiQuizas': {'in': 0, 'out': 132, 'ratio': 0.0},
#  'SimPolProject': {'in': 139, 'out': 26, 'ratio': 0.8424242424242424},
#  'SimonThordal': {'in': 0, 'out': 20, 'ratio': 0.0},
#  'SimulPast': {'in': 4, 'out': 178, 'ratio': 0.02197802197802198},
#  'SodreLuciana': {'in': 2, 'out': 6, 'ratio': 0.25},
#  'StarwarsMaker': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'StephaneNappo': {'in': 0, 'out': 0, 'ratio': 0},
#  'StieberHarald': {'in': 2, 'out': 13, 'ratio': 0.13333333333333333},
#  'SunilMalhotra': {'in': 1, 'out': 55, 'ratio': 0.017857142857142856},
#  'SusFinLab': {'in': 11, 'out': 155, 'ratio': 0.06626506024096386},
#  'SusieMod88': {'in': 0, 'out': 0, 'ratio': 0},
#  'SvyatoslavHrync': {'in': 0, 'out': 0, 'ratio': 0},
#  'SwissCognitive': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'TMWFTE': {'in': 1, 'out': 51, 'ratio': 0.019230769230769232},
#  'TSERETELI_0102': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'TagederSonne': {'in': 80, 'out': 27, 'ratio': 0.7476635514018691},
#  'TehRaio': {'in': 1, 'out': 20, 'ratio': 0.047619047619047616},
#  'TheRealShankar': {'in': 2, 'out': 180, 'ratio': 0.01098901098901099},
#  'Thierry_Kame': {'in': 15, 'out': 184, 'ratio': 0.07537688442211055},
#  'TiberiuPetre': {'in': 0, 'out': 0, 'ratio': 0},
#  'TipGhosh': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'TomasBalint': {'in': 5, 'out': 153, 'ratio': 0.03164556962025317},
#  'TorreyShine': {'in': 0, 'out': 0, 'ratio': 0},
#  'Transitionway': {'in': 23, 'out': 52, 'ratio': 0.30666666666666664},
#  'UB_ICS': {'in': 11, 'out': 69, 'ratio': 0.1375},
#  'UNEP_FI': {'in': 6, 'out': 63, 'ratio': 0.08695652173913043},
#  'ValerioVolpati': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'Vangel_artist': {'in': 0, 'out': 186, 'ratio': 0.0},
#  'VeronicaClima': {'in': 15, 'out': 124, 'ratio': 0.1079136690647482},
#  'Vibeka': {'in': 2, 'out': 135, 'ratio': 0.014598540145985401},
#  'VilmaBerta17': {'in': 0, 'out': 175, 'ratio': 0.0},
#  'VivereLanzarote': {'in': 92, 'out': 29, 'ratio': 0.7603305785123967},
#  'VlPetrovV': {'in': 53, 'out': 27, 'ratio': 0.6625},
#  'WJFTechnical': {'in': 6, 'out': 17, 'ratio': 0.2608695652173913},
#  'WOETUK': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'WRIClimate': {'in': 1, 'out': 49, 'ratio': 0.02},
#  'WarrenWhitlock': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'WelfareUnited': {'in': 1, 'out': 67, 'ratio': 0.014705882352941176},
#  'WiedmannBibel': {'in': 0, 'out': 0, 'ratio': 0},
#  'Xilbshi': {'in': 3, 'out': 116, 'ratio': 0.025210084033613446},
#  'YannisDafermos': {'in': 9, 'out': 46, 'ratio': 0.16363636363636364},
#  'ZeGordon': {'in': 0, 'out': 0, 'ratio': 0},
#  'Zen3dT': {'in': 0, 'out': 0, 'ratio': 0},
#  'ZhengIsabelle': {'in': 40, 'out': 1, 'ratio': 0.975609756097561},
#  'ZoeGold69': {'in': 0, 'out': 0, 'ratio': 0},
#  'ZofiaWemanska': {'in': 0, 'out': 0, 'ratio': 0},
#  '_ChiaraPerillo': {'in': 37, 'out': 9, 'ratio': 0.8043478260869565},
#  '_NicoFrey': {'in': 8, 'out': 136, 'ratio': 0.05555555555555555},
#  '__jasmy': {'in': 3, 'out': 1, 'ratio': 0.75},
#  '_ch3m': {'in': 5, 'out': 150, 'ratio': 0.03225806451612903},
#  '_marameo_': {'in': 9, 'out': 157, 'ratio': 0.05421686746987952},
#  '_ndrd_': {'in': 1, 'out': 19, 'ratio': 0.05},
#  'a_yang_w': {'in': 0, 'out': 0, 'ratio': 0},
#  'adilson_motter': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'adria_plazas': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'aebiondo': {'in': 9, 'out': 88, 'ratio': 0.09278350515463918},
#  'aetw15': {'in': 0, 'out': 199, 'ratio': 0.0},
#  'afrochia': {'in': 0, 'out': 0, 'ratio': 0},
#  'agabardo': {'in': 1, 'out': 17, 'ratio': 0.05555555555555555},
#  'ailatan1898': {'in': 0, 'out': 50, 'ratio': 0.0},
#  'ale_marichela': {'in': 0, 'out': 114, 'ratio': 0.0},
#  'aleaf_h2020': {'in': 6, 'out': 58, 'ratio': 0.09375},
#  'alediemmee': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'alfonso_soldano': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'alp08989139': {'in': 0, 'out': 0, 'ratio': 0},
#  'alvarofenomeno': {'in': 0, 'out': 148, 'ratio': 0.0},
#  'amanahramadiah': {'in': 2, 'out': 97, 'ratio': 0.020202020202020204},
#  'amapr1': {'in': 0, 'out': 0, 'ratio': 0},
#  'ambatellova8u9': {'in': 0, 'out': 0, 'ratio': 0},
#  'amritasaha': {'in': 1, 'out': 80, 'ratio': 0.012345679012345678},
#  'amsterdam_bill': {'in': 0, 'out': 52, 'ratio': 0.0},
#  'anaishannah': {'in': 3, 'out': 87, 'ratio': 0.03333333333333333},
#  'andkarpf': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'andrasonea': {'in': 3, 'out': 160, 'ratio': 0.018404907975460124},
#  'anduviera': {'in': 14, 'out': 163, 'ratio': 0.07909604519774012},
#  'anewmediaprof': {'in': 2, 'out': 20, 'ratio': 0.09090909090909091},
#  'angelnunhez': {'in': 7, 'out': 84, 'ratio': 0.07692307692307693},
#  'anhvan_dz': {'in': 1, 'out': 14, 'ratio': 0.06666666666666667},
#  'anielloiorio197': {'in': 73, 'out': 27, 'ratio': 0.73},
#  'anima_tu': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'anxosan': {'in': 4, 'out': 166, 'ratio': 0.023529411764705882},
#  'aparpau': {'in': 4, 'out': 38, 'ratio': 0.09523809523809523},
#  'arthurturrell': {'in': 3, 'out': 128, 'ratio': 0.022900763358778626},
#  'asgeirbt': {'in': 3, 'out': 113, 'ratio': 0.02586206896551724},
#  'aurorab96124853': {'in': 0, 'out': 0, 'ratio': 0},
#  'avogli': {'in': 0, 'out': 0, 'ratio': 0},
#  'axekoukou': {'in': 2, 'out': 22, 'ratio': 0.08333333333333333},
#  'ayazarka88': {'in': 4, 'out': 137, 'ratio': 0.028368794326241134},
#  'aymeric_vie': {'in': 14, 'out': 184, 'ratio': 0.0707070707070707},
#  'bandigsm': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'barcomerni': {'in': 2, 'out': 57, 'ratio': 0.03389830508474576},
#  'barryejames': {'in': 1, 'out': 47, 'ratio': 0.020833333333333332},
#  'baryshnevadn0': {'in': 0, 'out': 0, 'ratio': 0},
#  'bassindales': {'in': 1, 'out': 64, 'ratio': 0.015384615384615385},
#  'bastidas_d': {'in': 3, 'out': 115, 'ratio': 0.025423728813559324},
#  'bb_pedromartins': {'in': 0, 'out': 0, 'ratio': 0},
#  'bdp_smith': {'in': 0, 'out': 87, 'ratio': 0.0},
#  'bellacindylee': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'bergautier': {'in': 0, 'out': 99, 'ratio': 0.0},
#  'bethscleft': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'bginoc': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'bh7u86u5tvfsn': {'in': 0, 'out': 0, 'ratio': 0},
#  'bitlumens': {'in': 2, 'out': 41, 'ratio': 0.046511627906976744},
#  'bobbyreyes20': {'in': 0, 'out': 40, 'ratio': 0.0},
#  'bonosverdes': {'in': 6, 'out': 84, 'ratio': 0.06666666666666667},
#  'bplisse': {'in': 67, 'out': 4, 'ratio': 0.9436619718309859},
#  'brianehenyo': {'in': 0, 'out': 55, 'ratio': 0.0},
#  'brianla1': {'in': 2, 'out': 110, 'ratio': 0.017857142857142856},
#  'brjmoez': {'in': 0, 'out': 145, 'ratio': 0.0},
#  'bulentozel': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'burrolahola': {'in': 2, 'out': 87, 'ratio': 0.02247191011235955},
#  'camilleoudinot': {'in': 0, 'out': 30, 'ratio': 0.0},
#  'carinacarinas': {'in': 2, 'out': 147, 'ratio': 0.013422818791946308},
#  'carnadani': {'in': 78, 'out': 4, 'ratio': 0.9512195121951219},
#  'cbbagsic': {'in': 3, 'out': 175, 'ratio': 0.016853932584269662},
#  'chrizau': {'in': 0, 'out': 42, 'ratio': 0.0},
#  'ciro': {'in': 7, 'out': 165, 'ratio': 0.040697674418604654},
#  'claudia_mihai': {'in': 2, 'out': 37, 'ratio': 0.05128205128205128},
#  'complex_warsaw': {'in': 2, 'out': 25, 'ratio': 0.07407407407407407},
#  'coonchi14': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'cosnet_bifi': {'in': 30, 'out': 105, 'ratio': 0.2222222222222222},
#  'crie_ufrj': {'in': 12, 'out': 27, 'ratio': 0.3076923076923077},
#  'daniel_eth': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'daniel_goldsmth': {'in': 1, 'out': 33, 'ratio': 0.029411764705882353},
#  'danilo_liuzzi': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'danilushkinaed1': {'in': 0, 'out': 0, 'ratio': 0},
#  'darden2032': {'in': 0, 'out': 0, 'ratio': 0},
#  'dariomarmo_lama': {'in': 54, 'out': 110, 'ratio': 0.32926829268292684},
#  'darko_darkoa': {'in': 1, 'out': 9, 'ratio': 0.1},
#  'dataforpolicy': {'in': 5, 'out': 122, 'ratio': 0.03937007874015748},
#  'davidecellai': {'in': 8, 'out': 164, 'ratio': 0.046511627906976744},
#  'destiny_dii': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'dgpapanikas': {'in': 43, 'out': 32, 'ratio': 0.5733333333333334},
#  'dindjic': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'dlacalle_IA': {'in': 2, 'out': 66, 'ratio': 0.029411764705882353},
#  'dormiveglia': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'dpcwiseman': {'in': 9, 'out': 151, 'ratio': 0.05625},
#  'dsuker': {'in': 0, 'out': 49, 'ratio': 0.0},
#  'duyennguyen286': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'e77876519af54a6': {'in': 0, 'out': 100, 'ratio': 0.0},
#  'economics_twitr': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'ecozzo': {'in': 10, 'out': 154, 'ratio': 0.06097560975609756},
#  'edzaizvobwo': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'egbr916': {'in': 5, 'out': 190, 'ratio': 0.02564102564102564},
#  'eleni_choidas': {'in': 6, 'out': 124, 'ratio': 0.046153846153846156},
#  'elifgunduzyeli': {'in': 0, 'out': 149, 'ratio': 0.0},
#  'elisa_letizia': {'in': 3, 'out': 25, 'ratio': 0.10714285714285714},
#  'elisa_omodei': {'in': 23, 'out': 93, 'ratio': 0.19827586206896552},
#  'emacampiglio': {'in': 22, 'out': 74, 'ratio': 0.22916666666666666},
#  'emergir_co': {'in': 4, 'out': 39, 'ratio': 0.09302325581395349},
#  'energynewsnowtv': {'in': 76, 'out': 7, 'ratio': 0.9156626506024096},
#  'envproceng': {'in': 0, 'out': 0, 'ratio': 0},
#  'enzomanzo1': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'epathlo': {'in': 0, 'out': 0, 'ratio': 0},
#  'er_chechi': {'in': 18, 'out': 6, 'ratio': 0.75},
#  'eric_vanpraag': {'in': 10, 'out': 180, 'ratio': 0.05263157894736842},
#  'eswissolar': {'in': 1, 'out': 3, 'ratio': 0.25},
#  'eurohumph': {'in': 0, 'out': 106, 'ratio': 0.0},
#  'ey0758': {'in': 0, 'out': 0, 'ratio': 0},
#  'f_bontadini': {'in': 11, 'out': 166, 'ratio': 0.062146892655367235},
#  'fabiofxvanni': {'in': 18, 'out': 14, 'ratio': 0.5625},
#  'fbonmatiB': {'in': 0, 'out': 187, 'ratio': 0.0},
#  'feducaydesarrol': {'in': 74, 'out': 4, 'ratio': 0.9487179487179487},
#  'ferminserrano': {'in': 0, 'out': 48, 'ratio': 0.0},
#  'fet_eu': {'in': 26, 'out': 64, 'ratio': 0.28888888888888886},
#  'filevaig41': {'in': 0, 'out': 0, 'ratio': 0},
#  'filipe2747': {'in': 0, 'out': 102, 'ratio': 0.0},
#  'filippoaddarii': {'in': 26, 'out': 93, 'ratio': 0.2184873949579832},
#  'firth_john': {'in': 1, 'out': 138, 'ratio': 0.007194244604316547},
#  'flaskn6': {'in': 12, 'out': 19, 'ratio': 0.3870967741935484},
#  'flipparini': {'in': 67, 'out': 63, 'ratio': 0.5153846153846153},
#  'forfinancewatch': {'in': 12, 'out': 93, 'ratio': 0.11428571428571428},
#  'fotinipolichro': {'in': 0, 'out': 0, 'ratio': 0},
#  'francrsci': {'in': 0, 'out': 0, 'ratio': 0},
#  'fun_rich': {'in': 0, 'out': 49, 'ratio': 0.0},
#  'futsofwelfare': {'in': 0, 'out': 152, 'ratio': 0.0},
#  'gagliol': {'in': 1, 'out': 142, 'ratio': 0.006993006993006993},
#  'galeanojav': {'in': 9, 'out': 157, 'ratio': 0.05421686746987952},
#  'gary6115': {'in': 0, 'out': 0, 'ratio': 0},
#  'gbracci_des': {'in': 3, 'out': 55, 'ratio': 0.05172413793103448},
#  'georguensberg': {'in': 3, 'out': 55, 'ratio': 0.05172413793103448},
#  'georsara11': {'in': 1, 'out': 19, 'ratio': 0.05},
#  'germanacanzi': {'in': 0, 'out': 141, 'ratio': 0.0},
#  'gerrad12456789': {'in': 0, 'out': 0, 'ratio': 0},
#  'giacomo_rella': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'giacomolivan': {'in': 2, 'out': 42, 'ratio': 0.045454545454545456},
#  'giannismanidis1': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'gilologi': {'in': 0, 'out': 40, 'ratio': 0.0},
#  'giorgosvarzelio': {'in': 0, 'out': 0, 'ratio': 0},
#  'giuliaporino': {'in': 2, 'out': 4, 'ratio': 0.3333333333333333},
#  'globalromance16': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'godinfred': {'in': 4, 'out': 13, 'ratio': 0.23529411764705882},
#  'goldthau': {'in': 0, 'out': 55, 'ratio': 0.0},
#  'gomezramirez_ac': {'in': 1, 'out': 42, 'ratio': 0.023255813953488372},
#  'goodhartlaw': {'in': 0, 'out': 192, 'ratio': 0.0},
#  'greenblut_kris': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'greencareersorg': {'in': 0, 'out': 186, 'ratio': 0.0},
#  'greenetworksco': {'in': 5, 'out': 28, 'ratio': 0.15151515151515152},
#  'greenwinproject': {'in': 27, 'out': 101, 'ratio': 0.2109375},
#  'grippt': {'in': 0, 'out': 0, 'ratio': 0},
#  'guyyeomans': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'gzkbs': {'in': 13, 'out': 11, 'ratio': 0.5416666666666666},
#  'hamzaz': {'in': 13, 'out': 87, 'ratio': 0.13},
#  'hans_taeubler': {'in': 0, 'out': 49, 'ratio': 0.0},
#  'harshalhayat': {'in': 4, 'out': 161, 'ratio': 0.024242424242424242},
#  'helloplanetmars': {'in': 153, 'out': 44, 'ratio': 0.7766497461928934},
#  'heloisa58879287': {'in': 0, 'out': 0, 'ratio': 0},
#  'hjybuptster': {'in': 0, 'out': 99, 'ratio': 0.0},
#  'hsissom': {'in': 0, 'out': 0, 'ratio': 0},
#  'huumanhlc1980': {'in': 0, 'out': 149, 'ratio': 0.0},
#  'i_anag': {'in': 2, 'out': 28, 'ratio': 0.06666666666666667},
#  'iacobet79': {'in': 0, 'out': 0, 'ratio': 0},
#  'ideeverdi': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'igor_mozetic': {'in': 111, 'out': 12, 'ratio': 0.9024390243902439},
#  'ilhanakbas': {'in': 0, 'out': 131, 'ratio': 0.0},
#  'imleslahdin': {'in': 0, 'out': 22, 'ratio': 0.0},
#  'impactdottech': {'in': 1, 'out': 110, 'ratio': 0.009009009009009009},
#  'impactvesting': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'impaqt_io': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'imsumitchouhan': {'in': 1, 'out': 158, 'ratio': 0.006289308176100629},
#  'indy_johar': {'in': 0, 'out': 180, 'ratio': 0.0},
#  'iormazabali': {'in': 2, 'out': 184, 'ratio': 0.010752688172043012},
#  'ivan8848': {'in': 11, 'out': 119, 'ratio': 0.08461538461538462},
#  'ivancitocostasm': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'jarekkla': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'jferretm': {'in': 7, 'out': 150, 'ratio': 0.044585987261146494},
#  'jgliu626': {'in': 0, 'out': 0, 'ratio': 0},
#  'jimodonnell2': {'in': 1, 'out': 96, 'ratio': 0.010309278350515464},
#  'jiyanstorymovie': {'in': 0, 'out': 0, 'ratio': 0},
#  'jkpaulin': {'in': 0, 'out': 60, 'ratio': 0.0},
#  'jlmateos': {'in': 15, 'out': 120, 'ratio': 0.1111111111111111},
#  'jmblanch': {'in': 4, 'out': 185, 'ratio': 0.021164021164021163},
#  'jnode': {'in': 10, 'out': 73, 'ratio': 0.12048192771084337},
#  'joaquimfialho19': {'in': 0, 'out': 0, 'ratio': 0},
#  'joelcomm': {'in': 0, 'out': 21, 'ratio': 0.0},
#  'johemart55': {'in': 12, 'out': 158, 'ratio': 0.07058823529411765},
#  'johnbirdswords': {'in': 4, 'out': 82, 'ratio': 0.046511627906976744},
#  'joostmulder': {'in': 3, 'out': 32, 'ratio': 0.08571428571428572},
#  'jordywos': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'joseph_sattler': {'in': 0, 'out': 158, 'ratio': 0.0},
#  'juancerdap': {'in': 0, 'out': 120, 'ratio': 0.0},
#  'jviver': {'in': 4, 'out': 54, 'ratio': 0.06896551724137931},
#  'kaliterilamia': {'in': 0, 'out': 0, 'ratio': 0},
#  'karlape45': {'in': 0, 'out': 181, 'ratio': 0.0},
#  'katausten': {'in': 0, 'out': 86, 'ratio': 0.0},
#  'kate3lakes': {'in': 0, 'out': 74, 'ratio': 0.0},
#  'kevinpuisieux': {'in': 0, 'out': 12, 'ratio': 0.0},
#  'koptermaharania': {'in': 0, 'out': 0, 'ratio': 0},
#  'kostasdimou5': {'in': 0, 'out': 0, 'ratio': 0},
#  'kostasgal50': {'in': 0, 'out': 0, 'ratio': 0},
#  'kostastt1': {'in': 0, 'out': 0, 'ratio': 0},
#  'kosttttoziss': {'in': 0, 'out': 0, 'ratio': 0},
#  'kurganskayapos': {'in': 0, 'out': 0, 'ratio': 0},
#  'laografikos': {'in': 0, 'out': 0, 'ratio': 0},
#  'larryclane': {'in': 0, 'out': 0, 'ratio': 0},
#  'laurasabatini3': {'in': 0, 'out': 196, 'ratio': 0.0},
#  'laurentbaheux': {'in': 116, 'out': 51, 'ratio': 0.6946107784431138},
#  'laurettaeliana': {'in': 6, 'out': 24, 'ratio': 0.2},
#  'lectureverb': {'in': 22, 'out': 6, 'ratio': 0.7857142857142857},
#  'lgaalves': {'in': 25, 'out': 145, 'ratio': 0.14705882352941177},
#  'licht_anna': {'in': 1, 'out': 1, 'ratio': 0.5},
#  'lilitpopoyan': {'in': 125, 'out': 30, 'ratio': 0.8064516129032258},
#  'lindod1972': {'in': 1, 'out': 24, 'ratio': 0.04},
#  'lista_redes': {'in': 1, 'out': 74, 'ratio': 0.013333333333333334},
#  'lperodabasioglu': {'in': 0, 'out': 0, 'ratio': 0},
#  'm_dalp': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'm_waeck': {'in': 5, 'out': 84, 'ratio': 0.056179775280898875},
#  'maggie_q_q': {'in': 0, 'out': 0, 'ratio': 0},
#  'mallenbaker': {'in': 1, 'out': 66, 'ratio': 0.014925373134328358},
#  'manlius84': {'in': 6, 'out': 107, 'ratio': 0.05309734513274336},
#  'manuelhurt': {'in': 0, 'out': 0, 'ratio': 0},
#  'marcobardoscia': {'in': 13, 'out': 53, 'ratio': 0.19696969696969696},
#  'marcoderrico': {'in': 0, 'out': 0, 'ratio': 0},
#  'marcos_mancini': {'in': 4, 'out': 148, 'ratio': 0.02631578947368421},
#  'marialaxa541': {'in': 4, 'out': 6, 'ratio': 0.4},
#  'mariusjoh': {'in': 0, 'out': 42, 'ratio': 0.0},
#  'marlin_meier': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'mateusevil10': {'in': 0, 'out': 0, 'ratio': 0},
#  'maxidana1': {'in': 1, 'out': 4, 'ratio': 0.2},
#  'mennoliauw': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'mercadomagico': {'in': 41, 'out': 70, 'ratio': 0.36936936936936937},
#  'michele_slowey': {'in': 0, 'out': 0, 'ratio': 0},
#  'mientje1000000': {'in': 2, 'out': 0, 'ratio': 1.0},
#  'mike_n_martin': {'in': 1, 'out': 101, 'ratio': 0.00980392156862745},
#  'min_standardism': {'in': 0, 'out': 53, 'ratio': 0.0},
#  'mireillmartini': {'in': 11, 'out': 133, 'ratio': 0.0763888888888889},
#  'miromarchi': {'in': 0, 'out': 171, 'ratio': 0.0},
#  'mixalis_papako': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'mkhm': {'in': 0, 'out': 0, 'ratio': 0},
#  'mm1112322234': {'in': 0, 'out': 73, 'ratio': 0.0},
#  'mnapoletano1': {'in': 120, 'out': 33, 'ratio': 0.7843137254901961},
#  'monicanagore': {'in': 52, 'out': 67, 'ratio': 0.4369747899159664},
#  'moritszsz': {'in': 5, 'out': 134, 'ratio': 0.03597122302158273},
#  'mqdicer': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'mszll': {'in': 3, 'out': 114, 'ratio': 0.02564102564102564},
#  'multiplex_fet': {'in': 5, 'out': 1, 'ratio': 0.8333333333333334},
#  'mvly3': {'in': 0, 'out': 170, 'ratio': 0.0},
#  'my_pochemuchka': {'in': 0, 'out': 50, 'ratio': 0.0},
#  'mydailynews24': {'in': 0, 'out': 0, 'ratio': 0},
#  'n33dstfu': {'in': 0, 'out': 0, 'ratio': 0},
#  'nachoenblanco': {'in': 2, 'out': 59, 'ratio': 0.03278688524590164},
#  'nalsrarekli': {'in': 0, 'out': 161, 'ratio': 0.0},
#  'nanumyan': {'in': 3, 'out': 79, 'ratio': 0.036585365853658534},
#  'netizait': {'in': 0, 'out': 0, 'ratio': 0},
#  'netsci15': {'in': 26, 'out': 174, 'ratio': 0.13},
#  'netsci2017': {'in': 9, 'out': 95, 'ratio': 0.08653846153846154},
#  'ngominhthanh4': {'in': 0, 'out': 137, 'ratio': 0.0},
#  'nicolerycroft1': {'in': 0, 'out': 37, 'ratio': 0.0},
#  'nyaghouti': {'in': 0, 'out': 0, 'ratio': 0},
#  'oddsku007': {'in': 31, 'out': 0, 'ratio': 1.0},
#  'oikonomopoulo14': {'in': 6, 'out': 11, 'ratio': 0.35294117647058826},
#  'oil_products': {'in': 0, 'out': 12, 'ratio': 0.0},
#  'olivierhoedeman': {'in': 2, 'out': 197, 'ratio': 0.010050251256281407},
#  'openmaker': {'in': 16, 'out': 107, 'ratio': 0.13008130081300814},
#  'openp2pdesign': {'in': 4, 'out': 172, 'ratio': 0.022727272727272728},
#  'orbassano2000': {'in': 0, 'out': 171, 'ratio': 0.0},
#  'oskayipek': {'in': 0, 'out': 159, 'ratio': 0.0},
#  'p_chiocchetti': {'in': 4, 'out': 41, 'ratio': 0.08888888888888889},
#  'p_messages': {'in': 0, 'out': 62, 'ratio': 0.0},
#  'palabresgroup': {'in': 2, 'out': 27, 'ratio': 0.06896551724137931},
#  'palpi643': {'in': 0, 'out': 172, 'ratio': 0.0},
#  'panchulzz': {'in': 0, 'out': 0, 'ratio': 0},
#  'panteshkinati8': {'in': 0, 'out': 0, 'ratio': 0},
#  'parraguezr': {'in': 1, 'out': 96, 'ratio': 0.010309278350515464},
#  'partickaya7wa1': {'in': 0, 'out': 0, 'ratio': 0},
#  'pdjahnke': {'in': 2, 'out': 42, 'ratio': 0.045454545454545456},
#  'ph_desfosses': {'in': 1, 'out': 21, 'ratio': 0.045454545454545456},
#  'pikosapikosgr': {'in': 0, 'out': 0, 'ratio': 0},
#  'plusvaluetweets': {'in': 38, 'out': 36, 'ratio': 0.5135135135135135},
#  'poesiaculina': {'in': 4, 'out': 0, 'ratio': 1.0},
#  'popeye4__': {'in': 0, 'out': 0, 'ratio': 0},
#  'prabprab': {'in': 0, 'out': 74, 'ratio': 0.0},
#  'promitmoitra': {'in': 0, 'out': 86, 'ratio': 0.0},
#  'querforscher': {'in': 29, 'out': 34, 'ratio': 0.4603174603174603},
#  'r0guetrainer': {'in': 6, 'out': 60, 'ratio': 0.09090909090909091},
#  'rcabinte': {'in': 4, 'out': 133, 'ratio': 0.029197080291970802},
#  'recofunghi': {'in': 2, 'out': 32, 'ratio': 0.058823529411764705},
#  'renesugar': {'in': 0, 'out': 66, 'ratio': 0.0},
#  'repecCitEc': {'in': 20, 'out': 159, 'ratio': 0.11173184357541899},
#  'resume_unilu': {'in': 0, 'out': 116, 'ratio': 0.0},
#  'rgod777': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'ricardo11701135': {'in': 0, 'out': 0, 'ratio': 0},
#  'riddick19811': {'in': 0, 'out': 0, 'ratio': 0},
#  'rubene822': {'in': 0, 'out': 0, 'ratio': 0},
#  'saitej786': {'in': 0, 'out': 186, 'ratio': 0.0},
#  'sambaravioli': {'in': 0, 'out': 37, 'ratio': 0.0},
#  'sandrosapio': {'in': 3, 'out': 15, 'ratio': 0.16666666666666666},
#  'sarahncorry': {'in': 5, 'out': 73, 'ratio': 0.0641025641025641},
#  'sarresd8': {'in': 0, 'out': 0, 'ratio': 0},
#  'sartin': {'in': 0, 'out': 102, 'ratio': 0.0},
#  'saxorut': {'in': 0, 'out': 126, 'ratio': 0.0},
#  'schulte_stef': {'in': 1, 'out': 10, 'ratio': 0.09090909090909091},
#  'sconquer8': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'sebastienwathle': {'in': 0, 'out': 0, 'ratio': 0},
#  'sees_lab': {'in': 27, 'out': 108, 'ratio': 0.2},
#  'sergiocabrero': {'in': 0, 'out': 144, 'ratio': 0.0},
#  'shakgohir': {'in': 0, 'out': 139, 'ratio': 0.0},
#  'shanegibson': {'in': 0, 'out': 60, 'ratio': 0.0},
#  'shopwearblack': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'simply_jaehyuk': {'in': 0, 'out': 48, 'ratio': 0.0},
#  'sjnwoh': {'in': 1, 'out': 9, 'ratio': 0.1},
#  'smalkina5e1': {'in': 0, 'out': 0, 'ratio': 0},
#  'solarcollab': {'in': 0, 'out': 0, 'ratio': 0},
#  'solarfornia': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'spiros_patelis': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'stefanodigiorg3': {'in': 1, 'out': 36, 'ratio': 0.02702702702702703},
#  'stefatos_kostas': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'stephenkinsella': {'in': 1, 'out': 39, 'ratio': 0.025},
#  'stf18': {'in': 2, 'out': 73, 'ratio': 0.02666666666666667},
#  'strategypod': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'styvencr7': {'in': 0, 'out': 0, 'ratio': 0},
#  'su_re_co': {'in': 11, 'out': 54, 'ratio': 0.16923076923076924},
#  'syaltout': {'in': 0, 'out': 144, 'ratio': 0.0},
#  'syroter_': {'in': 0, 'out': 0, 'ratio': 0},
#  'systemRK': {'in': 5, 'out': 21, 'ratio': 0.19230769230769232},
#  'tachristopoulos': {'in': 0, 'out': 60, 'ratio': 0.0},
#  'takis_kt': {'in': 0, 'out': 146, 'ratio': 0.0},
#  'tarik_rko': {'in': 9, 'out': 69, 'ratio': 0.11538461538461539},
#  'thanhbong06': {'in': 1, 'out': 54, 'ratio': 0.01818181818181818},
#  'the_young_fdn': {'in': 15, 'out': 72, 'ratio': 0.1724137931034483},
#  'theceschi': {'in': 0, 'out': 77, 'ratio': 0.0},
#  'thekokytus': {'in': 0, 'out': 35, 'ratio': 0.0},
#  'thetippytopblog': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'titarchukaj2s': {'in': 0, 'out': 0, 'ratio': 0},
#  'tiveleva4ie': {'in': 0, 'out': 0, 'ratio': 0},
#  'tommaschera': {'in': 0, 'out': 0, 'ratio': 0},
#  'tori_henry2': {'in': 0, 'out': 0, 'ratio': 0},
#  'tozhs': {'in': 0, 'out': 0, 'ratio': 0},
#  'tricks_y': {'in': 0, 'out': 109, 'ratio': 0.0},
#  'trxias': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'uzh_bf': {'in': 10, 'out': 19, 'ratio': 0.3448275862068966},
#  'valteraguiar654': {'in': 16, 'out': 156, 'ratio': 0.09302325581395349},
#  'vectracrome111': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'veronika_st5': {'in': 49, 'out': 6, 'ratio': 0.8909090909090909},
#  'vijayakumarmad6': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'vtchakarova': {'in': 27, 'out': 90, 'ratio': 0.23076923076923078},
#  'xavierhervas': {'in': 1, 'out': 145, 'ratio': 0.00684931506849315},
#  'yanhua_yanhua7': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'yuliay': {'in': 1, 'out': 120, 'ratio': 0.008264462809917356},
#  'yuridayana10': {'in': 0, 'out': 77, 'ratio': 0.0},
#  'zbattiz': {'in': 94, 'out': 36, 'ratio': 0.7230769230769231},
#  'zoozanne': {'in': 0, 'out': 130, 'ratio': 0.0}}

# %%
pp.pprint(RT_Network_Internal_Connected)
# Out:
# {'0ttamatt': {'AndreaRoventini': 3,
#               'GuidoCaldarelli': 6,
#               'ISIgrowth': 1,
#               'Pierre_Monnin': 1,
#               'SimPolProject': 10,
#               'VlPetrovV': 1,
#               'ciro': 1,
#               'cosnet_bifi': 1,
#               'fabiofxvanni': 2,
#               'forfinancewatch': 1,
#               'mnapoletano1': 1,
#               'zbattiz': 3},
#  '2dipicchee': {'Agn_ssa': 3,
#                 'Beyond_Ratings': 1,
#                 'FinexusCenter': 1,
#                 'SimPolProject': 60,
#                 'Transitionway': 1,
#                 'VlPetrovV': 4,
#                 'cosnet_bifi': 1,
#                 'fabiofxvanni': 1,
#                 'fet_eu': 1,
#                 'lilitpopoyan': 1,
#                 'vtchakarova': 1,
#                 'zbattiz': 7},
#  'APRC_CF': {'aparpau': 4},
#  'Agn_ssa': {'SimPolProject': 72,
#              'VlPetrovV': 1,
#              'lilitpopoyan': 1,
#              'zbattiz': 3},
#  'AlanGIsaac': {'cosnet_bifi': 1},
#  'AlessandroLaced': {'MazzucatoM': 1},
#  'AlineCosette': {'AndreaRoventini': 1,
#                   'Complexity_Labs': 1,
#                   'LeanneUssher': 1},
#  'AndreaRoventini': {'Gianlucamisu': 1,
#                      'ISIgrowth': 25,
#                      'Mattia_Guerini': 2,
#                      'MazzucatoM': 4,
#                      'SimPolProject': 34,
#                      'Transitionway': 5,
#                      'arthurturrell': 2,
#                      'fabiofxvanni': 1,
#                      'lilitpopoyan': 2,
#                      'mnapoletano1': 6,
#                      'zbattiz': 2},
#  'AsaBentley': {'johnbirdswords': 5, 'the_young_fdn': 8},
#  'AugustusSouto': {'anxosan': 3},
#  'BUPardeeCenter': {'Transitionway': 1, 'WRIClimate': 6},
#  'Better_Finance': {'joostmulder': 2},
#  'Beyond_Ratings': {'FinforTomorrow': 2},
#  'Bifrostonline': {'WRIClimate': 2},
#  'BingoLittle1': {'D_young_69': 1, 'cosnet_bifi': 2, 'manlius84': 3},
#  'CGraciaLazaro': {'GuidoCaldarelli': 1,
#                    'IBSEN_H2020': 8,
#                    'KoljaKleineberg': 1,
#                    'anxosan': 14,
#                    'ciro': 2,
#                    'cosnet_bifi': 57,
#                    'ferminserrano': 1,
#                    'fet_eu': 1,
#                    'galeanojav': 1},
#  'CMCSatBU': {'anewmediaprof': 14},
#  'CT_Coughlin': {'Seavangelesse': 1},
#  'CardanIOTeam': {'CardanoStiftung': 5},
#  'ChristosEllina1': {'CT_Coughlin': 1,
#                      'KoljaKleineberg': 1,
#                      'adilson_motter': 2,
#                      'cosnet_bifi': 1,
#                      'manlius84': 3,
#                      'mszll': 1},
#  'Climate_Friend': {'SSEinitiative': 2, 'impactvesting': 1},
#  'CoeGSS': {'FcoKienzle': 1,
#             'GuidoCaldarelli': 3,
#             'SimPolProject': 2,
#             'fet_eu': 3},
#  'Complexity_Labs': {'LetsWorkHappy': 6},
#  'CorneliaDaniel': {'georguensberg': 1},
#  'Crypto20183': {'bitlumens': 1},
#  'D_young_69': {'_marameo_': 1},
#  'DarkMatter_Labs': {'indy_johar': 30},
#  'DecentralizedEn': {'DistributedNRG': 3},
#  'DucThiLuu': {'SimPolProject': 24, 'zbattiz': 2},
#  'Duph_Berg': {'L__Macfarlane': 5, 'MazzucatoM': 1, 'Transitionway': 1},
#  'EcologicalEcon': {'Transitionway': 6, 'emacampiglio': 9, 'zbattiz': 1},
#  'FETFX_EU': {'FETFlagships': 2,
#               'Fet2Rin': 8,
#               'MartaCalderaro': 1,
#               'SUPERTWIN_H2020': 1,
#               'fet_eu': 21},
#  'FETFlagships': {'FETFX_EU': 4, 'Fet2Rin': 2, 'fet_eu': 4},
#  'FabriceSabatier': {'SimPolProject': 3,
#                      'filippoaddarii': 1,
#                      'forfinancewatch': 1},
#  'FcoKienzle': {'fet_eu': 17},
#  'Fede_Botta': {'manlius84': 2},
#  'Fet2Rin': {'FETFX_EU': 2, 'FETFlagships': 1, 'fet_eu': 2},
#  'FinforTomorrow': {'Beyond_Ratings': 1, 'UNEP_FI': 1, 'ph_desfosses': 2},
#  'FranciscoICMC': {'CGraciaLazaro': 1,
#                    'adilson_motter': 5,
#                    'cosnet_bifi': 23,
#                    'lgaalves': 3,
#                    'manlius84': 1},
#  'FredAmblard': {'SimulPast': 1, 'manlius84': 1, 'netsci15': 1},
#  'GECoalition': {'LyndaMansson': 1, 'forfinancewatch': 2, 'lindod1972': 1},
#  'GeoVun': {'SimPolProject': 1},
#  'GiachiniDaniele': {'AndreaRoventini': 2,
#                      'ISIgrowth': 1,
#                      'Mattia_Guerini': 1,
#                      'SimPolProject': 100,
#                      'cosnet_bifi': 1,
#                      'fabiofxvanni': 1,
#                      'mnapoletano1': 1,
#                      'zbattiz': 1},
#  'Gianlucamisu': {'MazzucatoM': 1,
#                   'flipparini': 1,
#                   'openmaker': 2,
#                   'plusvaluetweets': 1,
#                   'zbattiz': 1},
#  'Gius_C': {'GuidoCaldarelli': 1,
#             'SimPolProject': 53,
#             'anxosan': 2,
#             'fet_eu': 1},
#  'GochaT69': {'bitlumens': 1},
#  'GuidoCaldarelli': {'2dipicchee': 1,
#                      'FETFlagships': 2,
#                      'Gianlucamisu': 3,
#                      'LuisaDeAmicis': 1,
#                      'SimPolProject': 1,
#                      'Transitionway': 2,
#                      'amanahramadiah': 1,
#                      'anxosan': 1,
#                      'cosnet_bifi': 6,
#                      'filippoaddarii': 1,
#                      'flipparini': 2,
#                      'marcobardoscia': 1,
#                      'mnapoletano1': 1,
#                      'openmaker': 1,
#                      'plusvaluetweets': 3,
#                      'zbattiz': 5},
#  'HamishJWyatt': {'APRC_CF': 28, 'aparpau': 8},
#  'HyacintheBuiss1': {'Transitionway': 1},
#  'IASS_DOLFINS': {'Beyond_Ratings': 1,
#                   'IASS_Potsdam': 2,
#                   'JoeRini6': 1,
#                   'LeanneUssher': 1,
#                   'LuisaDeAmicis': 1,
#                   'PaoloBarucca': 2,
#                   'RogerCremades': 1,
#                   'SimPolProject': 56,
#                   'cosnet_bifi': 1,
#                   'forfinancewatch': 1,
#                   'greenwinproject': 1,
#                   'uzh_bf': 1,
#                   'zbattiz': 2},
#  'IASS_Potsdam': {'IASS_DOLFINS': 1, 'goldthau': 1},
#  'IBSEN_H2020': {'FETFX_EU': 5,
#                  'FETFlagships': 4,
#                  'GuidoCaldarelli': 1,
#                  'SimPolProject': 24,
#                  'UB_ICS': 1,
#                  'anxosan': 20,
#                  'cosnet_bifi': 10,
#                  'fet_eu': 9,
#                  'plusvaluetweets': 1},
#  'ISI_Fondazione': {'ciro': 21, 'cosnet_bifi': 6, 'elisa_omodei': 1},
#  'ISIgrowth': {'AndreaRoventini': 35,
#                'FinexusCenter': 1,
#                'Mattia_Guerini': 1,
#                'MazzucatoM': 9,
#                'SimPolProject': 18,
#                'Transitionway': 1,
#                'fabiofxvanni': 1,
#                'lilitpopoyan': 1,
#                'mnapoletano1': 8,
#                'zbattiz': 5},
#  'JFernandoGRE': {'arthurturrell': 1},
#  'JacopoSestili': {'Complexity_Labs': 1, 'MazzucatoM': 1},
#  'JahelMielke': {'Blueland1': 1,
#                  'EnviroNews': 2,
#                  'SimPolProject': 1,
#                  'mnapoletano1': 1},
#  'James_Vaccaro': {'UNEP_FI': 4, 'forfinancewatch': 1},
#  'KoljaKleineberg': {'anxosan': 2, 'cosnet_bifi': 3, 'zbattiz': 1},
#  'KushyKush': {'greenetworksco': 1},
#  'LDNinst': {'PaoloBarucca': 2, 'SimPolProject': 1},
#  'L__Macfarlane': {'MazzucatoM': 2, 'Pierre_Monnin': 1, 'lindod1972': 1},
#  'LetsWorkHappy': {'Complexity_Labs': 11},
#  'LieveFransen': {'Gianlucamisu': 3,
#                   'filippoaddarii': 1,
#                   'flipparini': 1,
#                   'johnbirdswords': 1,
#                   'plusvaluetweets': 1},
#  'Lsuttors': {'EcologicalEcon': 1,
#               'Pierre_Monnin': 10,
#               'Transitionway': 5,
#               'emacampiglio': 2,
#               'forfinancewatch': 7,
#               'joostmulder': 2,
#               'jviver': 1,
#               'mireillmartini': 2,
#               'schulte_stef': 4},
#  'LuisaDeAmicis': {'SimPolProject': 11,
#                    'Transitionway': 1,
#                    'bplisse': 1,
#                    'dariomarmo_lama': 1,
#                    'filippoaddarii': 3,
#                    'flipparini': 2,
#                    'forfinancewatch': 1,
#                    'monicanagore': 1,
#                    'openmaker': 30,
#                    'plusvaluetweets': 19,
#                    'zbattiz': 2},
#  'LyndaMansson': {'forfinancewatch': 1},
#  'MARGA_GLEZ_FDEZ': {'Gianlucamisu': 1, 'SICommunity_EU': 1},
#  'MacroPru': {'dlacalle_IA': 1, 'mnapoletano1': 1, 'schulte_stef': 1},
#  'Mahfuz__Rahman': {'bitlumens': 5},
#  'Marji84': {'GuidoCaldarelli': 1, 'mireillmartini': 3},
#  'MartaCalderaro': {'FETFX_EU': 21,
#                     'FETFlagships': 5,
#                     'Fet2Rin': 7,
#                     'MazzucatoM': 1,
#                     'SUPERTWIN_H2020': 1,
#                     'aleaf_h2020': 1,
#                     'fet_eu': 37},
#  'MartinaOccelli': {'AndreaRoventini': 1, 'ISIgrowth': 1, 'mnapoletano1': 1},
#  'Mattia_Guerini': {'AndreaRoventini': 9,
#                     'ISIgrowth': 15,
#                     'MazzucatoM': 1,
#                     'SimPolProject': 49,
#                     'Transitionway': 2,
#                     'arthurturrell': 1,
#                     'bplisse': 1,
#                     'cosnet_bifi': 2,
#                     'fabiofxvanni': 4,
#                     'lilitpopoyan': 4,
#                     'mnapoletano1': 10,
#                     'veronika_st5': 1,
#                     'zbattiz': 4},
#  'MazzucatoM': {'ISIgrowth': 2, 'emacampiglio': 1},
#  'MolinariMax_': {'ISIgrowth': 1,
#                   'MacroPru': 2,
#                   'mnapoletano1': 1,
#                   'schulte_stef': 2},
#  'NectuntLab': {'CGraciaLazaro': 5,
#                 'SimPolProject': 1,
#                 'anxosan': 1,
#                 'cosnet_bifi': 30,
#                 'ferminserrano': 2,
#                 'mnapoletano1': 1,
#                 'zbattiz': 2},
#  'NickBeglinger': {'SimPolProject': 1},
#  'Nietzchrodinger': {'cosnet_bifi': 1, 'manlius84': 2},
#  'OnePlanetParis': {'FinforTomorrow': 1},
#  'PaoloBarucca': {'GuidoCaldarelli': 2,
#                   'LDNinst': 3,
#                   'Mattia_Guerini': 1,
#                   'SimPolProject': 8,
#                   'Transitionway': 3,
#                   'cosnet_bifi': 1,
#                   'elisa_omodei': 1,
#                   'mnapoletano1': 1,
#                   'the_young_fdn': 2,
#                   'zbattiz': 2},
#  'Paorazio': {'AndreaRoventini': 1,
#               'fabiofxvanni': 1,
#               'lilitpopoyan': 1,
#               'mnapoletano1': 1},
#  'PetraKraljNovak': {'SimPolProject': 10},
#  'Pierre_Monnin': {'EcologicalEcon': 1,
#                    'Lsuttors': 2,
#                    'MacroPru': 1,
#                    'Transitionway': 5,
#                    'emacampiglio': 2,
#                    'forfinancewatch': 3,
#                    'joostmulder': 1},
#  'PolicyCompassEU': {'7wData': 1, 'fet_eu': 1},
#  'RFIFoundation': {'Climate_Friend': 1, 'UNEP_FI': 1},
#  'RebuildMacro': {'GECoalition': 2,
#                   'MacroPru': 1,
#                   'gbracci_des': 1,
#                   'stephenkinsella': 5},
#  'Registry_Blocks': {'RogervEijk': 1},
#  'RobPasqualino': {'Transitionway': 1, 'zbattiz': 2},
#  'RockJimford': {'MazzucatoM': 1},
#  'RogerCremades': {'MazzucatoM': 1,
#                    'Pierre_Monnin': 3,
#                    'Transitionway': 7,
#                    'adilson_motter': 1,
#                    'firth_john': 1,
#                    'zbattiz': 2},
#  'RogervEijk': {'Registry_Blocks': 10},
#  'RothcoPepp': {'MazzucatoM': 1, 'zbattiz': 1},
#  'SICommunity_EU': {'Gianlucamisu': 3, 'monicanagore': 6, 'the_young_fdn': 5},
#  'SSEinitiative': {'UNEP_FI': 2},
#  'SUPERTWIN_H2020': {'fet_eu': 1},
#  'Seavangelesse': {'SeloSlav': 1},
#  'SeloSlav': {'zbattiz': 1},
#  'SimPolProject': {'2dipicchee': 1,
#                    'Agn_ssa': 1,
#                    'AndreaRoventini': 2,
#                    'EcologicalEcon': 1,
#                    'FETFX_EU': 1,
#                    'FETFlagships': 1,
#                    'GuidoCaldarelli': 2,
#                    'IASS_Potsdam': 1,
#                    'ISIgrowth': 4,
#                    'LindaBach14': 1,
#                    'LuisaDeAmicis': 2,
#                    'Mattia_Guerini': 1,
#                    'MazzucatoM': 2,
#                    'NickBeglinger': 1,
#                    'Pierre_Monnin': 7,
#                    'Transitionway': 26,
#                    'VlPetrovV': 1,
#                    'bitlumens': 4,
#                    'bplisse': 1,
#                    'cosnet_bifi': 1,
#                    'fabiofxvanni': 2,
#                    'fet_eu': 1,
#                    'filippoaddarii': 4,
#                    'flipparini': 1,
#                    'forfinancewatch': 5,
#                    'greenwinproject': 1,
#                    'lilitpopoyan': 3,
#                    'mnapoletano1': 11,
#                    'monicanagore': 5,
#                    'plusvaluetweets': 5,
#                    'the_young_fdn': 2,
#                    'uzh_bf': 2,
#                    'veronika_st5': 1,
#                    'zbattiz': 21},
#  'SodreLuciana': {'crie_ufrj': 2},
#  'StieberHarald': {'SimPolProject': 1, 'katausten': 1},
#  'SusFinLab': {'SFL_nl': 11},
#  'TMWFTE': {'eurohumph': 1},
#  'TehRaio': {'zbattiz': 1},
#  'TheRealShankar': {'manlius84': 1, 'mszll': 1},
#  'TomasBalint': {'SimPolProject': 5},
#  'Transitionway': {'AndreaRoventini': 2,
#                    'BUPardeeCenter': 1,
#                    'EcologicalEcon': 2,
#                    'GuidoCaldarelli': 1,
#                    'Lsuttors': 1,
#                    'MazzucatoM': 1,
#                    'Pierre_Monnin': 3,
#                    'emacampiglio': 2,
#                    'forfinancewatch': 1,
#                    'mnapoletano1': 1,
#                    'veronika_st5': 1,
#                    'zbattiz': 7},
#  'UB_ICS': {'RogerCremades': 1, 'anduviera': 6},
#  'UNEP_FI': {'GECoalition': 1, 'SSEinitiative': 5},
#  'Vibeka': {'filippoaddarii': 1, 'plusvaluetweets': 1},
#  'VlPetrovV': {'SimPolProject': 53},
#  'WelfareUnited': {'greencareersorg': 1},
#  'YannisDafermos': {'AndreaRoventini': 1,
#                     'ISIgrowth': 1,
#                     'MazzucatoM': 1,
#                     'Pierre_Monnin': 3,
#                     'Transitionway': 1,
#                     'emacampiglio': 1,
#                     'zbattiz': 1},
#  'ZhengIsabelle': {'Beyond_Ratings': 1,
#                    'SimPolProject': 35,
#                    'Transitionway': 2,
#                    'VlPetrovV': 1,
#                    'uzh_bf': 1},
#  '_ChiaraPerillo': {'Agn_ssa': 2, 'SimPolProject': 34, 'uzh_bf': 1},
#  '_NicoFrey': {'NickBeglinger': 2, 'SSEinitiative': 2, 'UNEP_FI': 1},
#  '__jasmy': {'SimPolProject': 3},
#  '_ch3m': {'GuidoCaldarelli': 2, 'ciro': 1, 'netsci2017': 1, 'zbattiz': 1},
#  '_marameo_': {'ISI_Fondazione': 1, 'anxosan': 3, 'ciro': 1, 'cosnet_bifi': 3},
#  '_ndrd_': {'jlmateos': 1},
#  'aebiondo': {'AndreaRoventini': 6, 'ISIgrowth': 1, 'Transitionway': 1},
#  'agabardo': {'cosnet_bifi': 1},
#  'aleaf_h2020': {'FETFX_EU': 2, 'fet_eu': 4},
#  'amanahramadiah': {'GuidoCaldarelli': 1, 'LetsWorkHappy': 1},
#  'amritasaha': {'ISIgrowth': 1},
#  'anaishannah': {'NickBeglinger': 2, 'SimPolProject': 1},
#  'andrasonea': {'ISIgrowth': 1, 'forfinancewatch': 1, 'zbattiz': 1},
#  'anduviera': {'UB_ICS': 6,
#                'adilson_motter': 1,
#                'anxosan': 2,
#                'cosnet_bifi': 1,
#                'elisa_omodei': 1,
#                'ferminserrano': 1,
#                'lgaalves': 1,
#                'manlius84': 1},
#  'anewmediaprof': {'CMCSatBU': 2},
#  'angelnunhez': {'anxosan': 4, 'cosnet_bifi': 1, 'manlius84': 2},
#  'anhvan_dz': {'bitlumens': 1},
#  'anxosan': {'anduviera': 1, 'ciro': 2, 'zbattiz': 1},
#  'aparpau': {'APRC_CF': 4},
#  'arthurturrell': {'AndreaRoventini': 2, 'RebuildMacro': 1},
#  'asgeirbt': {'stephenkinsella': 3},
#  'ayazarka88': {'ciro': 2, 'jlmateos': 1, 'manlius84': 1},
#  'aymeric_vie': {'Complexity_Labs': 3,
#                  'LetsWorkHappy': 2,
#                  'Pierre_Monnin': 1,
#                  'SimPolProject': 1,
#                  'adilson_motter': 1,
#                  'fabiofxvanni': 1,
#                  'jkpaulin': 2,
#                  'mnapoletano1': 3},
#  'barcomerni': {'dariomarmo_lama': 1, 'indy_johar': 1},
#  'bastidas_d': {'emacampiglio': 1, 'stf18': 2},
#  'bonosverdes': {'SSEinitiative': 2, 'UNEP_FI': 2},
#  'bplisse': {'IASS_DOLFINS': 2,
#              'ISIgrowth': 1,
#              'SimPolProject': 56,
#              'forfinancewatch': 1,
#              'greenwinproject': 1,
#              'mnapoletano1': 1,
#              'the_young_fdn': 1,
#              'zbattiz': 4},
#  'brianla1': {'Gianlucamisu': 2},
#  'burrolahola': {'EcologicalEcon': 1, 'emacampiglio': 1},
#  'carinacarinas': {'MazzucatoM': 1, 'indy_johar': 1},
#  'carnadani': {'IASS_DOLFINS': 1, 'SimPolProject': 76, 'cosnet_bifi': 1},
#  'cbbagsic': {'MacroPru': 2, 'zbattiz': 1},
#  'ciro': {'CT_Coughlin': 1,
#           'ISI_Fondazione': 2,
#           'cosnet_bifi': 2,
#           'elisa_omodei': 1,
#           'manlius84': 1},
#  'claudia_mihai': {'adilson_motter': 1, 'cosnet_bifi': 1},
#  'complex_warsaw': {'GuidoCaldarelli': 1, 'zbattiz': 1},
#  'cosnet_bifi': {'CGraciaLazaro': 7,
#                  'FinexusCenter': 1,
#                  'FranciscoICMC': 3,
#                  'GuidoCaldarelli': 1,
#                  'IBSEN_H2020': 2,
#                  'ISI_Fondazione': 2,
#                  'KoljaKleineberg': 1,
#                  'LuisaDeAmicis': 1,
#                  'SimPolProject': 1,
#                  'adilson_motter': 1,
#                  'anxosan': 4,
#                  'lgaalves': 1,
#                  'plusvaluetweets': 2},
#  'crie_ufrj': {'SodreLuciana': 12},
#  'daniel_goldsmth': {'cosnet_bifi': 1},
#  'dariomarmo_lama': {'flipparini': 3, 'openmaker': 45, 'plusvaluetweets': 5},
#  'darko_darkoa': {'Transitionway': 1},
#  'davidecellai': {'ISI_Fondazione': 2,
#                   'SimPolProject': 1,
#                   'anxosan': 1,
#                   'cosnet_bifi': 1,
#                   'elisa_omodei': 1,
#                   'marcobardoscia': 2},
#  'dpcwiseman': {'Pierre_Monnin': 1,
#                 'SSEinitiative': 2,
#                 'Transitionway': 2,
#                 'UNEP_FI': 3,
#                 'yuliay': 1},
#  'ecozzo': {'CGraciaLazaro': 2,
#             'anduviera': 1,
#             'anxosan': 3,
#             'ciro': 1,
#             'cosnet_bifi': 3},
#  'eleni_choidas': {'Better_Finance': 1,
#                    'PubAffairsEU': 1,
#                    'SimPolProject': 1,
#                    'UNEP_FI': 1,
#                    'joostmulder': 1,
#                    'schulte_stef': 1},
#  'elisa_letizia': {'SimPolProject': 2, 'cosnet_bifi': 1},
#  'elisa_omodei': {'Fede_Botta': 1,
#                   'anduviera': 1,
#                   'anxosan': 2,
#                   'ciro': 1,
#                   'cosnet_bifi': 1,
#                   'davidecellai': 1,
#                   'fet_eu': 1,
#                   'manlius84': 15},
#  'emacampiglio': {'AndreaRoventini': 1,
#                   'EcologicalEcon': 7,
#                   'Pierre_Monnin': 6,
#                   'SimPolProject': 1,
#                   'Transitionway': 3,
#                   'UNEP_FI': 1,
#                   'YannisDafermos': 2,
#                   'zbattiz': 1},
#  'emergir_co': {'Complexity_Labs': 4},
#  'er_chechi': {'CGraciaLazaro': 2, 'cosnet_bifi': 16},
#  'eric_vanpraag': {'IET_online': 1, 'WRIClimate': 1, 'takis_kt': 1},
#  'f_bontadini': {'AndreaRoventini': 1,
#                  'MazzucatoM': 5,
#                  'amritasaha': 4,
#                  'the_young_fdn': 1},
#  'fabiofxvanni': {'0ttamatt': 1,
#                   'AndreaRoventini': 3,
#                   'ISIgrowth': 2,
#                   'PaoloBarucca': 1,
#                   'SimPolProject': 3,
#                   'Transitionway': 1,
#                   'lilitpopoyan': 4,
#                   'mnapoletano1': 1,
#                   'zbattiz': 1},
#  'fet_eu': {'FETFX_EU': 16,
#             'FETFlagships': 2,
#             'FcoKienzle': 1,
#             'Fet2Rin': 4,
#             'aleaf_h2020': 1,
#             'cosnet_bifi': 1},
#  'filippoaddarii': {'Gianlucamisu': 7,
#                     'LuisaDeAmicis': 1,
#                     'MazzucatoM': 1,
#                     'SimPolProject': 1,
#                     'eurohumph': 1,
#                     'indy_johar': 1,
#                     'openmaker': 4,
#                     'plusvaluetweets': 10},
#  'firth_john': {'UNEP_FI': 1},
#  'flipparini': {'Gianlucamisu': 20,
#                 'GuidoCaldarelli': 1,
#                 'LuisaDeAmicis': 2,
#                 'eurohumph': 1,
#                 'filippoaddarii': 7,
#                 'openmaker': 9,
#                 'openp2pdesign': 1,
#                 'plusvaluetweets': 26},
#  'forfinancewatch': {'GECoalition': 3,
#                      'L__Macfarlane': 2,
#                      'LyndaMansson': 1,
#                      'Transitionway': 1,
#                      'jviver': 3,
#                      'lindod1972': 2},
#  'gagliol': {'HNR_org': 1},
#  'galeanojav': {'GuidoCaldarelli': 1, 'anduviera': 3, 'anxosan': 5},
#  'gbracci_des': {'schulte_stef': 1, 'stf18': 2},
#  'georguensberg': {'Transitionway': 3},
#  'georsara11': {'GuidoCaldarelli': 1},
#  'giacomolivan': {'GuidoCaldarelli': 1, 'cosnet_bifi': 1},
#  'giuliaporino': {'forfinancewatch': 1, 'monicanagore': 1},
#  'godinfred': {'SimPolProject': 4},
#  'greenetworksco': {'KushyKush': 5},
#  'greenwinproject': {'APRC_CF': 1,
#                      'IASS_Potsdam': 13,
#                      'SimPolProject': 6,
#                      'bplisse': 1,
#                      'su_re_co': 5,
#                      'zbattiz': 1},
#  'gzkbs': {'SimPolProject': 11, 'uzh_bf': 2},
#  'hamzaz': {'SimPolProject': 10, 'Transitionway': 1, 'zbattiz': 2},
#  'harshalhayat': {'Complexity_Labs': 3, 'adilson_motter': 1},
#  'helloplanetmars': {'Agn_ssa': 1,
#                      'Beyond_Ratings': 2,
#                      'FETFX_EU': 1,
#                      'FcoKienzle': 1,
#                      'FightInequalit1': 1,
#                      'FinexusCenter': 3,
#                      'GuidoCaldarelli': 1,
#                      'IASS_DOLFINS': 2,
#                      'LuisaDeAmicis': 1,
#                      'Mattia_Guerini': 1,
#                      'MazzucatoM': 1,
#                      'NickBeglinger': 1,
#                      'PaoloBarucca': 2,
#                      'SimPolProject': 97,
#                      'Transitionway': 6,
#                      'VlPetrovV': 6,
#                      'ciro': 2,
#                      'cosnet_bifi': 5,
#                      'fet_eu': 1,
#                      'forfinancewatch': 6,
#                      'germanacanzi': 1,
#                      'greenwinproject': 2,
#                      'plusvaluetweets': 4,
#                      'uzh_bf': 1,
#                      'zbattiz': 4},
#  'i_anag': {'PaoloBarucca': 1, 'SimPolProject': 1},
#  'igor_mozetic': {'SimPolProject': 97,
#                   'Transitionway': 2,
#                   'bplisse': 1,
#                   'cosnet_bifi': 1,
#                   'fet_eu': 1,
#                   'forfinancewatch': 2,
#                   'manlius84': 1,
#                   'plusvaluetweets': 1,
#                   'zbattiz': 5},
#  'imsumitchouhan': {'uzh_bf': 1},
#  'ivan8848': {'vtchakarova': 2},
#  'jarekkla': {'complex_warsaw': 1},
#  'jferretm': {'L__Macfarlane': 1, 'Pierre_Monnin': 5, 'Transitionway': 1},
#  'jlmateos': {'GuidoCaldarelli': 1,
#               'anduviera': 1,
#               'cosnet_bifi': 11,
#               'manlius84': 1},
#  'jmblanch': {'cosnet_bifi': 1, 'jlmateos': 1, 'sees_lab': 2},
#  'jnode': {'SimPolProject': 6,
#            'VlPetrovV': 2,
#            'the_young_fdn': 1,
#            'zbattiz': 1},
#  'johemart55': {'anduviera': 1,
#                 'galeanojav': 2,
#                 'manlius84': 5,
#                 'nachoenblanco': 1,
#                 'netsci2017': 1},
#  'johnbirdswords': {'MazzucatoM': 1},
#  'joostmulder': {'Better_Finance': 2, 'SFL_nl': 1},
#  'jviver': {'forfinancewatch': 4},
#  'laurettaeliana': {'AndreaRoventini': 1,
#                     'BUPardeeCenter': 1,
#                     'Paorazio': 1,
#                     'Transitionway': 2,
#                     'mnapoletano1': 1},
#  'lgaalves': {'FranciscoICMC': 4,
#               'KoljaKleineberg': 1,
#               'adilson_motter': 1,
#               'cosnet_bifi': 14,
#               'elisa_omodei': 1,
#               'manlius84': 1,
#               'sees_lab': 3},
#  'licht_anna': {'SimPolProject': 1},
#  'lilitpopoyan': {'AndreaRoventini': 8,
#                   'ISIgrowth': 5,
#                   'MacroPru': 2,
#                   'Mattia_Guerini': 3,
#                   'PaoloBarucca': 1,
#                   'Pierre_Monnin': 2,
#                   'SimPolProject': 58,
#                   'Transitionway': 9,
#                   'UNEP_FI': 1,
#                   'arthurturrell': 2,
#                   'bitlumens': 1,
#                   'bplisse': 1,
#                   'fabiofxvanni': 4,
#                   'mnapoletano1': 10,
#                   'monicanagore': 1,
#                   'stephenkinsella': 1,
#                   'veronika_st5': 3,
#                   'zbattiz': 13},
#  'lindod1972': {'forfinancewatch': 1},
#  'lista_redes': {'cosnet_bifi': 1},
#  'm_waeck': {'AndreaRoventini': 2,
#              'EcologicalEcon': 1,
#              'SimPolProject': 1,
#              'mnapoletano1': 1},
#  'mallenbaker': {'BradZarnett': 1},
#  'manlius84': {'anduviera': 2, 'cosnet_bifi': 3, 'elisa_omodei': 1},
#  'marcobardoscia': {'GuidoCaldarelli': 8,
#                     'LDNinst': 1,
#                     'SimPolProject': 1,
#                     'sjnwoh': 1,
#                     'zbattiz': 2},
#  'marcos_mancini': {'SSEinitiative': 4},
#  'mireillmartini': {'Pierre_Monnin': 3,
#                     'YannisDafermos': 1,
#                     'dlacalle_IA': 1,
#                     'emacampiglio': 1,
#                     'forfinancewatch': 2,
#                     'ph_desfosses': 2,
#                     'zbattiz': 1},
#  'mnapoletano1': {'2dipicchee': 1,
#                   'Agn_ssa': 1,
#                   'AndreaRoventini': 9,
#                   'Beyond_Ratings': 1,
#                   'GuidoCaldarelli': 2,
#                   'IASS_Potsdam': 1,
#                   'ISIgrowth': 6,
#                   'Mattia_Guerini': 3,
#                   'MazzucatoM': 2,
#                   'RebuildMacro': 1,
#                   'SimPolProject': 70,
#                   'Transitionway': 8,
#                   'WRIClimate': 1,
#                   'arthurturrell': 1,
#                   'fabiofxvanni': 3,
#                   'lilitpopoyan': 1,
#                   'marcobardoscia': 1,
#                   'monicanagore': 1,
#                   'stephenkinsella': 1,
#                   'veronika_st5': 1,
#                   'zbattiz': 4},
#  'monicanagore': {'Gianlucamisu': 1,
#                   'HanKitcher': 1,
#                   'MazzucatoM': 1,
#                   'SICommunity_EU': 10,
#                   'SimPolProject': 1,
#                   'plusvaluetweets': 1,
#                   'the_young_fdn': 33,
#                   'zbattiz': 2},
#  'moritszsz': {'MacroPru': 1,
#                'MazzucatoM': 2,
#                'RebuildMacro': 1,
#                'YannisDafermos': 1},
#  'mszll': {'adilson_motter': 2, 'manlius84': 1},
#  'multiplex_fet': {'SimPolProject': 1, 'fet_eu': 4},
#  'nachoenblanco': {'johemart55': 1, 'netsci2017': 1},
#  'nanumyan': {'ciro': 2, 'cosnet_bifi': 1},
#  'netsci15': {'CGraciaLazaro': 1,
#               'FranciscoICMC': 3,
#               'GuidoCaldarelli': 4,
#               'ISI_Fondazione': 1,
#               'KoljaKleineberg': 1,
#               'Transitionway': 1,
#               'adilson_motter': 1,
#               'ciro': 1,
#               'cosnet_bifi': 12,
#               'giacomolivan': 1},
#  'netsci2017': {'LDNinst': 1,
#                 'PaoloBarucca': 1,
#                 'ciro': 2,
#                 'cosnet_bifi': 1,
#                 'lgaalves': 1,
#                 'mszll': 1},
#  'olivierhoedeman': {'MazzucatoM': 1, 'joostmulder': 1},
#  'openmaker': {'Gianlucamisu': 2,
#                'LuisaDeAmicis': 3,
#                'dariomarmo_lama': 7,
#                'openp2pdesign': 1,
#                'plusvaluetweets': 2,
#                'the_young_fdn': 1},
#  'openp2pdesign': {'KoljaKleineberg': 1,
#                    'adilson_motter': 1,
#                    'ciro': 1,
#                    'openmaker': 1},
#  'p_chiocchetti': {'resume_unilu': 2},
#  'palabresgroup': {'FinforTomorrow': 1},
#  'parraguezr': {'Seavangelesse': 1},
#  'pdjahnke': {'Better_Finance': 1, 'BradZarnett': 1},
#  'ph_desfosses': {'FinforTomorrow': 1},
#  'plusvaluetweets': {'Gianlucamisu': 2,
#                      'LuisaDeAmicis': 2,
#                      'Transitionway': 1,
#                      'filippoaddarii': 19,
#                      'flipparini': 11,
#                      'openmaker': 2,
#                      'openp2pdesign': 1},
#  'querforscher': {'MazzucatoM': 1,
#                   'Pierre_Monnin': 1,
#                   'SimPolProject': 16,
#                   'UNEP_FI': 2,
#                   'forfinancewatch': 2,
#                   'greenwinproject': 4,
#                   'uzh_bf': 1,
#                   'zbattiz': 2},
#  'r0guetrainer': {'RebuildMacro': 1,
#                   'YannisDafermos': 1,
#                   'arthurturrell': 1,
#                   'schulte_stef': 1,
#                   'stephenkinsella': 2},
#  'rcabinte': {'BradZarnett': 1, 'KushyKush': 1, 'MazzucatoM': 2},
#  'sandrosapio': {'AndreaRoventini': 3},
#  'sarahncorry': {'APRC_CF': 3, 'FinforTomorrow': 1, 'UNEP_FI': 1},
#  'sees_lab': {'KoljaKleineberg': 1,
#               'UB_ICS': 6,
#               'adilson_motter': 2,
#               'anduviera': 1,
#               'anxosan': 8,
#               'cosnet_bifi': 3,
#               'ecozzo': 2,
#               'elisa_omodei': 1,
#               'manlius84': 3},
#  'sjnwoh': {'adilson_motter': 1},
#  'stephenkinsella': {'RebuildMacro': 1},
#  'stf18': {'Transitionway': 1},
#  'su_re_co': {'Blueland1': 1, 'greenwinproject': 8},
#  'systemRK': {'FinexusCenter': 3, 'impactvesting': 1, 'zbattiz': 1},
#  'tarik_rko': {'SimPolProject': 2,
#                'forfinancewatch': 1,
#                'gagliol': 1,
#                'mnapoletano1': 1,
#                'mszll': 1,
#                'r0guetrainer': 1,
#                'zbattiz': 2},
#  'thanhbong06': {'bitlumens': 1},
#  'the_young_fdn': {'SICommunity_EU': 2, 'monicanagore': 4},
#  'uzh_bf': {'FinexusCenter': 1,
#             'PaoloBarucca': 1,
#             'SimPolProject': 5,
#             'p_messages': 1,
#             'zbattiz': 2},
#  'veronika_st5': {'2dipicchee': 1,
#                   'GuidoCaldarelli': 1,
#                   'ISIgrowth': 2,
#                   'Mattia_Guerini': 1,
#                   'SimPolProject': 35,
#                   'Transitionway': 1,
#                   'VlPetrovV': 2,
#                   'fabiofxvanni': 1,
#                   'uzh_bf': 1,
#                   'zbattiz': 4},
#  'yuliay': {'UNEP_FI': 1},
#  'zbattiz': {'EcologicalEcon': 1,
#              'FinexusCenter': 1,
#              'GuidoCaldarelli': 3,
#              'ISIgrowth': 4,
#              'LindaBach14': 1,
#              'Pierre_Monnin': 3,
#              'RobPasqualino': 1,
#              'SimPolProject': 10,
#              'Transitionway': 32,
#              'UNEP_FI': 1,
#              'adilson_motter': 1,
#              'bitlumens': 1,
#              'bplisse': 1,
#              'cosnet_bifi': 3,
#              'emacampiglio': 2,
#              'fabiofxvanni': 1,
#              'filippoaddarii': 2,
#              'forfinancewatch': 4,
#              'mnapoletano1': 7,
#              'monicanagore': 3,
#              'plusvaluetweets': 3,
#              'uzh_bf': 2,
#              'veronika_st5': 1}}

# %%
print(len(RT_Network_Internal), len(RT_Network_Internal_Connected), len(RT_Network_Internal_Isolates))
# Out:
# 683 246 437

# %%
RT_Popularity = get_popularity(RT_Network)
RT_Popularity['zbattiz'], RT_Popularity['TheEconomist'], RT_Popularity['SimPolProject'],
# Out:
# (142, 94, 1262)

# %% [markdown]
# #### 5.3 Constructing and analyzing: who-mentions-whom network
#
# - **MentionPopularity** :  Of the all harvested tweets how often the follower is mentioned by the other followers.
# - **MentionInternal** : Of all the mentions by the follower the number of times the follower is mentioning the other followers of the community members.
# - **MentionExternal** : Of all the mentions by the follower the number of times the follower is mentioning the non-followers of the the community members.
# - **MentionCohesion** : The ratio of the internal mentions to the total mentions. The measure can be used as a proxy on 'to what extend the community under investigation is within the focus of the user. A cumulative statistics over all the followers may give an idea on the cohesion between followers.

# %%
Mention_Network = extract_relations(curated, linktype = 'mentions')
Mention_Network_Cohesion = get_cohesion_ratios(Mention_Network, followers)
Mention_Network_Internal = select_subnet(Mention_Network, followers)
Mention_Network_Internal_Connected, Mention_Network_Internal_Isolates = drop_isolates(Mention_Network_Internal)

# %%
pp.pprint(Mention_Network_Cohesion)
# Out:
# {'0ttamatt': {'in': 7, 'out': 6, 'ratio': 0.5384615384615384},
#  '2dipicchee': {'in': 16, 'out': 37, 'ratio': 0.3018867924528302},
#  '4A50CqwsQqeahlq': {'in': 0, 'out': 0, 'ratio': 0},
#  '7softley': {'in': 1, 'out': 19, 'ratio': 0.05},
#  '7wData': {'in': 0, 'out': 18, 'ratio': 0.0},
#  '85Fifteen': {'in': 0, 'out': 83, 'ratio': 0.0},
#  'AEBIOM': {'in': 7, 'out': 66, 'ratio': 0.0958904109589041},
#  'APRC_CF': {'in': 8, 'out': 42, 'ratio': 0.16},
#  'ARNAOYTHSD': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'AdaFerko': {'in': 0, 'out': 94, 'ratio': 0.0},
#  'AdamPC26': {'in': 0, 'out': 52, 'ratio': 0.0},
#  'Adeline_story': {'in': 0, 'out': 0, 'ratio': 0},
#  'Adellibya1979': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'AdolfSanchez5': {'in': 0, 'out': 72, 'ratio': 0.0},
#  'Adoufrancois': {'in': 0, 'out': 0, 'ratio': 0},
#  'Agent_Jase': {'in': 0, 'out': 120, 'ratio': 0.0},
#  'Agn_ssa': {'in': 19, 'out': 34, 'ratio': 0.3584905660377358},
#  'AlanGIsaac': {'in': 0, 'out': 117, 'ratio': 0.0},
#  'AlbertoMunoz': {'in': 0, 'out': 31, 'ratio': 0.0},
#  'AldeiDiogo': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'AlessandroLaced': {'in': 2, 'out': 273, 'ratio': 0.007272727272727273},
#  'Alex_GuerreroR': {'in': 0, 'out': 107, 'ratio': 0.0},
#  'AlineCosette': {'in': 0, 'out': 33, 'ratio': 0.0},
#  'Amanuel40Rui': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'AndreaBindo': {'in': 0, 'out': 33, 'ratio': 0.0},
#  'AndreaRoventini': {'in': 27, 'out': 42, 'ratio': 0.391304347826087},
#  'Andreas_Chile': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'Andrewbrum': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'AngelFe23124123': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'Angela07261976': {'in': 0, 'out': 82, 'ratio': 0.0},
#  'Anna_Hadorn': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'AnneMur16630871': {'in': 0, 'out': 175, 'ratio': 0.0},
#  'AppDeveloperHue': {'in': 0, 'out': 751, 'ratio': 0.0},
#  'ArcmorRib': {'in': 0, 'out': 26, 'ratio': 0.0},
#  'ArnautzPgvila': {'in': 0, 'out': 51, 'ratio': 0.0},
#  'Arturo311311311': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'AsaBentley': {'in': 9, 'out': 208, 'ratio': 0.041474654377880185},
#  'Asmmar1999': {'in': 0, 'out': 0, 'ratio': 0},
#  'AugustusSouto': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'BIntendente': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'BUPardeeCenter': {'in': 0, 'out': 123, 'ratio': 0.0},
#  'Barone54924381': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'BenitoMma': {'in': 3, 'out': 233, 'ratio': 0.012711864406779662},
#  'Benmccreton1': {'in': 0, 'out': 209, 'ratio': 0.0},
#  'Better_Finance': {'in': 2, 'out': 113, 'ratio': 0.017391304347826087},
#  'Beyond_Ratings': {'in': 30, 'out': 271, 'ratio': 0.09966777408637874},
#  'Bifrostonline': {'in': 4, 'out': 53, 'ratio': 0.07017543859649122},
#  'BigDataStackEU': {'in': 1, 'out': 8, 'ratio': 0.1111111111111111},
#  'BingoLittle1': {'in': 1, 'out': 32, 'ratio': 0.030303030303030304},
#  'BlacMambaMMA': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'Blinis': {'in': 0, 'out': 227, 'ratio': 0.0},
#  'Blueland1': {'in': 0, 'out': 66, 'ratio': 0.0},
#  'BluewaterGlobe': {'in': 21, 'out': 30, 'ratio': 0.4117647058823529},
#  'BoekeKatrin': {'in': 0, 'out': 0, 'ratio': 0},
#  'BradZarnett': {'in': 0, 'out': 58, 'ratio': 0.0},
#  'BrainConceptual': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'BsjgMMZetBPIHca': {'in': 0, 'out': 146, 'ratio': 0.0},
#  'BusinessPartnrs': {'in': 0, 'out': 37, 'ratio': 0.0},
#  'ByGeorgePerr': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'CASAPUEBLO8': {'in': 0, 'out': 13, 'ratio': 0.0},
#  'CCL_Aus': {'in': 1, 'out': 122, 'ratio': 0.008130081300813009},
#  'CGraciaLazaro': {'in': 21, 'out': 60, 'ratio': 0.25925925925925924},
#  'CMCSatBU': {'in': 3, 'out': 190, 'ratio': 0.015544041450777202},
#  'CT_Coughlin': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'CanddyShawn': {'in': 0, 'out': 83, 'ratio': 0.0},
#  'CanvasVC': {'in': 1, 'out': 112, 'ratio': 0.008849557522123894},
#  'CardanIOTeam': {'in': 2, 'out': 2, 'ratio': 0.5},
#  'CardanoStiftung': {'in': 1, 'out': 159, 'ratio': 0.00625},
#  'CarnesBestia': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'CaroleCasuco': {'in': 1, 'out': 50, 'ratio': 0.0196078431372549},
#  'CasaEdelVicenza': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'Casinos95': {'in': 0, 'out': 0, 'ratio': 0},
#  'Caydennash2': {'in': 0, 'out': 53, 'ratio': 0.0},
#  'CherryEnergy1': {'in': 0, 'out': 79, 'ratio': 0.0},
#  'ChrisGGeorgas': {'in': 0, 'out': 200, 'ratio': 0.0},
#  'ChrisHudgins5': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'ChristosEllina1': {'in': 5, 'out': 83, 'ratio': 0.056818181818181816},
#  'CigeuInfo': {'in': 0, 'out': 0, 'ratio': 0},
#  'Climate_Friend': {'in': 7, 'out': 185, 'ratio': 0.036458333333333336},
#  'CoeGSS': {'in': 6, 'out': 15, 'ratio': 0.2857142857142857},
#  'Complexity_Labs': {'in': 5, 'out': 38, 'ratio': 0.11627906976744186},
#  'Concerns_You': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'CorneliaDaniel': {'in': 0, 'out': 254, 'ratio': 0.0},
#  'CriptodivisasMx': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'Crypto20183': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'CyprusInno': {'in': 0, 'out': 96, 'ratio': 0.0},
#  'DELPHIBG': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'D_young_69': {'in': 4, 'out': 130, 'ratio': 0.029850746268656716},
#  'Daimakaimura': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'DarkMatter_Labs': {'in': 70, 'out': 2, 'ratio': 0.9722222222222222},
#  'DatingCH': {'in': 0, 'out': 0, 'ratio': 0},
#  'DeboyJames21': {'in': 0, 'out': 100, 'ratio': 0.0},
#  'DecentralizedEn': {'in': 0, 'out': 32, 'ratio': 0.0},
#  'DeepestLearning': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'Demon666Yt': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'DiabetesDaisy': {'in': 0, 'out': 183, 'ratio': 0.0},
#  'DimasSetyadi5': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'DinoFiorita': {'in': 1, 'out': 24, 'ratio': 0.04},
#  'DistributedNRG': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'DougThorpe_com': {'in': 0, 'out': 192, 'ratio': 0.0},
#  'DrDrossosDem': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'Drideologie': {'in': 0, 'out': 157, 'ratio': 0.0},
#  'DucThiLuu': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'Duph_Berg': {'in': 0, 'out': 0, 'ratio': 0},
#  'DustyTweak': {'in': 0, 'out': 0, 'ratio': 0},
#  'EERwtUeb7HgG8pf': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'EHillBrody': {'in': 0, 'out': 0, 'ratio': 0},
#  'EarthWatt': {'in': 0, 'out': 61, 'ratio': 0.0},
#  'Easyimpresa1': {'in': 0, 'out': 0, 'ratio': 0},
#  'EcologicalEcon': {'in': 4, 'out': 32, 'ratio': 0.1111111111111111},
#  'Eindhoven60': {'in': 0, 'out': 190, 'ratio': 0.0},
#  'Elcada_GmbH': {'in': 0, 'out': 66, 'ratio': 0.0},
#  'EmreYakr1': {'in': 0, 'out': 196, 'ratio': 0.0},
#  'EnviroNews': {'in': 18, 'out': 337, 'ratio': 0.05070422535211268},
#  'Etp4H': {'in': 21, 'out': 110, 'ratio': 0.16030534351145037},
#  'EuroLuckyStars': {'in': 0, 'out': 0, 'ratio': 0},
#  'FETFX_EU': {'in': 27, 'out': 56, 'ratio': 0.3253012048192771},
#  'FETFlagships': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'FabioCarrirolo': {'in': 0, 'out': 20, 'ratio': 0.0},
#  'FabriceSabatier': {'in': 1, 'out': 25, 'ratio': 0.038461538461538464},
#  'Falco810': {'in': 0, 'out': 214, 'ratio': 0.0},
#  'FcoKienzle': {'in': 42, 'out': 308, 'ratio': 0.12},
#  'Fede_Botta': {'in': 5, 'out': 121, 'ratio': 0.03968253968253968},
#  'Fet2Rin': {'in': 168, 'out': 448, 'ratio': 0.2727272727272727},
#  'FightInequalit1': {'in': 0, 'out': 12, 'ratio': 0.0},
#  'Filipata__': {'in': 0, 'out': 128, 'ratio': 0.0},
#  'FinexusCenter': {'in': 9, 'out': 3, 'ratio': 0.75},
#  'FinforTomorrow': {'in': 9, 'out': 184, 'ratio': 0.046632124352331605},
#  'FiramisCompany': {'in': 10, 'out': 35, 'ratio': 0.2222222222222222},
#  'FootnoteMedia': {'in': 0, 'out': 268, 'ratio': 0.0},
#  'FoundationRMF': {'in': 5, 'out': 429, 'ratio': 0.01152073732718894},
#  'Frances11022994': {'in': 0, 'out': 20, 'ratio': 0.0},
#  'FranciscoICMC': {'in': 11, 'out': 27, 'ratio': 0.2894736842105263},
#  'FredAmblard': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'FutSciNow': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'GECoalition': {'in': 0, 'out': 166, 'ratio': 0.0},
#  'Gabriel_Hatem': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'GautierChauvin': {'in': 0, 'out': 0, 'ratio': 0},
#  'GeoVun': {'in': 2, 'out': 45, 'ratio': 0.0425531914893617},
#  'GiachiniDaniele': {'in': 0, 'out': 0, 'ratio': 0},
#  'Gianlucamisu': {'in': 32, 'out': 328, 'ratio': 0.08888888888888889},
#  'Gius_C': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'GladiAAreise': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'GochaT69': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'GuidoCaldarelli': {'in': 30, 'out': 191, 'ratio': 0.13574660633484162},
#  'HNR_org': {'in': 0, 'out': 18, 'ratio': 0.0},
#  'HamishJWyatt': {'in': 5, 'out': 68, 'ratio': 0.0684931506849315},
#  'HanKitcher': {'in': 1, 'out': 216, 'ratio': 0.004608294930875576},
#  'HelenJackson0': {'in': 0, 'out': 85, 'ratio': 0.0},
#  'Helens60': {'in': 0, 'out': 65, 'ratio': 0.0},
#  'HyacintheBuiss1': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'IASS_DOLFINS': {'in': 68, 'out': 40, 'ratio': 0.6296296296296297},
#  'IASS_Potsdam': {'in': 2, 'out': 141, 'ratio': 0.013986013986013986},
#  'IBSEN_H2020': {'in': 27, 'out': 45, 'ratio': 0.375},
#  'IET_online': {'in': 0, 'out': 0, 'ratio': 0},
#  'IMPACT_EV': {'in': 2, 'out': 211, 'ratio': 0.009389671361502348},
#  'IMTipps': {'in': 4, 'out': 0, 'ratio': 1.0},
#  'IOPDAHKA': {'in': 0, 'out': 0, 'ratio': 0},
#  'ISEEORG': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'ISI_Fondazione': {'in': 2, 'out': 31, 'ratio': 0.06060606060606061},
#  'ISIgrowth': {'in': 78, 'out': 70, 'ratio': 0.527027027027027},
#  'Igorsemenoff': {'in': 1, 'out': 509, 'ratio': 0.00196078431372549},
#  'Ika_Midenistis': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'ImpactShapers': {'in': 0, 'out': 31, 'ratio': 0.0},
#  'Inova_Paciente': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'JBPKGSolutions': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'JFernandoGRE': {'in': 0, 'out': 47, 'ratio': 0.0},
#  'JacopoSestili': {'in': 2, 'out': 26, 'ratio': 0.07142857142857142},
#  'JahelMielke': {'in': 6, 'out': 5, 'ratio': 0.5454545454545454},
#  'James_Vaccaro': {'in': 4, 'out': 105, 'ratio': 0.03669724770642202},
#  'JeromeRoch74': {'in': 0, 'out': 84, 'ratio': 0.0},
#  'JoeRini6': {'in': 0, 'out': 344, 'ratio': 0.0},
#  'JofreCarnicer': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'JonathanEcon': {'in': 0, 'out': 0, 'ratio': 0},
#  'JulienHallak': {'in': 0, 'out': 38, 'ratio': 0.0},
#  'KerrieMengersen': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'KimMarln': {'in': 0, 'out': 87, 'ratio': 0.0},
#  'KleineBottleM': {'in': 0, 'out': 0, 'ratio': 0},
#  'KoljaKleineberg': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'KushyKush': {'in': 0, 'out': 120, 'ratio': 0.0},
#  'LDNinst': {'in': 6, 'out': 52, 'ratio': 0.10344827586206896},
#  'LERUnews': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'L__Macfarlane': {'in': 0, 'out': 121, 'ratio': 0.0},
#  'LeadMakelaar': {'in': 2, 'out': 47, 'ratio': 0.04081632653061224},
#  'LeanneUssher': {'in': 2, 'out': 23, 'ratio': 0.08},
#  'LetUsShineNow': {'in': 0, 'out': 0, 'ratio': 0},
#  'LetsWorkHappy': {'in': 12, 'out': 83, 'ratio': 0.12631578947368421},
#  'LieveFransen': {'in': 1, 'out': 112, 'ratio': 0.008849557522123894},
#  'LindaBach14': {'in': 2, 'out': 37, 'ratio': 0.05128205128205128},
#  'Lori_McNeill': {'in': 0, 'out': 85, 'ratio': 0.0},
#  'LostInMath': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'Louisbarla': {'in': 0, 'out': 0, 'ratio': 0},
#  'Lsuttors': {'in': 22, 'out': 70, 'ratio': 0.2391304347826087},
#  'LucieKirstein': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'LuisaDeAmicis': {'in': 59, 'out': 125, 'ratio': 0.32065217391304346},
#  'LyndaMansson': {'in': 3, 'out': 68, 'ratio': 0.04225352112676056},
#  'MARGA_GLEZ_FDEZ': {'in': 0, 'out': 32, 'ratio': 0.0},
#  'MARIASOLOMONID2': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'MBMConsultancy': {'in': 0, 'out': 351, 'ratio': 0.0},
#  'MPA37855265': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'MacroPru': {'in': 2, 'out': 240, 'ratio': 0.008264462809917356},
#  'Mahfuz__Rahman': {'in': 0, 'out': 60, 'ratio': 0.0},
#  'MariaBejaCosta1': {'in': 32, 'out': 211, 'ratio': 0.13168724279835392},
#  'MariaMariliam23': {'in': 0, 'out': 0, 'ratio': 0},
#  'Marji84': {'in': 1, 'out': 183, 'ratio': 0.005434782608695652},
#  'MarlonMasine': {'in': 2, 'out': 23, 'ratio': 0.08},
#  'MartaCalderaro': {'in': 8, 'out': 18, 'ratio': 0.3076923076923077},
#  'MartinaOccelli': {'in': 0, 'out': 52, 'ratio': 0.0},
#  'Mattia_Guerini': {'in': 14, 'out': 20, 'ratio': 0.4117647058823529},
#  'Maxknew': {'in': 0, 'out': 100, 'ratio': 0.0},
#  'MazzucatoM': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'MiaPhlor': {'in': 0, 'out': 0, 'ratio': 0},
#  'MichaelRFerrari': {'in': 0, 'out': 64, 'ratio': 0.0},
#  'MichellLiberty': {'in': 0, 'out': 0, 'ratio': 0},
#  'MiguelBasire': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'MikeOConnor3': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'MitchDOPEcom': {'in': 0, 'out': 0, 'ratio': 0},
#  'Mlopezforero': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'MolinariMax_': {'in': 2, 'out': 53, 'ratio': 0.03636363636363636},
#  'MoneyWAmission': {'in': 1, 'out': 4, 'ratio': 0.2},
#  'Monithon': {'in': 0, 'out': 20, 'ratio': 0.0},
#  'MorganBeaugrand': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'NectuntLab': {'in': 0, 'out': 0, 'ratio': 0},
#  'NgulunguT': {'in': 0, 'out': 0, 'ratio': 0},
#  'NickBeglinger': {'in': 0, 'out': 156, 'ratio': 0.0},
#  'NickJackson81': {'in': 5, 'out': 56, 'ratio': 0.08196721311475409},
#  'Nietzchrodinger': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'NomosCSP': {'in': 1, 'out': 533, 'ratio': 0.0018726591760299626},
#  'OVESCO': {'in': 11, 'out': 58, 'ratio': 0.15942028985507245},
#  'Oleatopia': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'OlgaBuchholz': {'in': 0, 'out': 0, 'ratio': 0},
#  'OneClickSolar': {'in': 3, 'out': 32, 'ratio': 0.08571428571428572},
#  'OnePlanetParis': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'OrpheusEU': {'in': 1, 'out': 287, 'ratio': 0.003472222222222222},
#  'PEP4UM': {'in': 0, 'out': 54, 'ratio': 0.0},
#  'PPFEnergia': {'in': 1, 'out': 236, 'ratio': 0.004219409282700422},
#  'PSalazarO': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'PaoloBarucca': {'in': 20, 'out': 72, 'ratio': 0.21739130434782608},
#  'Paorazio': {'in': 3, 'out': 61, 'ratio': 0.046875},
#  'PatrikReisinger': {'in': 0, 'out': 21, 'ratio': 0.0},
#  'PatsonBibou1168': {'in': 0, 'out': 0, 'ratio': 0},
#  'Pedromgi19': {'in': 0, 'out': 0, 'ratio': 0},
#  'PetraKraljNovak': {'in': 1, 'out': 10, 'ratio': 0.09090909090909091},
#  'Peveeeric1': {'in': 30, 'out': 90, 'ratio': 0.25},
#  'PheasantEnergy': {'in': 0, 'out': 0, 'ratio': 0},
#  'Phil5571': {'in': 0, 'out': 0, 'ratio': 0},
#  'PhillipNunnUK': {'in': 0, 'out': 107, 'ratio': 0.0},
#  'PhysScala': {'in': 0, 'out': 0, 'ratio': 0},
#  'Pierre_Monnin': {'in': 22, 'out': 151, 'ratio': 0.12716763005780346},
#  'Platy_Kalamatas': {'in': 0, 'out': 0, 'ratio': 0},
#  'PolatSihab': {'in': 3, 'out': 38, 'ratio': 0.07317073170731707},
#  'PolicyCompassEU': {'in': 3, 'out': 124, 'ratio': 0.023622047244094488},
#  'Project722TMX': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'PubAffairsEU': {'in': 1, 'out': 23, 'ratio': 0.041666666666666664},
#  'REANworld': {'in': 2, 'out': 51, 'ratio': 0.03773584905660377},
#  'RFIFoundation': {'in': 0, 'out': 21, 'ratio': 0.0},
#  'RRytenband': {'in': 0, 'out': 154, 'ratio': 0.0},
#  'RakibEnew': {'in': 0, 'out': 102, 'ratio': 0.0},
#  'RebuildMacro': {'in': 14, 'out': 95, 'ratio': 0.12844036697247707},
#  'Registry_Blocks': {'in': 0, 'out': 59, 'ratio': 0.0},
#  'RitaMaria_dRC': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'RobPasqualino': {'in': 1, 'out': 55, 'ratio': 0.017857142857142856},
#  'RoccaBam': {'in': 0, 'out': 0, 'ratio': 0},
#  'RockJimford': {'in': 0, 'out': 35, 'ratio': 0.0},
#  'RogerCremades': {'in': 0, 'out': 39, 'ratio': 0.0},
#  'RogervEijk': {'in': 0, 'out': 82, 'ratio': 0.0},
#  'RothcoPepp': {'in': 11, 'out': 150, 'ratio': 0.06832298136645963},
#  'RubyBretislav': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'SFL_nl': {'in': 11, 'out': 165, 'ratio': 0.0625},
#  'SICommunity_EU': {'in': 7, 'out': 73, 'ratio': 0.0875},
#  'SSEinitiative': {'in': 1, 'out': 117, 'ratio': 0.00847457627118644},
#  'SUPERTWIN_H2020': {'in': 1, 'out': 41, 'ratio': 0.023809523809523808},
#  'Sandra_G_Urbano': {'in': 0, 'out': 13, 'ratio': 0.0},
#  'Saracris95': {'in': 0, 'out': 285, 'ratio': 0.0},
#  'Sb4GvLAuBrNkc93': {'in': 0, 'out': 0, 'ratio': 0},
#  'Schumannpoet': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'Seavangelesse': {'in': 0, 'out': 89, 'ratio': 0.0},
#  'Sebespejo': {'in': 0, 'out': 78, 'ratio': 0.0},
#  'SelinaStoller': {'in': 0, 'out': 143, 'ratio': 0.0},
#  'SeloSlav': {'in': 0, 'out': 172, 'ratio': 0.0},
#  'ShaunFrankson': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'SiQuizas': {'in': 0, 'out': 108, 'ratio': 0.0},
#  'SimPolProject': {'in': 77, 'out': 47, 'ratio': 0.6209677419354839},
#  'SimonThordal': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'SimulPast': {'in': 10, 'out': 17, 'ratio': 0.37037037037037035},
#  'SodreLuciana': {'in': 3, 'out': 182, 'ratio': 0.016216216216216217},
#  'StarwarsMaker': {'in': 0, 'out': 12, 'ratio': 0.0},
#  'StephaneNappo': {'in': 0, 'out': 0, 'ratio': 0},
#  'StieberHarald': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'SunilMalhotra': {'in': 1, 'out': 284, 'ratio': 0.0035087719298245615},
#  'SusFinLab': {'in': 1, 'out': 27, 'ratio': 0.03571428571428571},
#  'SusieMod88': {'in': 0, 'out': 655, 'ratio': 0.0},
#  'SvyatoslavHrync': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'SwissCognitive': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'TMWFTE': {'in': 1, 'out': 198, 'ratio': 0.005025125628140704},
#  'TSERETELI_0102': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'TagederSonne': {'in': 0, 'out': 22, 'ratio': 0.0},
#  'TehRaio': {'in': 0, 'out': 118, 'ratio': 0.0},
#  'TheRealShankar': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'Thierry_Kame': {'in': 0, 'out': 0, 'ratio': 0},
#  'TiberiuPetre': {'in': 0, 'out': 0, 'ratio': 0},
#  'TipGhosh': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'TomasBalint': {'in': 0, 'out': 33, 'ratio': 0.0},
#  'TorreyShine': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'Transitionway': {'in': 197, 'out': 140, 'ratio': 0.5845697329376854},
#  'UB_ICS': {'in': 17, 'out': 121, 'ratio': 0.12318840579710146},
#  'UNEP_FI': {'in': 86, 'out': 143, 'ratio': 0.37554585152838427},
#  'ValerioVolpati': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'Vangel_artist': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'VeronicaClima': {'in': 0, 'out': 70, 'ratio': 0.0},
#  'Vibeka': {'in': 0, 'out': 79, 'ratio': 0.0},
#  'VilmaBerta17': {'in': 0, 'out': 39, 'ratio': 0.0},
#  'VivereLanzarote': {'in': 0, 'out': 41, 'ratio': 0.0},
#  'VlPetrovV': {'in': 30, 'out': 43, 'ratio': 0.410958904109589},
#  'WJFTechnical': {'in': 10, 'out': 45, 'ratio': 0.18181818181818182},
#  'WOETUK': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'WRIClimate': {'in': 1, 'out': 87, 'ratio': 0.011363636363636364},
#  'WarrenWhitlock': {'in': 3, 'out': 60, 'ratio': 0.047619047619047616},
#  'WelfareUnited': {'in': 9, 'out': 34, 'ratio': 0.20930232558139536},
#  'WiedmannBibel': {'in': 1, 'out': 27, 'ratio': 0.03571428571428571},
#  'Xilbshi': {'in': 0, 'out': 55, 'ratio': 0.0},
#  'YannisDafermos': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'ZeGordon': {'in': 0, 'out': 0, 'ratio': 0},
#  'Zen3dT': {'in': 0, 'out': 0, 'ratio': 0},
#  'ZhengIsabelle': {'in': 0, 'out': 0, 'ratio': 0},
#  'ZoeGold69': {'in': 0, 'out': 298, 'ratio': 0.0},
#  'ZofiaWemanska': {'in': 0, 'out': 0, 'ratio': 0},
#  '_ChiaraPerillo': {'in': 5, 'out': 3, 'ratio': 0.625},
#  '_NicoFrey': {'in': 0, 'out': 54, 'ratio': 0.0},
#  '__jasmy': {'in': 0, 'out': 0, 'ratio': 0},
#  '_ch3m': {'in': 0, 'out': 28, 'ratio': 0.0},
#  '_marameo_': {'in': 0, 'out': 91, 'ratio': 0.0},
#  '_ndrd_': {'in': 1, 'out': 14, 'ratio': 0.06666666666666667},
#  'a_yang_w': {'in': 0, 'out': 0, 'ratio': 0},
#  'adilson_motter': {'in': 2, 'out': 117, 'ratio': 0.01680672268907563},
#  'adria_plazas': {'in': 0, 'out': 233, 'ratio': 0.0},
#  'aebiondo': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'aetw15': {'in': 0, 'out': 0, 'ratio': 0},
#  'afrochia': {'in': 0, 'out': 0, 'ratio': 0},
#  'agabardo': {'in': 0, 'out': 44, 'ratio': 0.0},
#  'ailatan1898': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'ale_marichela': {'in': 0, 'out': 156, 'ratio': 0.0},
#  'aleaf_h2020': {'in': 23, 'out': 140, 'ratio': 0.1411042944785276},
#  'alediemmee': {'in': 1, 'out': 0, 'ratio': 1.0},
#  'alfonso_soldano': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'alp08989139': {'in': 0, 'out': 0, 'ratio': 0},
#  'alvarofenomeno': {'in': 0, 'out': 31, 'ratio': 0.0},
#  'amanahramadiah': {'in': 6, 'out': 82, 'ratio': 0.06818181818181818},
#  'amapr1': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'ambatellova8u9': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'amritasaha': {'in': 5, 'out': 148, 'ratio': 0.032679738562091505},
#  'amsterdam_bill': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'anaishannah': {'in': 1, 'out': 44, 'ratio': 0.022222222222222223},
#  'andkarpf': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'andrasonea': {'in': 0, 'out': 46, 'ratio': 0.0},
#  'anduviera': {'in': 1, 'out': 14, 'ratio': 0.06666666666666667},
#  'anewmediaprof': {'in': 0, 'out': 265, 'ratio': 0.0},
#  'angelnunhez': {'in': 4, 'out': 93, 'ratio': 0.041237113402061855},
#  'anhvan_dz': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'anielloiorio197': {'in': 1, 'out': 111, 'ratio': 0.008928571428571428},
#  'anima_tu': {'in': 0, 'out': 57, 'ratio': 0.0},
#  'anxosan': {'in': 2, 'out': 70, 'ratio': 0.027777777777777776},
#  'aparpau': {'in': 21, 'out': 291, 'ratio': 0.0673076923076923},
#  'arthurturrell': {'in': 0, 'out': 100, 'ratio': 0.0},
#  'asgeirbt': {'in': 0, 'out': 93, 'ratio': 0.0},
#  'aurorab96124853': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'avogli': {'in': 0, 'out': 0, 'ratio': 0},
#  'axekoukou': {'in': 0, 'out': 136, 'ratio': 0.0},
#  'ayazarka88': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'aymeric_vie': {'in': 0, 'out': 0, 'ratio': 0},
#  'bandigsm': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'barcomerni': {'in': 0, 'out': 39, 'ratio': 0.0},
#  'barryejames': {'in': 1, 'out': 141, 'ratio': 0.007042253521126761},
#  'baryshnevadn0': {'in': 0, 'out': 29, 'ratio': 0.0},
#  'bassindales': {'in': 0, 'out': 515, 'ratio': 0.0},
#  'bastidas_d': {'in': 1, 'out': 44, 'ratio': 0.022222222222222223},
#  'bb_pedromartins': {'in': 0, 'out': 43, 'ratio': 0.0},
#  'bdp_smith': {'in': 0, 'out': 102, 'ratio': 0.0},
#  'bellacindylee': {'in': 0, 'out': 55, 'ratio': 0.0},
#  'bergautier': {'in': 0, 'out': 67, 'ratio': 0.0},
#  'bethscleft': {'in': 0, 'out': 57, 'ratio': 0.0},
#  'bginoc': {'in': 2, 'out': 120, 'ratio': 0.01639344262295082},
#  'bh7u86u5tvfsn': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'bitlumens': {'in': 1, 'out': 137, 'ratio': 0.007246376811594203},
#  'bobbyreyes20': {'in': 0, 'out': 65, 'ratio': 0.0},
#  'bonosverdes': {'in': 4, 'out': 79, 'ratio': 0.04819277108433735},
#  'bplisse': {'in': 8, 'out': 5, 'ratio': 0.6153846153846154},
#  'brianehenyo': {'in': 0, 'out': 125, 'ratio': 0.0},
#  'brianla1': {'in': 2, 'out': 178, 'ratio': 0.011111111111111112},
#  'brjmoez': {'in': 0, 'out': 67, 'ratio': 0.0},
#  'bulentozel': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'burrolahola': {'in': 5, 'out': 82, 'ratio': 0.05747126436781609},
#  'camilleoudinot': {'in': 0, 'out': 237, 'ratio': 0.0},
#  'carinacarinas': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'carnadani': {'in': 0, 'out': 0, 'ratio': 0},
#  'cbbagsic': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'chrizau': {'in': 0, 'out': 195, 'ratio': 0.0},
#  'ciro': {'in': 7, 'out': 49, 'ratio': 0.125},
#  'claudia_mihai': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'complex_warsaw': {'in': 14, 'out': 44, 'ratio': 0.2413793103448276},
#  'coonchi14': {'in': 0, 'out': 0, 'ratio': 0},
#  'cosnet_bifi': {'in': 26, 'out': 115, 'ratio': 0.18439716312056736},
#  'crie_ufrj': {'in': 1, 'out': 48, 'ratio': 0.02040816326530612},
#  'daniel_eth': {'in': 0, 'out': 285, 'ratio': 0.0},
#  'daniel_goldsmth': {'in': 4, 'out': 289, 'ratio': 0.013651877133105802},
#  'danilo_liuzzi': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'danilushkinaed1': {'in': 0, 'out': 24, 'ratio': 0.0},
#  'darden2032': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'dariomarmo_lama': {'in': 26, 'out': 77, 'ratio': 0.2524271844660194},
#  'darko_darkoa': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'dataforpolicy': {'in': 0, 'out': 91, 'ratio': 0.0},
#  'davidecellai': {'in': 0, 'out': 13, 'ratio': 0.0},
#  'destiny_dii': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'dgpapanikas': {'in': 0, 'out': 302, 'ratio': 0.0},
#  'dindjic': {'in': 1, 'out': 228, 'ratio': 0.004366812227074236},
#  'dlacalle_IA': {'in': 0, 'out': 145, 'ratio': 0.0},
#  'dormiveglia': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'dpcwiseman': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'dsuker': {'in': 0, 'out': 282, 'ratio': 0.0},
#  'duyennguyen286': {'in': 2, 'out': 18, 'ratio': 0.1},
#  'e77876519af54a6': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'economics_twitr': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'ecozzo': {'in': 2, 'out': 32, 'ratio': 0.058823529411764705},
#  'edzaizvobwo': {'in': 0, 'out': 50, 'ratio': 0.0},
#  'egbr916': {'in': 0, 'out': 0, 'ratio': 0},
#  'eleni_choidas': {'in': 4, 'out': 52, 'ratio': 0.07142857142857142},
#  'elifgunduzyeli': {'in': 0, 'out': 32, 'ratio': 0.0},
#  'elisa_letizia': {'in': 6, 'out': 6, 'ratio': 0.5},
#  'elisa_omodei': {'in': 10, 'out': 97, 'ratio': 0.09345794392523364},
#  'emacampiglio': {'in': 25, 'out': 107, 'ratio': 0.1893939393939394},
#  'emergir_co': {'in': 10, 'out': 225, 'ratio': 0.0425531914893617},
#  'energynewsnowtv': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'envproceng': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'enzomanzo1': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'epathlo': {'in': 0, 'out': 0, 'ratio': 0},
#  'er_chechi': {'in': 0, 'out': 0, 'ratio': 0},
#  'eric_vanpraag': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'eswissolar': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'eurohumph': {'in': 0, 'out': 46, 'ratio': 0.0},
#  'ey0758': {'in': 0, 'out': 0, 'ratio': 0},
#  'f_bontadini': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'fabiofxvanni': {'in': 8, 'out': 64, 'ratio': 0.1111111111111111},
#  'fbonmatiB': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'feducaydesarrol': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'ferminserrano': {'in': 0, 'out': 337, 'ratio': 0.0},
#  'fet_eu': {'in': 36, 'out': 183, 'ratio': 0.1643835616438356},
#  'filevaig41': {'in': 0, 'out': 33, 'ratio': 0.0},
#  'filipe2747': {'in': 0, 'out': 398, 'ratio': 0.0},
#  'filippoaddarii': {'in': 53, 'out': 96, 'ratio': 0.35570469798657717},
#  'firth_john': {'in': 5, 'out': 57, 'ratio': 0.08064516129032258},
#  'flaskn6': {'in': 1, 'out': 85, 'ratio': 0.011627906976744186},
#  'flipparini': {'in': 37, 'out': 128, 'ratio': 0.22424242424242424},
#  'forfinancewatch': {'in': 4, 'out': 84, 'ratio': 0.045454545454545456},
#  'fotinipolichro': {'in': 0, 'out': 0, 'ratio': 0},
#  'francrsci': {'in': 0, 'out': 0, 'ratio': 0},
#  'fun_rich': {'in': 0, 'out': 78, 'ratio': 0.0},
#  'futsofwelfare': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'gagliol': {'in': 0, 'out': 44, 'ratio': 0.0},
#  'galeanojav': {'in': 1, 'out': 34, 'ratio': 0.02857142857142857},
#  'gary6115': {'in': 0, 'out': 207, 'ratio': 0.0},
#  'gbracci_des': {'in': 0, 'out': 1444, 'ratio': 0.0},
#  'georguensberg': {'in': 1, 'out': 137, 'ratio': 0.007246376811594203},
#  'georsara11': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'germanacanzi': {'in': 0, 'out': 115, 'ratio': 0.0},
#  'gerrad12456789': {'in': 0, 'out': 0, 'ratio': 0},
#  'giacomo_rella': {'in': 0, 'out': 0, 'ratio': 0},
#  'giacomolivan': {'in': 13, 'out': 111, 'ratio': 0.10483870967741936},
#  'giannismanidis1': {'in': 0, 'out': 9, 'ratio': 0.0},
#  'gilologi': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'giorgosvarzelio': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'giuliaporino': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'globalromance16': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'godinfred': {'in': 0, 'out': 68, 'ratio': 0.0},
#  'goldthau': {'in': 2, 'out': 107, 'ratio': 0.01834862385321101},
#  'gomezramirez_ac': {'in': 0, 'out': 85, 'ratio': 0.0},
#  'goodhartlaw': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'greenblut_kris': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'greencareersorg': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'greenetworksco': {'in': 2, 'out': 28, 'ratio': 0.06666666666666667},
#  'greenwinproject': {'in': 35, 'out': 75, 'ratio': 0.3181818181818182},
#  'grippt': {'in': 0, 'out': 201, 'ratio': 0.0},
#  'guyyeomans': {'in': 0, 'out': 280, 'ratio': 0.0},
#  'gzkbs': {'in': 0, 'out': 0, 'ratio': 0},
#  'hamzaz': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'hans_taeubler': {'in': 5, 'out': 51, 'ratio': 0.08928571428571429},
#  'harshalhayat': {'in': 0, 'out': 28, 'ratio': 0.0},
#  'helloplanetmars': {'in': 4, 'out': 9, 'ratio': 0.3076923076923077},
#  'heloisa58879287': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'hjybuptster': {'in': 0, 'out': 141, 'ratio': 0.0},
#  'hsissom': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'huumanhlc1980': {'in': 0, 'out': 63, 'ratio': 0.0},
#  'i_anag': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'iacobet79': {'in': 0, 'out': 0, 'ratio': 0},
#  'ideeverdi': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'igor_mozetic': {'in': 0, 'out': 6, 'ratio': 0.0},
#  'ilhanakbas': {'in': 0, 'out': 26, 'ratio': 0.0},
#  'imleslahdin': {'in': 0, 'out': 238, 'ratio': 0.0},
#  'impactdottech': {'in': 2, 'out': 128, 'ratio': 0.015384615384615385},
#  'impactvesting': {'in': 0, 'out': 44, 'ratio': 0.0},
#  'impaqt_io': {'in': 0, 'out': 64, 'ratio': 0.0},
#  'imsumitchouhan': {'in': 0, 'out': 61, 'ratio': 0.0},
#  'indy_johar': {'in': 2, 'out': 17, 'ratio': 0.10526315789473684},
#  'iormazabali': {'in': 0, 'out': 23, 'ratio': 0.0},
#  'ivan8848': {'in': 22, 'out': 40, 'ratio': 0.3548387096774194},
#  'ivancitocostasm': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'jarekkla': {'in': 0, 'out': 0, 'ratio': 0},
#  'jferretm': {'in': 4, 'out': 34, 'ratio': 0.10526315789473684},
#  'jgliu626': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'jimodonnell2': {'in': 0, 'out': 195, 'ratio': 0.0},
#  'jiyanstorymovie': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'jkpaulin': {'in': 0, 'out': 135, 'ratio': 0.0},
#  'jlmateos': {'in': 8, 'out': 132, 'ratio': 0.05714285714285714},
#  'jmblanch': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'jnode': {'in': 21, 'out': 70, 'ratio': 0.23076923076923078},
#  'joaquimfialho19': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'joelcomm': {'in': 0, 'out': 20, 'ratio': 0.0},
#  'johemart55': {'in': 3, 'out': 32, 'ratio': 0.08571428571428572},
#  'johnbirdswords': {'in': 1, 'out': 131, 'ratio': 0.007575757575757576},
#  'joostmulder': {'in': 1, 'out': 402, 'ratio': 0.0024813895781637717},
#  'jordywos': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'joseph_sattler': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'juancerdap': {'in': 0, 'out': 35, 'ratio': 0.0},
#  'jviver': {'in': 20, 'out': 100, 'ratio': 0.16666666666666666},
#  'kaliterilamia': {'in': 0, 'out': 0, 'ratio': 0},
#  'karlape45': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'katausten': {'in': 0, 'out': 107, 'ratio': 0.0},
#  'kate3lakes': {'in': 0, 'out': 105, 'ratio': 0.0},
#  'kevinpuisieux': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'koptermaharania': {'in': 0, 'out': 0, 'ratio': 0},
#  'kostasdimou5': {'in': 0, 'out': 0, 'ratio': 0},
#  'kostasgal50': {'in': 0, 'out': 7, 'ratio': 0.0},
#  'kostastt1': {'in': 0, 'out': 165, 'ratio': 0.0},
#  'kosttttoziss': {'in': 0, 'out': 70, 'ratio': 0.0},
#  'kurganskayapos': {'in': 0, 'out': 26, 'ratio': 0.0},
#  'laografikos': {'in': 0, 'out': 0, 'ratio': 0},
#  'larryclane': {'in': 0, 'out': 0, 'ratio': 0},
#  'laurasabatini3': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'laurentbaheux': {'in': 7, 'out': 58, 'ratio': 0.1076923076923077},
#  'laurettaeliana': {'in': 0, 'out': 15, 'ratio': 0.0},
#  'lectureverb': {'in': 0, 'out': 13, 'ratio': 0.0},
#  'lgaalves': {'in': 1, 'out': 56, 'ratio': 0.017543859649122806},
#  'licht_anna': {'in': 0, 'out': 0, 'ratio': 0},
#  'lilitpopoyan': {'in': 20, 'out': 9, 'ratio': 0.6896551724137931},
#  'lindod1972': {'in': 42, 'out': 360, 'ratio': 0.1044776119402985},
#  'lista_redes': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'lperodabasioglu': {'in': 0, 'out': 0, 'ratio': 0},
#  'm_dalp': {'in': 0, 'out': 10, 'ratio': 0.0},
#  'm_waeck': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'maggie_q_q': {'in': 0, 'out': 0, 'ratio': 0},
#  'mallenbaker': {'in': 1, 'out': 30, 'ratio': 0.03225806451612903},
#  'manlius84': {'in': 5, 'out': 141, 'ratio': 0.03424657534246575},
#  'manuelhurt': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'marcobardoscia': {'in': 45, 'out': 98, 'ratio': 0.3146853146853147},
#  'marcoderrico': {'in': 0, 'out': 0, 'ratio': 0},
#  'marcos_mancini': {'in': 1, 'out': 41, 'ratio': 0.023809523809523808},
#  'marialaxa541': {'in': 0, 'out': 161, 'ratio': 0.0},
#  'mariusjoh': {'in': 0, 'out': 103, 'ratio': 0.0},
#  'marlin_meier': {'in': 0, 'out': 17, 'ratio': 0.0},
#  'mateusevil10': {'in': 0, 'out': 0, 'ratio': 0},
#  'maxidana1': {'in': 0, 'out': 22, 'ratio': 0.0},
#  'mennoliauw': {'in': 1, 'out': 1, 'ratio': 0.5},
#  'mercadomagico': {'in': 42, 'out': 135, 'ratio': 0.23728813559322035},
#  'michele_slowey': {'in': 0, 'out': 0, 'ratio': 0},
#  'mientje1000000': {'in': 0, 'out': 196, 'ratio': 0.0},
#  'mike_n_martin': {'in': 0, 'out': 75, 'ratio': 0.0},
#  'min_standardism': {'in': 2, 'out': 361, 'ratio': 0.005509641873278237},
#  'mireillmartini': {'in': 21, 'out': 11, 'ratio': 0.65625},
#  'miromarchi': {'in': 0, 'out': 52, 'ratio': 0.0},
#  'mixalis_papako': {'in': 1, 'out': 54, 'ratio': 0.01818181818181818},
#  'mkhm': {'in': 0, 'out': 0, 'ratio': 0},
#  'mm1112322234': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'mnapoletano1': {'in': 64, 'out': 58, 'ratio': 0.5245901639344263},
#  'monicanagore': {'in': 86, 'out': 35, 'ratio': 0.7107438016528925},
#  'moritszsz': {'in': 0, 'out': 22, 'ratio': 0.0},
#  'mqdicer': {'in': 1, 'out': 66, 'ratio': 0.014925373134328358},
#  'mszll': {'in': 0, 'out': 109, 'ratio': 0.0},
#  'multiplex_fet': {'in': 9, 'out': 13, 'ratio': 0.4090909090909091},
#  'mvly3': {'in': 0, 'out': 2, 'ratio': 0.0},
#  'my_pochemuchka': {'in': 0, 'out': 32, 'ratio': 0.0},
#  'mydailynews24': {'in': 0, 'out': 0, 'ratio': 0},
#  'n33dstfu': {'in': 0, 'out': 0, 'ratio': 0},
#  'nachoenblanco': {'in': 1, 'out': 24, 'ratio': 0.04},
#  'nalsrarekli': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'nanumyan': {'in': 1, 'out': 21, 'ratio': 0.045454545454545456},
#  'netizait': {'in': 0, 'out': 0, 'ratio': 0},
#  'netsci15': {'in': 0, 'out': 0, 'ratio': 0},
#  'netsci2017': {'in': 0, 'out': 36, 'ratio': 0.0},
#  'ngominhthanh4': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'nicolerycroft1': {'in': 0, 'out': 92, 'ratio': 0.0},
#  'nyaghouti': {'in': 0, 'out': 0, 'ratio': 0},
#  'oddsku007': {'in': 2, 'out': 19, 'ratio': 0.09523809523809523},
#  'oikonomopoulo14': {'in': 0, 'out': 56, 'ratio': 0.0},
#  'oil_products': {'in': 10, 'out': 17, 'ratio': 0.37037037037037035},
#  'olivierhoedeman': {'in': 0, 'out': 0, 'ratio': 0},
#  'openmaker': {'in': 5, 'out': 44, 'ratio': 0.10204081632653061},
#  'openp2pdesign': {'in': 0, 'out': 25, 'ratio': 0.0},
#  'orbassano2000': {'in': 0, 'out': 60, 'ratio': 0.0},
#  'oskayipek': {'in': 0, 'out': 19, 'ratio': 0.0},
#  'p_chiocchetti': {'in': 0, 'out': 266, 'ratio': 0.0},
#  'p_messages': {'in': 2, 'out': 101, 'ratio': 0.019417475728155338},
#  'palabresgroup': {'in': 1, 'out': 84, 'ratio': 0.011764705882352941},
#  'palpi643': {'in': 0, 'out': 30, 'ratio': 0.0},
#  'panchulzz': {'in': 0, 'out': 0, 'ratio': 0},
#  'panteshkinati8': {'in': 1, 'out': 26, 'ratio': 0.037037037037037035},
#  'parraguezr': {'in': 0, 'out': 153, 'ratio': 0.0},
#  'partickaya7wa1': {'in': 0, 'out': 29, 'ratio': 0.0},
#  'pdjahnke': {'in': 2, 'out': 69, 'ratio': 0.028169014084507043},
#  'ph_desfosses': {'in': 11, 'out': 1079, 'ratio': 0.010091743119266056},
#  'pikosapikosgr': {'in': 0, 'out': 0, 'ratio': 0},
#  'plusvaluetweets': {'in': 154, 'out': 204, 'ratio': 0.4301675977653631},
#  'poesiaculina': {'in': 6, 'out': 55, 'ratio': 0.09836065573770492},
#  'popeye4__': {'in': 0, 'out': 429, 'ratio': 0.0},
#  'prabprab': {'in': 3, 'out': 111, 'ratio': 0.02631578947368421},
#  'promitmoitra': {'in': 0, 'out': 103, 'ratio': 0.0},
#  'querforscher': {'in': 2, 'out': 0, 'ratio': 1.0},
#  'r0guetrainer': {'in': 8, 'out': 108, 'ratio': 0.06896551724137931},
#  'rcabinte': {'in': 0, 'out': 30, 'ratio': 0.0},
#  'recofunghi': {'in': 8, 'out': 29, 'ratio': 0.21621621621621623},
#  'renesugar': {'in': 0, 'out': 160, 'ratio': 0.0},
#  'repecCitEc': {'in': 1, 'out': 68, 'ratio': 0.014492753623188406},
#  'resume_unilu': {'in': 0, 'out': 43, 'ratio': 0.0},
#  'rgod777': {'in': 0, 'out': 38, 'ratio': 0.0},
#  'ricardo11701135': {'in': 0, 'out': 14, 'ratio': 0.0},
#  'riddick19811': {'in': 0, 'out': 0, 'ratio': 0},
#  'rubene822': {'in': 0, 'out': 0, 'ratio': 0},
#  'saitej786': {'in': 0, 'out': 5, 'ratio': 0.0},
#  'sambaravioli': {'in': 0, 'out': 92, 'ratio': 0.0},
#  'sandrosapio': {'in': 2, 'out': 16, 'ratio': 0.1111111111111111},
#  'sarahncorry': {'in': 4, 'out': 191, 'ratio': 0.020512820512820513},
#  'sarresd8': {'in': 0, 'out': 0, 'ratio': 0},
#  'sartin': {'in': 0, 'out': 67, 'ratio': 0.0},
#  'saxorut': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'schulte_stef': {'in': 31, 'out': 1284, 'ratio': 0.023574144486692015},
#  'sconquer8': {'in': 0, 'out': 0, 'ratio': 0},
#  'sebastienwathle': {'in': 0, 'out': 0, 'ratio': 0},
#  'sees_lab': {'in': 1, 'out': 33, 'ratio': 0.029411764705882353},
#  'sergiocabrero': {'in': 0, 'out': 68, 'ratio': 0.0},
#  'shakgohir': {'in': 0, 'out': 53, 'ratio': 0.0},
#  'shanegibson': {'in': 0, 'out': 154, 'ratio': 0.0},
#  'shopwearblack': {'in': 0, 'out': 8, 'ratio': 0.0},
#  'simply_jaehyuk': {'in': 6, 'out': 73, 'ratio': 0.0759493670886076},
#  'sjnwoh': {'in': 0, 'out': 1215, 'ratio': 0.0},
#  'smalkina5e1': {'in': 0, 'out': 37, 'ratio': 0.0},
#  'solarcollab': {'in': 0, 'out': 0, 'ratio': 0},
#  'solarfornia': {'in': 0, 'out': 4, 'ratio': 0.0},
#  'spiros_patelis': {'in': 0, 'out': 0, 'ratio': 0},
#  'stefanodigiorg3': {'in': 1, 'out': 119, 'ratio': 0.008333333333333333},
#  'stefatos_kostas': {'in': 1, 'out': 20, 'ratio': 0.047619047619047616},
#  'stephenkinsella': {'in': 2, 'out': 259, 'ratio': 0.007662835249042145},
#  'stf18': {'in': 0, 'out': 193, 'ratio': 0.0},
#  'strategypod': {'in': 2, 'out': 2, 'ratio': 0.5},
#  'styvencr7': {'in': 0, 'out': 0, 'ratio': 0},
#  'su_re_co': {'in': 14, 'out': 112, 'ratio': 0.1111111111111111},
#  'syaltout': {'in': 0, 'out': 46, 'ratio': 0.0},
#  'syroter_': {'in': 0, 'out': 16, 'ratio': 0.0},
#  'systemRK': {'in': 3, 'out': 2, 'ratio': 0.6},
#  'tachristopoulos': {'in': 0, 'out': 49, 'ratio': 0.0},
#  'takis_kt': {'in': 0, 'out': 98, 'ratio': 0.0},
#  'tarik_rko': {'in': 22, 'out': 120, 'ratio': 0.15492957746478872},
#  'thanhbong06': {'in': 0, 'out': 58, 'ratio': 0.0},
#  'the_young_fdn': {'in': 9, 'out': 148, 'ratio': 0.05732484076433121},
#  'theceschi': {'in': 0, 'out': 175, 'ratio': 0.0},
#  'thekokytus': {'in': 0, 'out': 238, 'ratio': 0.0},
#  'thetippytopblog': {'in': 2, 'out': 22, 'ratio': 0.08333333333333333},
#  'titarchukaj2s': {'in': 0, 'out': 38, 'ratio': 0.0},
#  'tiveleva4ie': {'in': 0, 'out': 33, 'ratio': 0.0},
#  'tommaschera': {'in': 0, 'out': 11, 'ratio': 0.0},
#  'tori_henry2': {'in': 0, 'out': 0, 'ratio': 0},
#  'tozhs': {'in': 0, 'out': 0, 'ratio': 0},
#  'tricks_y': {'in': 0, 'out': 194, 'ratio': 0.0},
#  'trxias': {'in': 0, 'out': 3, 'ratio': 0.0},
#  'uzh_bf': {'in': 9, 'out': 102, 'ratio': 0.08108108108108109},
#  'valteraguiar654': {'in': 0, 'out': 1, 'ratio': 0.0},
#  'vectracrome111': {'in': 0, 'out': 0, 'ratio': 0},
#  'veronika_st5': {'in': 3, 'out': 1, 'ratio': 0.75},
#  'vijayakumarmad6': {'in': 0, 'out': 0, 'ratio': 0},
#  'vtchakarova': {'in': 0, 'out': 66, 'ratio': 0.0},
#  'xavierhervas': {'in': 0, 'out': 27, 'ratio': 0.0},
#  'yanhua_yanhua7': {'in': 0, 'out': 0, 'ratio': 0},
#  'yuliay': {'in': 0, 'out': 56, 'ratio': 0.0},
#  'yuridayana10': {'in': 1, 'out': 19, 'ratio': 0.05},
#  'zbattiz': {'in': 88, 'out': 92, 'ratio': 0.4888888888888889},
#  'zoozanne': {'in': 2, 'out': 84, 'ratio': 0.023255813953488372}}

# %%
pp.pprint(Mention_Network_Internal_Connected)
# Out:
# {'0ttamatt': {'FinexusCenter': 1,
#               'Gius_C': 1,
#               'GuidoCaldarelli': 3,
#               'SimPolProject': 1,
#               'fabiofxvanni': 1},
#  '2dipicchee': {'FinexusCenter': 1,
#                 'GuidoCaldarelli': 1,
#                 'SimPolProject': 5,
#                 'fet_eu': 1,
#                 'forfinancewatch': 3,
#                 'marcobardoscia': 1,
#                 'marcoderrico': 1,
#                 'zbattiz': 3},
#  '7softley': {'anxosan': 1},
#  'Agn_ssa': {'2dipicchee': 1,
#              'SimPolProject': 13,
#              '_ChiaraPerillo': 2,
#              'forfinancewatch': 1,
#              'veronika_st5': 1,
#              'zbattiz': 1},
#  'AlessandroLaced': {'gbracci_des': 2},
#  'AndreaRoventini': {'ISIgrowth': 19,
#                      'Mattia_Guerini': 1,
#                      'SimPolProject': 3,
#                      'Transitionway': 1,
#                      'arthurturrell': 1,
#                      'mnapoletano1': 1,
#                      'zbattiz': 1},
#  'AsaBentley': {'forfinancewatch': 1, 'johnbirdswords': 3, 'the_young_fdn': 5},
#  'Better_Finance': {'forfinancewatch': 1},
#  'Beyond_Ratings': {'FinforTomorrow': 6, 'ph_desfosses': 5},
#  'BingoLittle1': {'JFernandoGRE': 1},
#  'CGraciaLazaro': {'IBSEN_H2020': 1,
#                    'ISI_Fondazione': 1,
#                    'anxosan': 6,
#                    'cosnet_bifi': 10,
#                    'er_chechi': 2,
#                    'fet_eu': 1},
#  'CardanIOTeam': {'CardanoStiftung': 2},
#  'CardanoStiftung': {'CardanIOTeam': 1},
#  'ChristosEllina1': {'GuidoCaldarelli': 1,
#                      'adilson_motter': 2,
#                      'manlius84': 1,
#                      'zbattiz': 1},
#  'Climate_Friend': {'NickBeglinger': 1,
#                     'SSEinitiative': 2,
#                     'UNEP_FI': 1,
#                     'bitlumens': 1,
#                     'filippoaddarii': 1},
#  'CoeGSS': {'GuidoCaldarelli': 1, 'SimPolProject': 1, 'zbattiz': 1},
#  'Complexity_Labs': {'LetsWorkHappy': 4, 'emergir_co': 1},
#  'D_young_69': {'AndreaRoventini': 3, 'adilson_motter': 1},
#  'DarkMatter_Labs': {'indy_johar': 70},
#  'EcologicalEcon': {'Transitionway': 2, 'emacampiglio': 1, 'zbattiz': 1},
#  'FETFX_EU': {'FETFlagships': 7,
#               'Fet2Rin': 1,
#               'IBSEN_H2020': 1,
#               'MazzucatoM': 1,
#               'fet_eu': 17},
#  'FabriceSabatier': {'forfinancewatch': 1},
#  'FcoKienzle': {'FETFlagships': 7,
#                 'Fet2Rin': 1,
#                 'SUPERTWIN_H2020': 5,
#                 'fet_eu': 27},
#  'Fede_Botta': {'ISI_Fondazione': 1, 'ciro': 2, 'manlius84': 2},
#  'Fet2Rin': {'FETFX_EU': 18,
#              'FETFlagships': 41,
#              'MartaCalderaro': 2,
#              'MazzucatoM': 1,
#              'fet_eu': 94},
#  'FinexusCenter': {'SimPolProject': 2, 'cosnet_bifi': 1, 'zbattiz': 4},
#  'FinforTomorrow': {'Beyond_Ratings': 1, 'UNEP_FI': 2, 'ph_desfosses': 1},
#  'FranciscoICMC': {'adilson_motter': 1,
#                    'cosnet_bifi': 5,
#                    'ecozzo': 3,
#                    'lgaalves': 2},
#  'GeoVun': {'SSEinitiative': 1},
#  'Gianlucamisu': {'AndreaRoventini': 2,
#                   'GuidoCaldarelli': 2,
#                   'LieveFransen': 1,
#                   'SICommunity_EU': 9,
#                   'brianla1': 2,
#                   'filippoaddarii': 6,
#                   'flipparini': 8,
#                   'indy_johar': 1,
#                   'openmaker': 1},
#  'Gius_C': {'SimPolProject': 1},
#  'GuidoCaldarelli': {'AndreaRoventini': 1,
#                      'FETFlagships': 1,
#                      'Gianlucamisu': 10,
#                      'KoljaKleineberg': 1,
#                      'Transitionway': 1,
#                      'adilson_motter': 1,
#                      'cosnet_bifi': 5,
#                      'filippoaddarii': 1,
#                      'flipparini': 3,
#                      'marcobardoscia': 1,
#                      'mnapoletano1': 1,
#                      'plusvaluetweets': 1,
#                      'zbattiz': 3},
#  'HamishJWyatt': {'APRC_CF': 4, 'WRIClimate': 1},
#  'HanKitcher': {'the_young_fdn': 1},
#  'IASS_DOLFINS': {'FETFX_EU': 1,
#                   'FinexusCenter': 2,
#                   'IASS_Potsdam': 28,
#                   'ISIgrowth': 1,
#                   'PaoloBarucca': 1,
#                   'RogerCremades': 1,
#                   'SimPolProject': 22,
#                   'fet_eu': 4,
#                   'uzh_bf': 2,
#                   'zbattiz': 4},
#  'IASS_Potsdam': {'goldthau': 1},
#  'IBSEN_H2020': {'CGraciaLazaro': 4,
#                  'NectuntLab': 1,
#                  'anxosan': 5,
#                  'cosnet_bifi': 7,
#                  'fet_eu': 10},
#  'ISIgrowth': {'AndreaRoventini': 33,
#                'Mattia_Guerini': 1,
#                'MazzucatoM': 14,
#                'mnapoletano1': 5,
#                'zbattiz': 1},
#  'Igorsemenoff': {'7wData': 1},
#  'JacopoSestili': {'MazzucatoM': 2},
#  'JahelMielke': {'FinexusCenter': 1,
#                  'SimPolProject': 3,
#                  'licht_anna': 1,
#                  'zbattiz': 1},
#  'James_Vaccaro': {'UNEP_FI': 1, 'forfinancewatch': 2},
#  'LDNinst': {'GuidoCaldarelli': 1, 'PaoloBarucca': 1},
#  'LeanneUssher': {'IASS_DOLFINS': 1, 'SimPolProject': 1},
#  'LetsWorkHappy': {'Complexity_Labs': 12},
#  'LieveFransen': {'Gianlucamisu': 1},
#  'LindaBach14': {'SimPolProject': 2},
#  'Lsuttors': {'MazzucatoM': 1,
#               'Pierre_Monnin': 3,
#               'Transitionway': 3,
#               'emacampiglio': 1,
#               'forfinancewatch': 7,
#               'joostmulder': 2,
#               'mireillmartini': 3,
#               'zbattiz': 2},
#  'LuisaDeAmicis': {'FinexusCenter': 4,
#                    'SICommunity_EU': 1,
#                    'SimPolProject': 6,
#                    'UNEP_FI': 1,
#                    'anxosan': 1,
#                    'cosnet_bifi': 1,
#                    'dariomarmo_lama': 1,
#                    'fet_eu': 1,
#                    'filippoaddarii': 5,
#                    'flipparini': 5,
#                    'indy_johar': 1,
#                    'openmaker': 13,
#                    'plusvaluetweets': 14,
#                    'the_young_fdn': 1,
#                    'zbattiz': 4},
#  'LyndaMansson': {'GECoalition': 3},
#  'MacroPru': {'dlacalle_IA': 2},
#  'MarlonMasine': {'netsci2017': 2},
#  'MartaCalderaro': {'FETFX_EU': 3, 'FETFlagships': 1, 'fet_eu': 4},
#  'Mattia_Guerini': {'AndreaRoventini': 3,
#                     'DucThiLuu': 1,
#                     'PaoloBarucca': 2,
#                     'SimPolProject': 2,
#                     'fabiofxvanni': 1,
#                     'mnapoletano1': 4,
#                     'zbattiz': 1},
#  'MolinariMax_': {'PaoloBarucca': 1, 'zbattiz': 1},
#  'NickJackson81': {'MazzucatoM': 1,
#                    'RebuildMacro': 2,
#                    'arthurturrell': 1,
#                    'stephenkinsella': 1},
#  'OrpheusEU': {'eurohumph': 1},
#  'PaoloBarucca': {'AndreaRoventini': 2,
#                   'LDNinst': 2,
#                   'SimPolProject': 2,
#                   'Transitionway': 2,
#                   'cosnet_bifi': 1,
#                   'emacampiglio': 2,
#                   'mnapoletano1': 2,
#                   'uzh_bf': 5,
#                   'zbattiz': 2},
#  'Paorazio': {'FinexusCenter': 1, 'SimPolProject': 1, 'lilitpopoyan': 1},
#  'Pierre_Monnin': {'FinexusCenter': 5,
#                    'HelenJackson0': 1,
#                    'L__Macfarlane': 1,
#                    'Lsuttors': 2,
#                    'MacroPru': 1,
#                    'Transitionway': 4,
#                    'YannisDafermos': 1,
#                    'emacampiglio': 1,
#                    'forfinancewatch': 3,
#                    'mireillmartini': 1,
#                    'zbattiz': 2},
#  'PolicyCompassEU': {'fet_eu': 1},
#  'RebuildMacro': {'stephenkinsella': 4},
#  'RobPasqualino': {'Transitionway': 1},
#  'RothcoPepp': {'EcologicalEcon': 1,
#                 'RebuildMacro': 4,
#                 'SimPolProject': 1,
#                 'Transitionway': 1,
#                 'arthurturrell': 1,
#                 'georguensberg': 1,
#                 'zbattiz': 2},
#  'SFL_nl': {'SusFinLab': 2},
#  'SICommunity_EU': {'Gianlucamisu': 1, 'indy_johar': 1, 'the_young_fdn': 4},
#  'SimPolProject': {'2dipicchee': 1,
#                    'Agn_ssa': 1,
#                    'AndreaRoventini': 1,
#                    'CoeGSS': 1,
#                    'FETFX_EU': 1,
#                    'FETFlagships': 2,
#                    'FinexusCenter': 4,
#                    'GiachiniDaniele': 1,
#                    'GuidoCaldarelli': 4,
#                    'IASS_DOLFINS': 3,
#                    'MacroPru': 1,
#                    'Mattia_Guerini': 1,
#                    'NickBeglinger': 3,
#                    'PaoloBarucca': 2,
#                    'Transitionway': 6,
#                    '_ChiaraPerillo': 1,
#                    'bitlumens': 2,
#                    'bplisse': 1,
#                    'cosnet_bifi': 2,
#                    'fet_eu': 2,
#                    'filippoaddarii': 2,
#                    'forfinancewatch': 2,
#                    'hamzaz': 3,
#                    'lilitpopoyan': 1,
#                    'mnapoletano1': 5,
#                    'plusvaluetweets': 2,
#                    'the_young_fdn': 2,
#                    'uzh_bf': 2,
#                    'veronika_st5': 1,
#                    'vtchakarova': 1,
#                    'zbattiz': 15},
#  'SodreLuciana': {'crie_ufrj': 3},
#  'SusFinLab': {'SFL_nl': 1},
#  'TMWFTE': {'eurohumph': 1},
#  'Transitionway': {'AndreaRoventini': 12,
#                    'BUPardeeCenter': 6,
#                    'EcologicalEcon': 23,
#                    'GuidoCaldarelli': 1,
#                    'PaoloBarucca': 1,
#                    'Pierre_Monnin': 22,
#                    'SimPolProject': 28,
#                    'YannisDafermos': 1,
#                    'emacampiglio': 17,
#                    'georguensberg': 5,
#                    'mireillmartini': 2,
#                    'mnapoletano1': 4,
#                    'veronika_st5': 1,
#                    'zbattiz': 74},
#  'UB_ICS': {'anduviera': 6, 'sees_lab': 5},
#  'UNEP_FI': {'FinforTomorrow': 20},
#  'VlPetrovV': {'2dipicchee': 1,
#                'Agn_ssa': 3,
#                'FinexusCenter': 3,
#                'SimPolProject': 14,
#                '_ChiaraPerillo': 1,
#                'jnode': 1,
#                'zbattiz': 7},
#  'WRIClimate': {'UNEP_FI': 1},
#  'WarrenWhitlock': {'joelcomm': 3},
#  '_ChiaraPerillo': {'GuidoCaldarelli': 1,
#                     'SimPolProject': 1,
#                     'forfinancewatch': 1,
#                     'uzh_bf': 1,
#                     'zbattiz': 1},
#  '_ndrd_': {'jlmateos': 1},
#  'adilson_motter': {'ChristosEllina1': 1, 'anduviera': 1},
#  'aleaf_h2020': {'FETFX_EU': 1,
#                  'Fet2Rin': 1,
#                  'SUPERTWIN_H2020': 1,
#                  'fet_eu': 17},
#  'amanahramadiah': {'GuidoCaldarelli': 4, 'marcobardoscia': 1, 'zbattiz': 1},
#  'amritasaha': {'ISIgrowth': 1, 'MazzucatoM': 3},
#  'anduviera': {'ecozzo': 1},
#  'angelnunhez': {'anxosan': 2, 'galeanojav': 2},
#  'anxosan': {'cosnet_bifi': 1, 'ferminserrano': 1},
#  'aparpau': {'APRC_CF': 20, 'HamishJWyatt': 1},
#  'bastidas_d': {'emacampiglio': 1},
#  'bonosverdes': {'SSEinitiative': 2, 'UNEP_FI': 2},
#  'bplisse': {'SimPolProject': 4, 'greenwinproject': 2, 'zbattiz': 2},
#  'brianla1': {'Gianlucamisu': 2},
#  'burrolahola': {'ISEEORG': 2,
#                  'Pierre_Monnin': 1,
#                  'YannisDafermos': 1,
#                  'emacampiglio': 1},
#  'ciro': {'ISI_Fondazione': 7},
#  'complex_warsaw': {'7softley': 5, 'TehRaio': 1},
#  'cosnet_bifi': {'CGraciaLazaro': 2,
#                  'FranciscoICMC': 4,
#                  'ISI_Fondazione': 2,
#                  'KoljaKleineberg': 1,
#                  'SimPolProject': 1,
#                  'adilson_motter': 1,
#                  'anxosan': 2,
#                  'daniel_goldsmth': 3,
#                  'ecozzo': 2,
#                  'er_chechi': 2,
#                  'fet_eu': 4,
#                  'lgaalves': 1,
#                  'zbattiz': 1},
#  'crie_ufrj': {'SodreLuciana': 1},
#  'daniel_goldsmth': {'cosnet_bifi': 2, 'lgaalves': 1, 'zbattiz': 1},
#  'dariomarmo_lama': {'openmaker': 25, 'plusvaluetweets': 1},
#  'duyennguyen286': {'GeoVun': 2},
#  'ecozzo': {'anxosan': 1, 'manlius84': 1},
#  'eleni_choidas': {'Better_Finance': 1,
#                    'forfinancewatch': 1,
#                    'joostmulder': 1,
#                    'schulte_stef': 1},
#  'elisa_letizia': {'ISI_Fondazione': 1,
#                    'PaoloBarucca': 1,
#                    'SimPolProject': 1,
#                    'jnode': 1,
#                    'marcoderrico': 1,
#                    'veronika_st5': 1},
#  'elisa_omodei': {'ISI_Fondazione': 1, 'KoljaKleineberg': 2, 'manlius84': 7},
#  'emacampiglio': {'AndreaRoventini': 1,
#                   'EcologicalEcon': 1,
#                   'MazzucatoM': 1,
#                   'Pierre_Monnin': 4,
#                   'RebuildMacro': 1,
#                   'SimPolProject': 1,
#                   'SusFinLab': 1,
#                   'Transitionway': 7,
#                   'YannisDafermos': 2,
#                   'bastidas_d': 1,
#                   'forfinancewatch': 1,
#                   'mnapoletano1': 1,
#                   'zbattiz': 3},
#  'emergir_co': {'Complexity_Labs': 7, 'UB_ICS': 1},
#  'fabiofxvanni': {'AndreaRoventini': 1,
#                   'GiachiniDaniele': 1,
#                   'Mattia_Guerini': 1,
#                   'SimPolProject': 2,
#                   'Transitionway': 1},
#  'fet_eu': {'FETFX_EU': 13, 'FETFlagships': 14, 'aleaf_h2020': 3},
#  'filippoaddarii': {'Gianlucamisu': 3,
#                     'LieveFransen': 1,
#                     'flipparini': 3,
#                     'plusvaluetweets': 45,
#                     'zbattiz': 1},
#  'firth_john': {'UNEP_FI': 5},
#  'flipparini': {'Gianlucamisu': 8,
#                 'GuidoCaldarelli': 1,
#                 'LieveFransen': 2,
#                 'LuisaDeAmicis': 1,
#                 'dariomarmo_lama': 1,
#                 'filippoaddarii': 11,
#                 'openmaker': 3,
#                 'plusvaluetweets': 10},
#  'forfinancewatch': {'mireillmartini': 4},
#  'galeanojav': {'anxosan': 1},
#  'georguensberg': {'CorneliaDaniel': 1},
#  'giacomolivan': {'GuidoCaldarelli': 2, 'cosnet_bifi': 1, 'marcobardoscia': 10},
#  'goldthau': {'IASS_Potsdam': 2},
#  'greenetworksco': {'KushyKush': 2},
#  'greenwinproject': {'FinexusCenter': 1,
#                      'IASS_Potsdam': 1,
#                      'andkarpf': 1,
#                      'bplisse': 3,
#                      'su_re_co': 8},
#  'helloplanetmars': {'SimPolProject': 2,
#                      'forfinancewatch': 1,
#                      'mireillmartini': 1},
#  'indy_johar': {'DarkMatter_Labs': 2},
#  'ivan8848': {'vtchakarova': 22},
#  'jferretm': {'Pierre_Monnin': 3, 'Transitionway': 1},
#  'jlmateos': {'adilson_motter': 1, 'anduviera': 3, 'anxosan': 2},
#  'jnode': {'GuidoCaldarelli': 1,
#            'SimPolProject': 1,
#            'axekoukou': 5,
#            'filippoaddarii': 1,
#            'zbattiz': 13},
#  'johnbirdswords': {'the_young_fdn': 1},
#  'joostmulder': {'Lsuttors': 1},
#  'jviver': {'Lsuttors': 1, 'forfinancewatch': 19},
#  'lgaalves': {'FranciscoICMC': 1},
#  'lilitpopoyan': {'AndreaRoventini': 1,
#                   'FinexusCenter': 7,
#                   'ISIgrowth': 1,
#                   'SimPolProject': 8,
#                   'fabiofxvanni': 1,
#                   'zbattiz': 2},
#  'lindod1972': {'GECoalition': 1,
#                 'L__Macfarlane': 10,
#                 'forfinancewatch': 29,
#                 'mireillmartini': 1,
#                 'schulte_stef': 1},
#  'mallenbaker': {'BradZarnett': 1},
#  'manlius84': {'Fede_Botta': 1, 'anduviera': 2, 'ciro': 1, 'ecozzo': 1},
#  'marcobardoscia': {'GuidoCaldarelli': 20,
#                     'PaoloBarucca': 2,
#                     'giacomolivan': 5,
#                     'mnapoletano1': 1,
#                     'netsci15': 1,
#                     'querforscher': 1,
#                     'zbattiz': 15},
#  'marcos_mancini': {'SSEinitiative': 1},
#  'min_standardism': {'MacroPru': 1, 'indy_johar': 1},
#  'mireillmartini': {'Lsuttors': 2,
#                     'Pierre_Monnin': 1,
#                     'forfinancewatch': 17,
#                     'joostmulder': 1},
#  'mnapoletano1': {'AndreaRoventini': 15,
#                   'DucThiLuu': 1,
#                   'FinexusCenter': 8,
#                   'GuidoCaldarelli': 1,
#                   'ISIgrowth': 6,
#                   'MacroPru': 3,
#                   'Mattia_Guerini': 1,
#                   'MazzucatoM': 1,
#                   'PaoloBarucca': 1,
#                   'SimPolProject': 13,
#                   'Transitionway': 1,
#                   'bplisse': 1,
#                   'forfinancewatch': 1,
#                   'lilitpopoyan': 1,
#                   'marcobardoscia': 1,
#                   'zbattiz': 9},
#  'monicanagore': {'HanKitcher': 3,
#                   'LuisaDeAmicis': 1,
#                   'SICommunity_EU': 31,
#                   'SimPolProject': 12,
#                   'forfinancewatch': 1,
#                   'giuliaporino': 1,
#                   'the_young_fdn': 37},
#  'multiplex_fet': {'FETFlagships': 1,
#                    'GuidoCaldarelli': 2,
#                    'SimPolProject': 1,
#                    'fet_eu': 3,
#                    'zbattiz': 1},
#  'nachoenblanco': {'johemart55': 1},
#  'nanumyan': {'ciro': 1},
#  'openmaker': {'Gianlucamisu': 1,
#                'LuisaDeAmicis': 2,
#                'dariomarmo_lama': 1,
#                'plusvaluetweets': 1},
#  'p_messages': {'uzh_bf': 2},
#  'panteshkinati8': {'SimPolProject': 1},
#  'ph_desfosses': {'Better_Finance': 1,
#                   'FinforTomorrow': 3,
#                   'OnePlanetParis': 1,
#                   'RFIFoundation': 1,
#                   'UNEP_FI': 5},
#  'plusvaluetweets': {'Gianlucamisu': 4,
#                      'GuidoCaldarelli': 2,
#                      'LuisaDeAmicis': 8,
#                      'SimPolProject': 3,
#                      'filippoaddarii': 83,
#                      'flipparini': 50,
#                      'zbattiz': 3},
#  'prabprab': {'eurohumph': 1, 'indy_johar': 2},
#  'querforscher': {'SimPolProject': 1, 'greenwinproject': 1},
#  'r0guetrainer': {'marcoderrico': 1, 'stephenkinsella': 7},
#  'sandrosapio': {'AndreaRoventini': 1, 'mnapoletano1': 1},
#  'sarahncorry': {'FinforTomorrow': 1,
#                  'GECoalition': 1,
#                  'UNEP_FI': 1,
#                  'forfinancewatch': 1},
#  'schulte_stef': {'stf18': 31},
#  'simply_jaehyuk': {'netsci2017': 3, 'sjnwoh': 3},
#  'stephenkinsella': {'MazzucatoM': 2},
#  'su_re_co': {'greenwinproject': 13},
#  'systemRK': {'FinexusCenter': 2},
#  'tarik_rko': {'GuidoCaldarelli': 4,
#                'forfinancewatch': 1,
#                'marcoderrico': 8,
#                'zbattiz': 9},
#  'the_young_fdn': {'SICommunity_EU': 4,
#                    'monicanagore': 2,
#                    'plusvaluetweets': 2},
#  'uzh_bf': {'FinexusCenter': 1,
#             'SimPolProject': 2,
#             '_ChiaraPerillo': 1,
#             'fet_eu': 1,
#             'zbattiz': 1},
#  'veronika_st5': {'SimPolProject': 1, 'Transitionway': 1, 'zbattiz': 1},
#  'zbattiz': {'AndreaRoventini': 6,
#              'EcologicalEcon': 9,
#              'FinexusCenter': 1,
#              'GuidoCaldarelli': 6,
#              'Pierre_Monnin': 3,
#              'SimPolProject': 12,
#              'Transitionway': 24,
#              '_ChiaraPerillo': 1,
#              'bitlumens': 1,
#              'cosnet_bifi': 1,
#              'emacampiglio': 11,
#              'forfinancewatch': 3,
#              'hamzaz': 1,
#              'mnapoletano1': 7,
#              'uzh_bf': 2}}

# %%
print(len(Mention_Network_Internal), len(Mention_Network_Internal_Connected), len(Mention_Network_Internal_Isolates))
# Out:
# 683 159 524

# %%
Mention_Popularity = get_popularity(Mention_Network)
Mention_Popularity['zbattiz'], Mention_Popularity['TheEconomist'], Mention_Popularity['SimPolProject'],
# Out:
# (195, 59, 176)

# %% [markdown]
# #### 5.4 Identifying important external nodes

# %% [markdown]
# ##### Cehcking the source of retweets

# %%
RT_Network_External = select_subnet(RT_Network, followers, isin = False)

# %%
pp.pprint(RT_Network_External['zbattiz'])
# Out:
# {'BenLallemand': 4,
#  'CEPweb': 2,
#  'CampanaleMark': 1,
#  'Frank_vanlerven': 1,
#  'GaelGiraud_AFD': 1,
#  'IngridHolmes7': 1,
#  'KR_MachineLearn': 1,
#  'LiveSpinoza': 1,
#  'NVJRobins1': 3,
#  'NetSciPhDs': 2,
#  'SPRU': 1,
#  'SriEvent': 3,
#  'TheEconomist': 1,
#  'VDombrovskis': 1,
#  'alexvespi': 2,
#  'andytuit': 1,
#  'bbuchner13': 1,
#  'eaepe': 3,
#  'ecfin': 1,
#  'ivcubic': 1,
#  'jkbren': 1,
#  'jryancollins': 1,
#  'netsci2018': 1,
#  'vcolizza': 1}

# %%
pp.pprint(RT_Network_Internal['zbattiz'])
# Out:
# {'EcologicalEcon': 1,
#  'FinexusCenter': 1,
#  'GuidoCaldarelli': 3,
#  'ISIgrowth': 4,
#  'LindaBach14': 1,
#  'Pierre_Monnin': 3,
#  'RobPasqualino': 1,
#  'SimPolProject': 10,
#  'Transitionway': 32,
#  'UNEP_FI': 1,
#  'adilson_motter': 1,
#  'bitlumens': 1,
#  'bplisse': 1,
#  'cosnet_bifi': 3,
#  'emacampiglio': 2,
#  'fabiofxvanni': 1,
#  'filippoaddarii': 2,
#  'forfinancewatch': 4,
#  'mnapoletano1': 7,
#  'monicanagore': 3,
#  'plusvaluetweets': 3,
#  'uzh_bf': 2,
#  'veronika_st5': 1,
#  'zbattiz': 6}

# %%
RT_Popularity_External = get_popularity(RT_Network_External)

# %%
df_external_RT = pd.DataFrame.from_dict(RT_Popularity_External, orient='index')
df_external_RT.columns = ['Count']
df_external_RT.head(10)
# Out:
#                Count
# OnTheHub           4
# CBSNews            4
# mcspocky           2
# Gokuss7Gamer       1
# review_wall        1
# vexxhost           1
# aaronvick          1
# ElixiumCrypto      1
# IsaiahGmusic       1
# Digijoe78          1

# %%
df_external_RT = df_external_RT.sort_values(by = 'Count', ascending = False)
df_external_RT.head(10)
# Out:
#                 Count
# alexvespi         281
# wef               125
# zerohedge         105
# TheEconomist       94
# Team4Nature300     88
# LaNet_2017         85
# DSMeu              84
# stevenstrogatz     83
# net_science        83
# EU_Commission      79

# %% [markdown]
# ##### Cehcking the mentions of the community members

# %%
M_Network_External = select_subnet(Mention_Network, followers, isin = False)
M_Popularity_External = get_popularity(M_Network_External)
df_external_M = pd.DataFrame.from_dict(M_Popularity_External, orient='index')
df_external_M.columns = ['Count']
df_external_M.head()
df_external_M = df_external_M.sort_values(by = 'Count', ascending = False)
df_external_M.head(11)
# Out:
#                  Count
# YouTube           1048
# _ERAFP_            173
#                    166
# EU_Commission      142
# Frances_Coppola    139
# FT                 133
# rightrelevance     129
# jeuasommenulle     128
# GrkStav            128
# elchaposing        128
# RichardBlyth7      126

# %% [markdown]
# ### 6. Exporting the summary of results

# %%
Summary = dict()
for n in followers:
    PopM,PopRT,nT,nRT,rDiff = 0,0,0,0,0
    if n in Mention_Popularity.keys():
        PopM = Mention_Popularity[n]
    if n in RT_Popularity.keys():
        PopRT = RT_Popularity[n]
    if n in RT_Stats.keys():
        nT = RT_Stats[n]['nTweet']
        nRT = RT_Stats[n]['nRTweet']
        rDiff = RT_Stats[n]['rDiffusion']
    inM, outM, rM, inRT, outRT, rRT = 0,0,0,0,0,0 
    if n in Mention_Network_Cohesion.keys():
        inM = Mention_Network_Cohesion[n]['in']
        outM = Mention_Network_Cohesion[n]['out']
        rM = Mention_Network_Cohesion[n]['ratio']
    if n in RT_Network_Cohesion.keys():
        inRT = RT_Network_Cohesion[n]['in']
        outRT = RT_Network_Cohesion[n]['out']
        rRT = RT_Network_Cohesion[n]['ratio']
    Summary[n] = {
        'MentionPopularity':PopM,
        'RTPopularity':PopRT,
        'RTweetDiffusion':rDiff,
        'nTweet':nT,
        'nRTweet':nRT,
        'MentionInternal': inM,
        'MentionExternal': outM,
        'MentionCohesion': rM,
        'RTInternal': inRT,
        'RTExternal': outRT,
        'RTCohesion': rRT}

# %%
pp.pprint(Summary)
# Out:
# {'0ttamatt': {'MentionCohesion': 0.5384615384615384,
#               'MentionExternal': 6,
#               'MentionInternal': 7,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.45588235294117646,
#               'RTExternal': 37,
#               'RTInternal': 31,
#               'RTPopularity': 1,
#               'RTweetDiffusion': 0.9315068493150684,
#               'nRTweet': 68,
#               'nTweet': 73},
#  '2dipicchee': {'MentionCohesion': 0.3018867924528302,
#                 'MentionExternal': 37,
#                 'MentionInternal': 16,
#                 'MentionPopularity': 3,
#                 'RTCohesion': 0.5256410256410257,
#                 'RTExternal': 74,
#                 'RTInternal': 82,
#                 'RTPopularity': 4,
#                 'RTweetDiffusion': 0.8125,
#                 'nRTweet': 156,
#                 'nTweet': 192},
#  '4A50CqwsQqeahlq': {'MentionCohesion': 0,
#                      'MentionExternal': 0,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0,
#                      'RTExternal': 0,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0,
#                      'nRTweet': 0,
#                      'nTweet': 0},
#  '7softley': {'MentionCohesion': 0.05,
#               'MentionExternal': 19,
#               'MentionInternal': 1,
#               'MentionPopularity': 5,
#               'RTCohesion': 0.0,
#               'RTExternal': 161,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.805,
#               'nRTweet': 161,
#               'nTweet': 200},
#  '7wData': {'MentionCohesion': 0.0,
#             'MentionExternal': 18,
#             'MentionInternal': 0,
#             'MentionPopularity': 1,
#             'RTCohesion': 0.0,
#             'RTExternal': 132,
#             'RTInternal': 0,
#             'RTPopularity': 1,
#             'RTweetDiffusion': 0.66,
#             'nRTweet': 132,
#             'nTweet': 200},
#  '85Fifteen': {'MentionCohesion': 0.0,
#                'MentionExternal': 83,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0.0,
#                'RTExternal': 24,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.12,
#                'nRTweet': 24,
#                'nTweet': 200},
#  'AEBIOM': {'MentionCohesion': 0.0958904109589041,
#             'MentionExternal': 66,
#             'MentionInternal': 7,
#             'MentionPopularity': 7,
#             'RTCohesion': 0.008403361344537815,
#             'RTExternal': 118,
#             'RTInternal': 1,
#             'RTPopularity': 1,
#             'RTweetDiffusion': 0.595,
#             'nRTweet': 119,
#             'nTweet': 200},
#  'APRC_CF': {'MentionCohesion': 0.16,
#              'MentionExternal': 42,
#              'MentionInternal': 8,
#              'MentionPopularity': 32,
#              'RTCohesion': 0.04,
#              'RTExternal': 96,
#              'RTInternal': 4,
#              'RTPopularity': 36,
#              'RTweetDiffusion': 0.5,
#              'nRTweet': 100,
#              'nTweet': 200},
#  'ARNAOYTHSD': {'MentionCohesion': 0.0,
#                 'MentionExternal': 4,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0,
#                 'RTExternal': 0,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.0,
#                 'nRTweet': 0,
#                 'nTweet': 200},
#  'AdaFerko': {'MentionCohesion': 0.0,
#               'MentionExternal': 94,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.0,
#               'RTExternal': 56,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.28,
#               'nRTweet': 56,
#               'nTweet': 200},
#  'AdamPC26': {'MentionCohesion': 0.0,
#               'MentionExternal': 52,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.0,
#               'RTExternal': 107,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.5376884422110553,
#               'nRTweet': 107,
#               'nTweet': 199},
#  'Adeline_story': {'MentionCohesion': 0,
#                    'MentionExternal': 0,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0,
#                    'RTExternal': 0,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0,
#                    'nRTweet': 0,
#                    'nTweet': 0},
#  'Adellibya1979': {'MentionCohesion': 0.0,
#                    'MentionExternal': 16,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.0,
#                    'RTExternal': 123,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.8661971830985915,
#                    'nRTweet': 123,
#                    'nTweet': 142},
#  'AdolfSanchez5': {'MentionCohesion': 0.0,
#                    'MentionExternal': 72,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.0,
#                    'RTExternal': 153,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.765,
#                    'nRTweet': 153,
#                    'nTweet': 200},
#  'Adoufrancois': {'MentionCohesion': 0,
#                   'MentionExternal': 0,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0,
#                   'RTExternal': 0,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0,
#                   'nRTweet': 0,
#                   'nTweet': 0},
#  'Agent_Jase': {'MentionCohesion': 0.0,
#                 'MentionExternal': 120,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.044444444444444446,
#                 'RTExternal': 43,
#                 'RTInternal': 2,
#                 'RTPopularity': 2,
#                 'RTweetDiffusion': 0.225,
#                 'nRTweet': 45,
#                 'nTweet': 200},
#  'Agn_ssa': {'MentionCohesion': 0.3584905660377358,
#              'MentionExternal': 34,
#              'MentionInternal': 19,
#              'MentionPopularity': 4,
#              'RTCohesion': 0.719626168224299,
#              'RTExternal': 30,
#              'RTInternal': 77,
#              'RTPopularity': 8,
#              'RTweetDiffusion': 0.7867647058823529,
#              'nRTweet': 107,
#              'nTweet': 136},
#  'AlanGIsaac': {'MentionCohesion': 0.0,
#                 'MentionExternal': 117,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.021739130434782608,
#                 'RTExternal': 45,
#                 'RTInternal': 1,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.23,
#                 'nRTweet': 46,
#                 'nTweet': 200},
#  'AlbertoMunoz': {'MentionCohesion': 0.0,
#                   'MentionExternal': 31,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.02702702702702703,
#                   'RTExternal': 72,
#                   'RTInternal': 2,
#                   'RTPopularity': 2,
#                   'RTweetDiffusion': 0.37,
#                   'nRTweet': 74,
#                   'nTweet': 200},
#  'AldeiDiogo': {'MentionCohesion': 0.0,
#                 'MentionExternal': 2,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.017857142857142856,
#                 'RTExternal': 165,
#                 'RTInternal': 3,
#                 'RTPopularity': 3,
#                 'RTweetDiffusion': 0.9545454545454546,
#                 'nRTweet': 168,
#                 'nTweet': 176},
#  'AlessandroLaced': {'MentionCohesion': 0.007272727272727273,
#                      'MentionExternal': 273,
#                      'MentionInternal': 2,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.01,
#                      'RTExternal': 99,
#                      'RTInternal': 1,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.5025125628140703,
#                      'nRTweet': 100,
#                      'nTweet': 199},
#  'Alex_GuerreroR': {'MentionCohesion': 0.0,
#                     'MentionExternal': 107,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.0,
#                     'RTExternal': 126,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.63,
#                     'nRTweet': 126,
#                     'nTweet': 200},
#  'AlineCosette': {'MentionCohesion': 0.0,
#                   'MentionExternal': 33,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.023255813953488372,
#                   'RTExternal': 126,
#                   'RTInternal': 3,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.645,
#                   'nRTweet': 129,
#                   'nTweet': 200},
#  'Amanuel40Rui': {'MentionCohesion': 0.0,
#                   'MentionExternal': 3,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 199,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.995,
#                   'nRTweet': 199,
#                   'nTweet': 200},
#  'AndreaBindo': {'MentionCohesion': 0.0,
#                  'MentionExternal': 33,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.5932203389830508,
#                  'RTExternal': 48,
#                  'RTInternal': 70,
#                  'RTPopularity': 70,
#                  'RTweetDiffusion': 0.59,
#                  'nRTweet': 118,
#                  'nTweet': 200},
#  'AndreaRoventini': {'MentionCohesion': 0.391304347826087,
#                      'MentionExternal': 42,
#                      'MentionInternal': 27,
#                      'MentionPopularity': 82,
#                      'RTCohesion': 0.6222222222222222,
#                      'RTExternal': 51,
#                      'RTInternal': 84,
#                      'RTPopularity': 93,
#                      'RTweetDiffusion': 0.675,
#                      'nRTweet': 135,
#                      'nTweet': 200},
#  'Andreas_Chile': {'MentionCohesion': 0.0,
#                    'MentionExternal': 2,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0,
#                    'RTExternal': 0,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.0,
#                    'nRTweet': 0,
#                    'nTweet': 4},
#  'Andrewbrum': {'MentionCohesion': 0.0,
#                 'MentionExternal': 17,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.0,
#                 'RTExternal': 2,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.01,
#                 'nRTweet': 2,
#                 'nTweet': 200},
#  'AngelFe23124123': {'MentionCohesion': 0.0,
#                      'MentionExternal': 8,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0,
#                      'RTExternal': 0,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.0,
#                      'nRTweet': 0,
#                      'nTweet': 9},
#  'Angela07261976': {'MentionCohesion': 0.0,
#                     'MentionExternal': 82,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.0,
#                     'RTExternal': 1,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.005,
#                     'nRTweet': 1,
#                     'nTweet': 200},
#  'Anna_Hadorn': {'MentionCohesion': 0.0,
#                  'MentionExternal': 2,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.0,
#                  'RTExternal': 12,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.8571428571428571,
#                  'nRTweet': 12,
#                  'nTweet': 14},
#  'AnneMur16630871': {'MentionCohesion': 0.0,
#                      'MentionExternal': 175,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 8,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.04,
#                      'nRTweet': 8,
#                      'nTweet': 200},
#  'AppDeveloperHue': {'MentionCohesion': 0.0,
#                      'MentionExternal': 751,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.02,
#                      'RTExternal': 49,
#                      'RTInternal': 1,
#                      'RTPopularity': 1,
#                      'RTweetDiffusion': 0.29069767441860467,
#                      'nRTweet': 50,
#                      'nTweet': 172},
#  'ArcmorRib': {'MentionCohesion': 0.0,
#                'MentionExternal': 26,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0,
#                'RTExternal': 0,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.0,
#                'nRTweet': 0,
#                'nTweet': 26},
#  'ArnautzPgvila': {'MentionCohesion': 0.0,
#                    'MentionExternal': 51,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.0,
#                    'RTExternal': 161,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.805,
#                    'nRTweet': 161,
#                    'nTweet': 200},
#  'Arturo311311311': {'MentionCohesion': 0.0,
#                      'MentionExternal': 2,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0,
#                      'RTExternal': 0,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.0,
#                      'nRTweet': 0,
#                      'nTweet': 2},
#  'AsaBentley': {'MentionCohesion': 0.041474654377880185,
#                 'MentionExternal': 208,
#                 'MentionInternal': 9,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.13978494623655913,
#                 'RTExternal': 80,
#                 'RTInternal': 13,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.465,
#                 'nRTweet': 93,
#                 'nTweet': 200},
#  'Asmmar1999': {'MentionCohesion': 0,
#                 'MentionExternal': 0,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0,
#                 'RTExternal': 0,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.0,
#                 'nRTweet': 0,
#                 'nTweet': 2},
#  'AugustusSouto': {'MentionCohesion': 0.0,
#                    'MentionExternal': 3,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.016574585635359115,
#                    'RTExternal': 178,
#                    'RTInternal': 3,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.905,
#                    'nRTweet': 181,
#                    'nTweet': 200},
#  'BIntendente': {'MentionCohesion': 0.0,
#                  'MentionExternal': 3,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
#                  'nTweet': 200},
#  'BUPardeeCenter': {'MentionCohesion': 0.0,
#                     'MentionExternal': 123,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 6,
#                     'RTCohesion': 0.050724637681159424,
#                     'RTExternal': 131,
#                     'RTInternal': 7,
#                     'RTPopularity': 2,
#                     'RTweetDiffusion': 0.69,
#                     'nRTweet': 138,
#                     'nTweet': 200},
#  'Barone54924381': {'MentionCohesion': 0.0,
#                     'MentionExternal': 16,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.0,
#                     'RTExternal': 41,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.20812182741116753,
#                     'nRTweet': 41,
#                     'nTweet': 197},
#  'BenitoMma': {'MentionCohesion': 0.012711864406779662,
#                'MentionExternal': 233,
#                'MentionInternal': 3,
#                'MentionPopularity': 3,
#                'RTCohesion': 0.14285714285714285,
#                'RTExternal': 24,
#                'RTInternal': 4,
#                'RTPopularity': 4,
#                'RTweetDiffusion': 0.16279069767441862,
#                'nRTweet': 28,
#                'nTweet': 172},
#  'Benmccreton1': {'MentionCohesion': 0.0,
#                   'MentionExternal': 209,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.07692307692307693,
#                   'RTExternal': 12,
#                   'RTInternal': 1,
#                   'RTPopularity': 1,
#                   'RTweetDiffusion': 0.065,
#                   'nRTweet': 13,
#                   'nTweet': 200},
#  'Better_Finance': {'MentionCohesion': 0.017391304347826087,
#                     'MentionExternal': 113,
#                     'MentionInternal': 2,
#                     'MentionPopularity': 3,
#                     'RTCohesion': 0.0234375,
#                     'RTExternal': 125,
#                     'RTInternal': 3,
#                     'RTPopularity': 5,
#                     'RTweetDiffusion': 0.64,
#                     'nRTweet': 128,
#                     'nTweet': 200},
#  'Beyond_Ratings': {'MentionCohesion': 0.09966777408637874,
#                     'MentionExternal': 271,
#                     'MentionInternal': 30,
#                     'MentionPopularity': 20,
#                     'RTCohesion': 0.10526315789473684,
#                     'RTExternal': 17,
#                     'RTInternal': 2,
#                     'RTPopularity': 7,
#                     'RTweetDiffusion': 0.095,
#                     'nRTweet': 19,
#                     'nTweet': 200},
#  'Bifrostonline': {'MentionCohesion': 0.07017543859649122,
#                    'MentionExternal': 53,
#                    'MentionInternal': 4,
#                    'MentionPopularity': 4,
#                    'RTCohesion': 0.019230769230769232,
#                    'RTExternal': 102,
#                    'RTInternal': 2,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.52,
#                    'nRTweet': 104,
#                    'nTweet': 200},
#  'BigDataStackEU': {'MentionCohesion': 0.1111111111111111,
#                     'MentionExternal': 8,
#                     'MentionInternal': 1,
#                     'MentionPopularity': 1,
#                     'RTCohesion': 0,
#                     'RTExternal': 0,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.0,
#                     'nRTweet': 0,
#                     'nTweet': 34},
#  'BingoLittle1': {'MentionCohesion': 0.030303030303030304,
#                   'MentionExternal': 32,
#                   'MentionInternal': 1,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.034482758620689655,
#                   'RTExternal': 168,
#                   'RTInternal': 6,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.87,
#                   'nRTweet': 174,
#                   'nTweet': 200},
#  'BlacMambaMMA': {'MentionCohesion': 0.0,
#                   'MentionExternal': 14,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 143,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.7447916666666666,
#                   'nRTweet': 143,
#                   'nTweet': 192},
#  'Blinis': {'MentionCohesion': 0.0,
#             'MentionExternal': 227,
#             'MentionInternal': 0,
#             'MentionPopularity': 0,
#             'RTCohesion': 0.0,
#             'RTExternal': 41,
#             'RTInternal': 0,
#             'RTPopularity': 0,
#             'RTweetDiffusion': 0.205,
#             'nRTweet': 41,
#             'nTweet': 200},
#  'Blueland1': {'MentionCohesion': 0.0,
#                'MentionExternal': 66,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0,
#                'RTExternal': 0,
#                'RTInternal': 0,
#                'RTPopularity': 2,
#                'RTweetDiffusion': 0.0,
#                'nRTweet': 0,
#                'nTweet': 200},
#  'BluewaterGlobe': {'MentionCohesion': 0.4117647058823529,
#                     'MentionExternal': 30,
#                     'MentionInternal': 21,
#                     'MentionPopularity': 21,
#                     'RTCohesion': 0.009900990099009901,
#                     'RTExternal': 100,
#                     'RTInternal': 1,
#                     'RTPopularity': 1,
#                     'RTweetDiffusion': 0.505,
#                     'nRTweet': 101,
#                     'nTweet': 200},
#  'BoekeKatrin': {'MentionCohesion': 0,
#                  'MentionExternal': 0,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0,
#                  'nRTweet': 0,
#                  'nTweet': 0},
#  'BradZarnett': {'MentionCohesion': 0.0,
#                  'MentionExternal': 58,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 1,
#                  'RTCohesion': 0.0,
#                  'RTExternal': 51,
#                  'RTInternal': 0,
#                  'RTPopularity': 3,
#                  'RTweetDiffusion': 0.255,
#                  'nRTweet': 51,
#                  'nTweet': 200},
#  'BrainConceptual': {'MentionCohesion': 0.0,
#                      'MentionExternal': 6,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 1.0,
#                      'RTExternal': 0,
#                      'RTInternal': 2,
#                      'RTPopularity': 2,
#                      'RTweetDiffusion': 0.038461538461538464,
#                      'nRTweet': 2,
#                      'nTweet': 52},
#  'BsjgMMZetBPIHca': {'MentionCohesion': 0.0,
#                      'MentionExternal': 146,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0,
#                      'RTExternal': 0,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.0,
#                      'nRTweet': 0,
#                      'nTweet': 94},
#  'BusinessPartnrs': {'MentionCohesion': 0.0,
#                      'MentionExternal': 37,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.1111111111111111,
#                      'RTExternal': 8,
#                      'RTInternal': 1,
#                      'RTPopularity': 1,
#                      'RTweetDiffusion': 0.045,
#                      'nRTweet': 9,
#                      'nTweet': 200},
#  'ByGeorgePerr': {'MentionCohesion': 0.0,
#                   'MentionExternal': 7,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0,
#                   'RTExternal': 0,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.0,
#                   'nRTweet': 0,
#                   'nTweet': 200},
#  'CASAPUEBLO8': {'MentionCohesion': 0.0,
#                  'MentionExternal': 13,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.4,
#                  'RTExternal': 6,
#                  'RTInternal': 4,
#                  'RTPopularity': 4,
#                  'RTweetDiffusion': 0.12658227848101267,
#                  'nRTweet': 10,
#                  'nTweet': 79},
#  'CCL_Aus': {'MentionCohesion': 0.008130081300813009,
#              'MentionExternal': 122,
#              'MentionInternal': 1,
#              'MentionPopularity': 1,
#              'RTCohesion': 0.01818181818181818,
#              'RTExternal': 54,
#              'RTInternal': 1,
#              'RTPopularity': 1,
#              'RTweetDiffusion': 0.275,
#              'nRTweet': 55,
#              'nTweet': 200},
#  'CGraciaLazaro': {'MentionCohesion': 0.25925925925925924,
#                    'MentionExternal': 60,
#                    'MentionInternal': 21,
#                    'MentionPopularity': 6,
#                    'RTCohesion': 0.6056338028169014,
#                    'RTExternal': 56,
#                    'RTInternal': 86,
#                    'RTPopularity': 18,
#                    'RTweetDiffusion': 0.71,
#                    'nRTweet': 142,
#                    'nTweet': 200},
#  'CMCSatBU': {'MentionCohesion': 0.015544041450777202,
#               'MentionExternal': 190,
#               'MentionInternal': 3,
#               'MentionPopularity': 3,
#               'RTCohesion': 0.32558139534883723,
#               'RTExternal': 29,
#               'RTInternal': 14,
#               'RTPopularity': 2,
#               'RTweetDiffusion': 0.215,
#               'nRTweet': 43,
#               'nTweet': 200},
#  'CT_Coughlin': {'MentionCohesion': 0.0,
#                  'MentionExternal': 9,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.005780346820809248,
#                  'RTExternal': 172,
#                  'RTInternal': 1,
#                  'RTPopularity': 2,
#                  'RTweetDiffusion': 0.865,
#                  'nRTweet': 173,
#                  'nTweet': 200},
#  'CanddyShawn': {'MentionCohesion': 0.0,
#                  'MentionExternal': 83,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.1,
#                  'RTExternal': 18,
#                  'RTInternal': 2,
#                  'RTPopularity': 2,
#                  'RTweetDiffusion': 0.10050251256281408,
#                  'nRTweet': 20,
#                  'nTweet': 199},
#  'CanvasVC': {'MentionCohesion': 0.008849557522123894,
#               'MentionExternal': 112,
#               'MentionInternal': 1,
#               'MentionPopularity': 1,
#               'RTCohesion': 0.0,
#               'RTExternal': 143,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.715,
#               'nRTweet': 143,
#               'nTweet': 200},
#  'CardanIOTeam': {'MentionCohesion': 0.5,
#                   'MentionExternal': 2,
#                   'MentionInternal': 2,
#                   'MentionPopularity': 1,
#                   'RTCohesion': 0.3333333333333333,
#                   'RTExternal': 10,
#                   'RTInternal': 5,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.5,
#                   'nRTweet': 15,
#                   'nTweet': 30},
#  'CardanoStiftung': {'MentionCohesion': 0.00625,
#                      'MentionExternal': 159,
#                      'MentionInternal': 1,
#                      'MentionPopularity': 2,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 42,
#                      'RTInternal': 0,
#                      'RTPopularity': 5,
#                      'RTweetDiffusion': 0.21105527638190955,
#                      'nRTweet': 42,
#                      'nTweet': 199},
#  'CarnesBestia': {'MentionCohesion': 0.0,
#                   'MentionExternal': 2,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 1,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.0625,
#                   'nRTweet': 1,
#                   'nTweet': 16},
#  'CaroleCasuco': {'MentionCohesion': 0.0196078431372549,
#                   'MentionExternal': 50,
#                   'MentionInternal': 1,
#                   'MentionPopularity': 1,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 123,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.615,
#                   'nRTweet': 123,
#                   'nTweet': 200},
#  'CasaEdelVicenza': {'MentionCohesion': 0.0,
#                      'MentionExternal': 10,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.5833333333333334,
#                      'RTExternal': 5,
#                      'RTInternal': 7,
#                      'RTPopularity': 7,
#                      'RTweetDiffusion': 0.5,
#                      'nRTweet': 12,
#                      'nTweet': 24},
#  'Casinos95': {'MentionCohesion': 0,
#                'MentionExternal': 0,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0,
#                'RTExternal': 0,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0,
#                'nRTweet': 0,
#                'nTweet': 0},
#  'Caydennash2': {'MentionCohesion': 0.0,
#                  'MentionExternal': 53,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.0,
#                  'RTExternal': 18,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.14173228346456693,
#                  'nRTweet': 18,
#                  'nTweet': 127},
#  'CherryEnergy1': {'MentionCohesion': 0.0,
#                    'MentionExternal': 79,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.0,
#                    'RTExternal': 88,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.44221105527638194,
#                    'nRTweet': 88,
#                    'nTweet': 199},
#  'ChrisGGeorgas': {'MentionCohesion': 0.0,
#                    'MentionExternal': 200,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0,
#                    'RTExternal': 0,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.0,
#                    'nRTweet': 0,
#                    'nTweet': 200},
#  'ChrisHudgins5': {'MentionCohesion': 0.0,
#                    'MentionExternal': 24,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.005747126436781609,
#                    'RTExternal': 173,
#                    'RTInternal': 1,
#                    'RTPopularity': 1,
#                    'RTweetDiffusion': 0.90625,
#                    'nRTweet': 174,
#                    'nTweet': 192},
#  'ChristosEllina1': {'MentionCohesion': 0.056818181818181816,
#                      'MentionExternal': 83,
#                      'MentionInternal': 5,
#                      'MentionPopularity': 1,
#                      'RTCohesion': 0.056962025316455694,
#                      'RTExternal': 149,
#                      'RTInternal': 9,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.79,
#                      'nRTweet': 158,
#                      'nTweet': 200},
#  'CigeuInfo': {'MentionCohesion': 0,
#                'MentionExternal': 0,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0,
#                'RTExternal': 0,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0,
#                'nRTweet': 0,
#                'nTweet': 0},
#  'Climate_Friend': {'MentionCohesion': 0.036458333333333336,
#                     'MentionExternal': 185,
#                     'MentionInternal': 7,
#                     'MentionPopularity': 1,
#                     'RTCohesion': 0.08695652173913043,
#                     'RTExternal': 42,
#                     'RTInternal': 4,
#                     'RTPopularity': 2,
#                     'RTweetDiffusion': 0.23,
#                     'nRTweet': 46,
#                     'nTweet': 200},
#  'CoeGSS': {'MentionCohesion': 0.2857142857142857,
#             'MentionExternal': 15,
#             'MentionInternal': 6,
#             'MentionPopularity': 4,
#             'RTCohesion': 0.06428571428571428,
#             'RTExternal': 131,
#             'RTInternal': 9,
#             'RTPopularity': 0,
#             'RTweetDiffusion': 0.7035175879396985,
#             'nRTweet': 140,
#             'nTweet': 199},
#  'Complexity_Labs': {'MentionCohesion': 0.11627906976744186,
#                      'MentionExternal': 38,
#                      'MentionInternal': 5,
#                      'MentionPopularity': 19,
#                      'RTCohesion': 0.5882352941176471,
#                      'RTExternal': 7,
#                      'RTInternal': 10,
#                      'RTPopularity': 27,
#                      'RTweetDiffusion': 0.085,
#                      'nRTweet': 17,
#                      'nTweet': 200},
#  'Concerns_You': {'MentionCohesion': 0.0,
#                   'MentionExternal': 5,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 1,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.005,
#                   'nRTweet': 1,
#                   'nTweet': 200},
#  'CorneliaDaniel': {'MentionCohesion': 0.0,
#                     'MentionExternal': 254,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 1,
#                     'RTCohesion': 0.015384615384615385,
#                     'RTExternal': 64,
#                     'RTInternal': 1,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.325,
#                     'nRTweet': 65,
#                     'nTweet': 200},
#  'CriptodivisasMx': {'MentionCohesion': 0.0,
#                      'MentionExternal': 5,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.010526315789473684,
#                      'RTExternal': 188,
#                      'RTInternal': 2,
#                      'RTPopularity': 2,
#                      'RTweetDiffusion': 0.9595959595959596,
#                      'nRTweet': 190,
#                      'nTweet': 198},
#  'Crypto20183': {'MentionCohesion': 0.0,
#                  'MentionExternal': 11,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.011494252873563218,
#                  'RTExternal': 86,
#                  'RTInternal': 1,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.71900826446281,
#                  'nRTweet': 87,
#                  'nTweet': 121},
#  'CyprusInno': {'MentionCohesion': 0.0,
#                 'MentionExternal': 96,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.0,
#                 'RTExternal': 30,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.15,
#                 'nRTweet': 30,
#                 'nTweet': 200},
#  'DELPHIBG': {'MentionCohesion': 0.0,
#               'MentionExternal': 10,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 1.0,
#               'RTExternal': 0,
#               'RTInternal': 2,
#               'RTPopularity': 2,
#               'RTweetDiffusion': 0.01,
#               'nRTweet': 2,
#               'nTweet': 200},
#  'D_young_69': {'MentionCohesion': 0.029850746268656716,
#                 'MentionExternal': 130,
#                 'MentionInternal': 4,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.05263157894736842,
#                 'RTExternal': 90,
#                 'RTInternal': 5,
#                 'RTPopularity': 5,
#                 'RTweetDiffusion': 0.475,
#                 'nRTweet': 95,
#                 'nTweet': 200},
#  'Daimakaimura': {'MentionCohesion': 0.0,
#                   'MentionExternal': 10,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 190,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.9595959595959596,
#                   'nRTweet': 190,
#                   'nTweet': 198},
#  'DarkMatter_Labs': {'MentionCohesion': 0.9722222222222222,
#                      'MentionExternal': 2,
#                      'MentionInternal': 70,
#                      'MentionPopularity': 2,
#                      'RTCohesion': 0.411214953271028,
#                      'RTExternal': 63,
#                      'RTInternal': 44,
#                      'RTPopularity': 14,
#                      'RTweetDiffusion': 0.535,
#                      'nRTweet': 107,
#                      'nTweet': 200},
#  'DatingCH': {'MentionCohesion': 0,
#               'MentionExternal': 0,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0,
#               'RTExternal': 0,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.0,
#               'nRTweet': 0,
#               'nTweet': 200},
#  'DeboyJames21': {'MentionCohesion': 0.0,
#                   'MentionExternal': 100,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 89,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.4810810810810811,
#                   'nRTweet': 89,
#                   'nTweet': 185},
#  'DecentralizedEn': {'MentionCohesion': 0.0,
#                      'MentionExternal': 32,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.04225352112676056,
#                      'RTExternal': 136,
#                      'RTInternal': 6,
#                      'RTPopularity': 3,
#                      'RTweetDiffusion': 0.71,
#                      'nRTweet': 142,
#                      'nTweet': 200},
#  'DeepestLearning': {'MentionCohesion': 0.0,
#                      'MentionExternal': 25,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0,
#                      'RTExternal': 0,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.0,
#                      'nRTweet': 0,
#                      'nTweet': 12},
#  'Demon666Yt': {'MentionCohesion': 0.0,
#                 'MentionExternal': 16,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.0,
#                 'RTExternal': 1,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.03125,
#                 'nRTweet': 1,
#                 'nTweet': 32},
#  'DiabetesDaisy': {'MentionCohesion': 0.0,
#                    'MentionExternal': 183,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.9770114942528736,
#                    'RTExternal': 2,
#                    'RTInternal': 85,
#                    'RTPopularity': 85,
#                    'RTweetDiffusion': 0.435,
#                    'nRTweet': 87,
#                    'nTweet': 200},
#  'DimasSetyadi5': {'MentionCohesion': 0.0,
#                    'MentionExternal': 2,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0.0,
#                    'RTExternal': 144,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.9863013698630136,
#                    'nRTweet': 144,
#                    'nTweet': 146},
#  'DinoFiorita': {'MentionCohesion': 0.04,
#                  'MentionExternal': 24,
#                  'MentionInternal': 1,
#                  'MentionPopularity': 1,
#                  'RTCohesion': 0.9444444444444444,
#                  'RTExternal': 1,
#                  'RTInternal': 17,
#                  'RTPopularity': 17,
#                  'RTweetDiffusion': 0.09045226130653267,
#                  'nRTweet': 18,
#                  'nTweet': 199},
#  'DistributedNRG': {'MentionCohesion': 0.0,
#                     'MentionExternal': 9,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.019230769230769232,
#                     'RTExternal': 153,
#                     'RTInternal': 3,
#                     'RTPopularity': 6,
#                     'RTweetDiffusion': 0.78,
#                     'nRTweet': 156,
#                     'nTweet': 200},
#  'DougThorpe_com': {'MentionCohesion': 0.0,
#                     'MentionExternal': 192,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.0,
#                     'RTExternal': 38,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 0.19,
#                     'nRTweet': 38,
#                     'nTweet': 200},
#  'DrDrossosDem': {'MentionCohesion': 0.0,
#                   'MentionExternal': 2,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 175,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.875,
#                   'nRTweet': 175,
#                   'nTweet': 200},
#  'Drideologie': {'MentionCohesion': 0.0,
#                  'MentionExternal': 157,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.0,
#                  'RTExternal': 3,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.015,
#                  'nRTweet': 3,
#                  'nTweet': 200},
#  'DucThiLuu': {'MentionCohesion': 0.0,
#                'MentionExternal': 5,
#                'MentionInternal': 0,
#                'MentionPopularity': 2,
#                'RTCohesion': 0.7428571428571429,
#                'RTExternal': 9,
#                'RTInternal': 26,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.7291666666666666,
#                'nRTweet': 35,
#                'nTweet': 48},
#  'Duph_Berg': {'MentionCohesion': 0,
#                'MentionExternal': 0,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0.035175879396984924,
#                'RTExternal': 192,
#                'RTInternal': 7,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 1.0,
#                'nRTweet': 199,
#                'nTweet': 199},
#  'DustyTweak': {'MentionCohesion': 0,
#                 'MentionExternal': 0,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0,
#                 'RTExternal': 0,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0,
#                 'nRTweet': 0,
#                 'nTweet': 0},
#  'EERwtUeb7HgG8pf': {'MentionCohesion': 0.0,
#                      'MentionExternal': 5,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 38,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.2878787878787879,
#                      'nRTweet': 38,
#                      'nTweet': 132},
#  'EHillBrody': {'MentionCohesion': 0,
#                 'MentionExternal': 0,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0,
#                 'RTExternal': 0,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0,
#                 'nRTweet': 0,
#                 'nTweet': 0},
#  'EarthWatt': {'MentionCohesion': 0.0,
#                'MentionExternal': 61,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0.0,
#                'RTExternal': 28,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.1414141414141414,
#                'nRTweet': 28,
#                'nTweet': 198},
#  'Easyimpresa1': {'MentionCohesion': 0,
#                   'MentionExternal': 0,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 1.0,
#                   'RTExternal': 0,
#                   'RTInternal': 4,
#                   'RTPopularity': 4,
#                   'RTweetDiffusion': 0.23529411764705882,
#                   'nRTweet': 4,
#                   'nTweet': 17},
#  'EcologicalEcon': {'MentionCohesion': 0.1111111111111111,
#                     'MentionExternal': 32,
#                     'MentionInternal': 4,
#                     'MentionPopularity': 34,
#                     'RTCohesion': 0.2909090909090909,
#                     'RTExternal': 39,
#                     'RTInternal': 16,
#                     'RTPopularity': 15,
#                     'RTweetDiffusion': 0.275,
#                     'nRTweet': 55,
#                     'nTweet': 200},
#  'Eindhoven60': {'MentionCohesion': 0.0,
#                  'MentionExternal': 190,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
#                  'nTweet': 200},
#  'Elcada_GmbH': {'MentionCohesion': 0.0,
#                  'MentionExternal': 66,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
# ...
#                  'nTweet': 12},
#  'spiros_patelis': {'MentionCohesion': 0,
#                     'MentionExternal': 0,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 1.0,
#                     'RTExternal': 0,
#                     'RTInternal': 1,
#                     'RTPopularity': 1,
#                     'RTweetDiffusion': 0.09090909090909091,
#                     'nRTweet': 1,
#                     'nTweet': 11},
#  'stefanodigiorg3': {'MentionCohesion': 0.008333333333333333,
#                      'MentionExternal': 119,
#                      'MentionInternal': 1,
#                      'MentionPopularity': 1,
#                      'RTCohesion': 0.02702702702702703,
#                      'RTExternal': 36,
#                      'RTInternal': 1,
#                      'RTPopularity': 1,
#                      'RTweetDiffusion': 0.22981366459627328,
#                      'nRTweet': 37,
#                      'nTweet': 161},
#  'stefatos_kostas': {'MentionCohesion': 0.047619047619047616,
#                      'MentionExternal': 20,
#                      'MentionInternal': 1,
#                      'MentionPopularity': 1,
#                      'RTCohesion': 1.0,
#                      'RTExternal': 0,
#                      'RTInternal': 1,
#                      'RTPopularity': 1,
#                      'RTweetDiffusion': 0.005,
#                      'nRTweet': 1,
#                      'nTweet': 200},
#  'stephenkinsella': {'MentionCohesion': 0.007662835249042145,
#                      'MentionExternal': 259,
#                      'MentionInternal': 2,
#                      'MentionPopularity': 12,
#                      'RTCohesion': 0.025,
#                      'RTExternal': 39,
#                      'RTInternal': 1,
#                      'RTPopularity': 12,
#                      'RTweetDiffusion': 0.2,
#                      'nRTweet': 40,
#                      'nTweet': 200},
#  'stf18': {'MentionCohesion': 0.0,
#            'MentionExternal': 193,
#            'MentionInternal': 0,
#            'MentionPopularity': 31,
#            'RTCohesion': 0.02666666666666667,
#            'RTExternal': 73,
#            'RTInternal': 2,
#            'RTPopularity': 5,
#            'RTweetDiffusion': 0.375,
#            'nRTweet': 75,
#            'nTweet': 200},
#  'strategypod': {'MentionCohesion': 0.5,
#                  'MentionExternal': 2,
#                  'MentionInternal': 2,
#                  'MentionPopularity': 2,
#                  'RTCohesion': 0.0,
#                  'RTExternal': 24,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.12,
#                  'nRTweet': 24,
#                  'nTweet': 200},
#  'styvencr7': {'MentionCohesion': 0,
#                'MentionExternal': 0,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0,
#                'RTExternal': 0,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0,
#                'nRTweet': 0,
#                'nTweet': 0},
#  'su_re_co': {'MentionCohesion': 0.1111111111111111,
#               'MentionExternal': 112,
#               'MentionInternal': 14,
#               'MentionPopularity': 9,
#               'RTCohesion': 0.16923076923076924,
#               'RTExternal': 54,
#               'RTInternal': 11,
#               'RTPopularity': 7,
#               'RTweetDiffusion': 0.32663316582914576,
#               'nRTweet': 65,
#               'nTweet': 199},
#  'syaltout': {'MentionCohesion': 0.0,
#               'MentionExternal': 46,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.0,
#               'RTExternal': 144,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.7236180904522613,
#               'nRTweet': 144,
#               'nTweet': 199},
#  'syroter_': {'MentionCohesion': 0.0,
#               'MentionExternal': 16,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0,
#               'RTExternal': 0,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.0,
#               'nRTweet': 0,
#               'nTweet': 23},
#  'systemRK': {'MentionCohesion': 0.6,
#               'MentionExternal': 2,
#               'MentionInternal': 3,
#               'MentionPopularity': 1,
#               'RTCohesion': 0.19230769230769232,
#               'RTExternal': 21,
#               'RTInternal': 5,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.3132530120481928,
#               'nRTweet': 26,
#               'nTweet': 83},
#  'tachristopoulos': {'MentionCohesion': 0.0,
#                      'MentionExternal': 49,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 60,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.3,
#                      'nRTweet': 60,
#                      'nTweet': 200},
#  'takis_kt': {'MentionCohesion': 0.0,
#               'MentionExternal': 98,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.0,
#               'RTExternal': 146,
#               'RTInternal': 0,
#               'RTPopularity': 1,
#               'RTweetDiffusion': 0.73,
#               'nRTweet': 146,
#               'nTweet': 200},
#  'tarik_rko': {'MentionCohesion': 0.15492957746478872,
#                'MentionExternal': 120,
#                'MentionInternal': 22,
#                'MentionPopularity': 0,
#                'RTCohesion': 0.11538461538461539,
#                'RTExternal': 69,
#                'RTInternal': 9,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.3939393939393939,
#                'nRTweet': 78,
#                'nTweet': 198},
#  'thanhbong06': {'MentionCohesion': 0.0,
#                  'MentionExternal': 58,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0.01818181818181818,
#                  'RTExternal': 54,
#                  'RTInternal': 1,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.4074074074074074,
#                  'nRTweet': 55,
#                  'nTweet': 135},
#  'the_young_fdn': {'MentionCohesion': 0.05732484076433121,
#                    'MentionExternal': 148,
#                    'MentionInternal': 9,
#                    'MentionPopularity': 52,
#                    'RTCohesion': 0.1724137931034483,
#                    'RTExternal': 72,
#                    'RTInternal': 15,
#                    'RTPopularity': 63,
#                    'RTweetDiffusion': 0.435,
#                    'nRTweet': 87,
#                    'nTweet': 200},
#  'theceschi': {'MentionCohesion': 0.0,
#                'MentionExternal': 175,
#                'MentionInternal': 0,
#                'MentionPopularity': 0,
#                'RTCohesion': 0.0,
#                'RTExternal': 77,
#                'RTInternal': 0,
#                'RTPopularity': 0,
#                'RTweetDiffusion': 0.385,
#                'nRTweet': 77,
#                'nTweet': 200},
#  'thekokytus': {'MentionCohesion': 0.0,
#                 'MentionExternal': 238,
#                 'MentionInternal': 0,
#                 'MentionPopularity': 0,
#                 'RTCohesion': 0.0,
#                 'RTExternal': 35,
#                 'RTInternal': 0,
#                 'RTPopularity': 0,
#                 'RTweetDiffusion': 0.18134715025906736,
#                 'nRTweet': 35,
#                 'nTweet': 193},
#  'thetippytopblog': {'MentionCohesion': 0.08333333333333333,
#                      'MentionExternal': 22,
#                      'MentionInternal': 2,
#                      'MentionPopularity': 2,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 1,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 0.005025125628140704,
#                      'nRTweet': 1,
#                      'nTweet': 199},
#  'titarchukaj2s': {'MentionCohesion': 0.0,
#                    'MentionExternal': 38,
#                    'MentionInternal': 0,
#                    'MentionPopularity': 0,
#                    'RTCohesion': 0,
#                    'RTExternal': 0,
#                    'RTInternal': 0,
#                    'RTPopularity': 0,
#                    'RTweetDiffusion': 0.0,
#                    'nRTweet': 0,
#                    'nTweet': 39},
#  'tiveleva4ie': {'MentionCohesion': 0.0,
#                  'MentionExternal': 33,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
#                  'nTweet': 34},
#  'tommaschera': {'MentionCohesion': 0.0,
#                  'MentionExternal': 11,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
#                  'nTweet': 11},
#  'tori_henry2': {'MentionCohesion': 0,
#                  'MentionExternal': 0,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 0,
#                  'RTCohesion': 0,
#                  'RTExternal': 0,
#                  'RTInternal': 0,
#                  'RTPopularity': 0,
#                  'RTweetDiffusion': 0.0,
#                  'nRTweet': 0,
#                  'nTweet': 1},
#  'tozhs': {'MentionCohesion': 0,
#            'MentionExternal': 0,
#            'MentionInternal': 0,
#            'MentionPopularity': 0,
#            'RTCohesion': 0,
#            'RTExternal': 0,
#            'RTInternal': 0,
#            'RTPopularity': 0,
#            'RTweetDiffusion': 0,
#            'nRTweet': 0,
#            'nTweet': 0},
#  'tricks_y': {'MentionCohesion': 0.0,
#               'MentionExternal': 194,
#               'MentionInternal': 0,
#               'MentionPopularity': 0,
#               'RTCohesion': 0.0,
#               'RTExternal': 109,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.6193181818181818,
#               'nRTweet': 109,
#               'nTweet': 176},
#  'trxias': {'MentionCohesion': 0.0,
#             'MentionExternal': 3,
#             'MentionInternal': 0,
#             'MentionPopularity': 0,
#             'RTCohesion': 0.0,
#             'RTExternal': 1,
#             'RTInternal': 0,
#             'RTPopularity': 0,
#             'RTweetDiffusion': 0.1,
#             'nRTweet': 1,
#             'nTweet': 10},
#  'uzh_bf': {'MentionCohesion': 0.08108108108108109,
#             'MentionExternal': 102,
#             'MentionInternal': 9,
#             'MentionPopularity': 17,
#             'RTCohesion': 0.3448275862068966,
#             'RTExternal': 19,
#             'RTInternal': 10,
#             'RTPopularity': 13,
#             'RTweetDiffusion': 0.2815533980582524,
#             'nRTweet': 29,
#             'nTweet': 103},
#  'valteraguiar654': {'MentionCohesion': 0.0,
#                      'MentionExternal': 1,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.09302325581395349,
#                      'RTExternal': 156,
#                      'RTInternal': 16,
#                      'RTPopularity': 16,
#                      'RTweetDiffusion': 0.8686868686868687,
#                      'nRTweet': 172,
#                      'nTweet': 198},
#  'vectracrome111': {'MentionCohesion': 0,
#                     'MentionExternal': 0,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 1.0,
#                     'RTExternal': 0,
#                     'RTInternal': 1,
#                     'RTPopularity': 1,
#                     'RTweetDiffusion': 0.005,
#                     'nRTweet': 1,
#                     'nTweet': 200},
#  'veronika_st5': {'MentionCohesion': 0.75,
#                   'MentionExternal': 1,
#                   'MentionInternal': 3,
#                   'MentionPopularity': 4,
#                   'RTCohesion': 0.8909090909090909,
#                   'RTExternal': 6,
#                   'RTInternal': 49,
#                   'RTPopularity': 8,
#                   'RTweetDiffusion': 0.8088235294117647,
#                   'nRTweet': 55,
#                   'nTweet': 68},
#  'vijayakumarmad6': {'MentionCohesion': 0,
#                      'MentionExternal': 0,
#                      'MentionInternal': 0,
#                      'MentionPopularity': 0,
#                      'RTCohesion': 0.0,
#                      'RTExternal': 1,
#                      'RTInternal': 0,
#                      'RTPopularity': 0,
#                      'RTweetDiffusion': 1.0,
#                      'nRTweet': 1,
#                      'nTweet': 1},
#  'vtchakarova': {'MentionCohesion': 0.0,
#                  'MentionExternal': 66,
#                  'MentionInternal': 0,
#                  'MentionPopularity': 23,
#                  'RTCohesion': 0.23076923076923078,
#                  'RTExternal': 90,
#                  'RTInternal': 27,
#                  'RTPopularity': 30,
#                  'RTweetDiffusion': 0.585,
#                  'nRTweet': 117,
#                  'nTweet': 200},
#  'xavierhervas': {'MentionCohesion': 0.0,
#                   'MentionExternal': 27,
#                   'MentionInternal': 0,
#                   'MentionPopularity': 0,
#                   'RTCohesion': 0.00684931506849315,
#                   'RTExternal': 145,
#                   'RTInternal': 1,
#                   'RTPopularity': 1,
#                   'RTweetDiffusion': 0.7336683417085427,
#                   'nRTweet': 146,
#                   'nTweet': 199},
#  'yanhua_yanhua7': {'MentionCohesion': 0,
#                     'MentionExternal': 0,
#                     'MentionInternal': 0,
#                     'MentionPopularity': 0,
#                     'RTCohesion': 0.0,
#                     'RTExternal': 1,
#                     'RTInternal': 0,
#                     'RTPopularity': 0,
#                     'RTweetDiffusion': 1.0,
#                     'nRTweet': 1,
#                     'nTweet': 1},
#  'yuliay': {'MentionCohesion': 0.0,
#             'MentionExternal': 56,
#             'MentionInternal': 0,
#             'MentionPopularity': 0,
#             'RTCohesion': 0.008264462809917356,
#             'RTExternal': 120,
#             'RTInternal': 1,
#             'RTPopularity': 1,
#             'RTweetDiffusion': 0.6080402010050251,
#             'nRTweet': 121,
#             'nTweet': 199},
#  'yuridayana10': {'MentionCohesion': 0.05,
#                   'MentionExternal': 19,
#                   'MentionInternal': 1,
#                   'MentionPopularity': 1,
#                   'RTCohesion': 0.0,
#                   'RTExternal': 77,
#                   'RTInternal': 0,
#                   'RTPopularity': 0,
#                   'RTweetDiffusion': 0.7938144329896907,
#                   'nRTweet': 77,
#                   'nTweet': 97},
#  'zbattiz': {'MentionCohesion': 0.4888888888888889,
#              'MentionExternal': 92,
#              'MentionInternal': 88,
#              'MentionPopularity': 195,
#              'RTCohesion': 0.7230769230769231,
#              'RTExternal': 36,
#              'RTInternal': 94,
#              'RTPopularity': 142,
#              'RTweetDiffusion': 0.65,
#              'nRTweet': 130,
#              'nTweet': 200},
#  'zoozanne': {'MentionCohesion': 0.023255813953488372,
#               'MentionExternal': 84,
#               'MentionInternal': 2,
#               'MentionPopularity': 2,
#               'RTCohesion': 0.0,
#               'RTExternal': 130,
#               'RTInternal': 0,
#               'RTPopularity': 0,
#               'RTweetDiffusion': 0.65,
#               'nRTweet': 130,
#               'nTweet': 200}}

# %%
df_Summary = pd.DataFrame.from_dict(Summary, orient='index')

# %%
df_Summary = df_Summary.sort_values(by = ['MentionPopularity','RTPopularity','nTweet','MentionCohesion','RTCohesion', 'nRTweet'], ascending=False)

# %%
df_Summary.head(10)
# Out:
#                  MentionPopularity  RTPopularity  RTweetDiffusion  nTweet  \
# zbattiz                        195           142            0.650     200
# fet_eu                         193           111            0.450     200
# SimPolProject                  176          1262            0.825     200
# filippoaddarii                 110            39            0.595     200
# forfinancewatch                 97            49            0.525     200
# UNEP_FI                         85            23            0.345     200
# AndreaRoventini                 82            93            0.675     200
# plusvaluetweets                 77            85            0.370     200
# indy_johar                      76            33            0.900     200
# FETFlagships                    74            17            0.870     200
#
#                  nRTweet  MentionInternal  MentionExternal  MentionCohesion  \
# zbattiz              130               88               92         0.488889
# fet_eu                90               36              183         0.164384
# SimPolProject        165               77               47         0.620968
# filippoaddarii       119               53               96         0.355705
# forfinancewatch      105                4               84         0.045455
# UNEP_FI               69               86              143         0.375546
# AndreaRoventini      135               27               42         0.391304
# plusvaluetweets       74              154              204         0.430168
# indy_johar           180                2               17         0.105263
# FETFlagships         174                0               27         0.000000
#
#                  RTInternal  RTExternal  RTCohesion
# zbattiz                  94          36    0.723077
# fet_eu                   26          64    0.288889
# SimPolProject           139          26    0.842424
# filippoaddarii           26          93    0.218487
# forfinancewatch          12          93    0.114286
# UNEP_FI                   6          63    0.086957
# AndreaRoventini          84          51    0.622222
# plusvaluetweets          38          36    0.513514
# indy_johar                0         180    0.000000
# FETFlagships             10         164    0.057471

# %%
df_external_M.head(42).to_csv('top_external_mentions.csv')

# %%
df_external_RT.head(42).to_csv('top_external_RT.csv')

# %%
df_Summary.head(42).to_csv('top_SimPolProject_followers.csv')

# %%
df_Summary.to_csv('SimPolProject_followers.csv')
